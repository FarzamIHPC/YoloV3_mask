# %% [markdown]
# # <font style="color:blue">Train a Custom Object Detector using DarkNet YOLOv3</font>
# In this notebook, we will learn how train a object detector for an object of our choice. We will use DarkNet framework and YOLO v3 architecture.
#
# We will use images of Ambulance from Open Images Dataset.
#
# # <font style="color:blue">Change Runtime Type</font>
# Before proceeding, make sure that the notebook is running on the GPU. Go to Runtime -> Change runtime type -> Select hardware Accelerator as GPU.

# %% [markdown]
# # <font style="color:blue">1. Link Google Drive [ Optional ]</font>
# Since it will take considerable amount of time to train the network, it is a good idea to link your Google Drive with Colab so that everything is backed up. So, if the runtime gets disconnected in the middle of something, you can simply re-link the drive and start working. To link drive, just run the cell below and follow the 2 steps.
#
# 1. It will generate a link. Click on the link to login to your google account
# 1. Get the authorization code and paste it in the box under the cell.
#
# You may however choose to do everything without linking google drive and everything will work as usual.

# %% [markdown]
# ### <font style="color:green">Uncomment the 2 cells below to link google drive</font>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
 # %cd /content/drive/My\ Drive
# Out:
# /content/drive/My Drive

# %% [markdown]
# # <font style="color:blue">2. Clone the DarkNet Repository </font>
# We will use Alexey's darknet fork which has many modifications and improvements and is actively maintained by him.

# %%
# !git clone https://github.com/AlexeyAB/darknet.git
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 13778 (delta 0), reused 1 (delta 0), pack-reused 13775
# Receiving objects: 100% (13778/13778), 12.37 MiB | 6.64 MiB/s, done.
# Resolving deltas: 100% (9402/9402), done.
# Checking out files: 100% (2006/2006), done.

# %% [markdown]
# # <font style="color:blue">3. Compile DarkNet</font>
# We will first make some changes to the Makefile before we compile. Specifically, we will enable the following:
# 1. Build darknet with OpenCV
# 1. Build with CUDA enabled
# 1. Build with cuDNN enabled.

# %%
# %cd darknet
# Out:
# /content/drive/My Drive/darknet

# %%
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile

print("Building. . . It might take 2-3 minutes")

# !make &> build_log.txt
# Out:
# Building. . . It might take 2-3 minutes

# %% [markdown]
# # <font style="color:blue">4. Download Data from Open Images Dataset</font>
# Given below is the script for downloading data from open images dataset.
#
# It downloads 2 files from Open Images.
#
# 1. **train-annotations-bbox.csv** contains the bounding box labels for all images present in the training data of Open Images
# 1. **class-descriptions-boxable.csv** contains the classes which have bounding box annotations available in the dataset.
#
# Using these 2 files we can get a list of all files corresponding to a particular class.
#
# You can specify which classes you want to download and it will download the data. One thing to note here is that YOLO expects the bounding boxes to be in a specific format as given below.
#
# ```
# <object-class> <x_center> <y_center> <width> <height>
# ```
#
# The first field object-class-id is an integer representing the class of the object. It ranges from 0 to (number of classes – 1). In our current case, since we have only one class of snowman, it is always set to 0.
#
# The second and third entry, center-x and center-y are respectively the x and y coordinates of the center of the bounding box, normalized (divided) by the image width and height respectively.
#
# The fourth and fifth entry, width and height are respectively the width and height of the bounding box, again normalized (divided) by the image width and height respectively.
#
# Let’s consider an example with the following notations:
# ```
# x – x-coordinate(in pixels) of the center of the bounding box
# y – y-coordinate(in pixels) of the center of the bounding box
# w – width(in pixels) of the bounding box
# h – height(in pixels) of the bounding box
# W – width(in pixels) of the whole image
# H – height(in pixels) of the whole image
# ```
# Then we compute the annotation values in the label files as follows:
# ```
# center-x = x / W
# center-y = y / H
# width = w / W
# height = h / H
# ```
# The above four entries are all floating point values between 0 to 1.
#
# Note that the 2nd and 3rd elements are centers and NOT the top/bottom left corners. This is different from most datasets available on the internet.
#
# Thus, we reformat the bounding boxes according to YOLO in the last line of code in the function below.
#
# **NOTE:** Downloading the data from aws takes considerable amount of time ( ~7 seconds per image ). Thus, we have provided a zip file for the dataset which you can download in the next cell. You can use the script to download other classes when you experiment further.

# %%
def download_open_images_data(classes=["Ambulance"],maxImages=500):
    import csv
    import subprocess
    import os,time

    if not os.path.exists("train-annotations-bbox.csv"):
        print("Downloading annotation files. . .\n")
        # !wget https://storage.googleapis.com/openimages/2018_04/train/train-annotations-bbox.csv
        # !wget https://storage.googleapis.com/openimages/2018_04/class-descriptions-boxable.csv
    
    # !pip install awscli &> /dev/null

    runMode = "train"
    dataPath = "OID-data"

    with open('class-descriptions-boxable.csv', mode='r') as infile:
        reader = csv.reader(infile)
        dict_list = {rows[1]:rows[0] for rows in reader}

    subprocess.run(['rm', '-rf', dataPath])
    subprocess.run([ 'mkdir', dataPath])

    for ind in range(0, len(classes)):
        
        className = classes[ind]
        print("Class " + str(ind) + " : " + className)

        commandStr = "grep " + dict_list[className] + " " + runMode + "-annotations-bbox.csv"
        print(commandStr)
        class_annotations = subprocess.run(commandStr.split(), stdout=subprocess.PIPE).stdout.decode('utf-8')
        class_annotations = class_annotations.splitlines()

        totalNumOfAnnotations = len(class_annotations)
        print("Total number of annotations : "+str(totalNumOfAnnotations))
        cnt = 0
        for line in class_annotations[0:min(maxImages,totalNumOfAnnotations)]:

            cnt = cnt + 1
            print("annotation count : " + str(cnt))
            lineParts = line.split(',')
            subprocess.run([ 'aws', 's3', '--no-sign-request', '--only-show-errors', 'cp', 's3://open-images-dataset/'+runMode+'/'+lineParts[0]+".jpg", dataPath + '/'+lineParts[0]+".jpg"])
            with open(dataPath + '/%s.txt'%(lineParts[0]),'a') as f:
                f.write(' '.join([str(ind),str((float(lineParts[5]) + float(lineParts[4]))/2), str((float(lineParts[7]) + float(lineParts[6]))/2), str(float(lineParts[5])-float(lineParts[4])),str(float(lineParts[7])-float(lineParts[6]))])+'\n')

# %%
classes = ["Ambulance"]
maxImages = 400

# %% [markdown]
# Uncomment the cell below if you want to download a new class. You can download the data using the cell below.

# %%
## It might ask you to restart runtime, but it is not required.
# download_open_images_data(classes, maxImages)

# %% [markdown]
# ## <font style="color:blue">4.1. Download Data</font>
# Download the data which we have shared using the dropbox link. This is a faster way. You can use the above process for downloading any other category.

# %%
# !wget "https://www.dropbox.com/s/84jr6gxlvrw3azy/OID-data.zip?dl=1" -O OID-data.zip
# !unzip OID-data.zip &> /dev/null
# Out:
# --2020-06-30 09:25:56--  https://www.dropbox.com/s/84jr6gxlvrw3azy/OID-data.zip?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.1, 2620:100:601d:1::a27d:501
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/84jr6gxlvrw3azy/OID-data.zip [following]
# --2020-06-30 09:25:56--  https://www.dropbox.com/s/dl/84jr6gxlvrw3azy/OID-data.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc15cc66568f4448468a317be3a4.dl.dropboxusercontent.com/cd/0/get/A6ohqJgALBCyga-s_8VEPRWJLxd3HPbdC6ePsrMb5FP42Y9QN1FTKkcpRVrxcJdnu-lPW8_IcbRlz5jkoPWkuem2oSrFQfwSrk8ndLYRF7xSysFyk7aE_w56Npx6n4tbuqo/file?dl=1# [following]
# --2020-06-30 09:25:57--  https://uc15cc66568f4448468a317be3a4.dl.dropboxusercontent.com/cd/0/get/A6ohqJgALBCyga-s_8VEPRWJLxd3HPbdC6ePsrMb5FP42Y9QN1FTKkcpRVrxcJdnu-lPW8_IcbRlz5jkoPWkuem2oSrFQfwSrk8ndLYRF7xSysFyk7aE_w56Npx6n4tbuqo/file?dl=1
# Resolving uc15cc66568f4448468a317be3a4.dl.dropboxusercontent.com (uc15cc66568f4448468a317be3a4.dl.dropboxusercontent.com)... 162.125.5.15, 2620:100:601d:15::a27d:50f
# Connecting to uc15cc66568f4448468a317be3a4.dl.dropboxusercontent.com (uc15cc66568f4448468a317be3a4.dl.dropboxusercontent.com)|162.125.5.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 116188863 (111M) [application/binary]
# Saving to: ‘OID-data.zip’
#
# OID-data.zip        100%[===================>] 110.81M  49.5MB/s    in 2.2s
#
# 2020-06-30 09:26:00 (49.5 MB/s) - ‘OID-data.zip’ saved [116188863/116188863]

# %% [markdown]
# ## <font style="color:blue">4.2. Prepare dataset files</font>
# We need to create a txt file which contains the path to the images. These files will be used while setting up the training.
#
# The data is split into train and test in the ratio of 80:20. So, we will use 80% of the data for training and the rest for testing after a few iterations of training.

# %%
import random
import os
import subprocess
import sys

#image_dir = "./OID-data"  # This is for Ambulance object detection
image_dir = "./kaggle_and_no-mask_dataset"  # This is for mask detection

f_val = open("data_test.txt", 'w')
f_train = open("data_train.txt", 'w')

path, dirs, files = next(os.walk(image_dir))
data_size = len(files)

ind = 0
data_test_size = int(0.2 * data_size)
test_array = random.sample(range(data_size), k=data_test_size)

for f in os.listdir(image_dir):
    if(f.split(".")[-1] == "jpg"):
        ind += 1
        
        if ind in test_array:
            f_val.write(image_dir+'/'+f+'\n')
        else:
            f_train.write(image_dir+'/'+f+'\n')

f_train.close()
f_val.close()

# %% [markdown]
# # <font style="color:blue">5. Download Code for YOLO Training</font>
# We have shared the code for training in the link below. Explanation of each file follows next.

# %%
# !wget "https://www.dropbox.com/sh/jfyj1wetf28bgpr/AACGJHIlPyKRO70B9DlAVqWPa?dl=1" -O yolov3-ambulance-code.zip
# !unzip yolov3-ambulance-code.zip
# Out:
# --2020-06-30 09:30:46--  https://www.dropbox.com/sh/jfyj1wetf28bgpr/AACGJHIlPyKRO70B9DlAVqWPa?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.1, 2620:100:601d:1::a27d:501
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /sh/dl/jfyj1wetf28bgpr/AACGJHIlPyKRO70B9DlAVqWPa [following]
# --2020-06-30 09:30:46--  https://www.dropbox.com/sh/dl/jfyj1wetf28bgpr/AACGJHIlPyKRO70B9DlAVqWPa
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc77f6a6e60b6716ebe66f6f38d0.dl.dropboxusercontent.com/zip_download_get/AeBLin5wfEDs0Nx1_1yzJL-PJHshfmn_pkzqRl-GzoxNqj-OLbjugSahNQqZAyPjdvziTh6ZMIHc0-etfyInHtp2s3iceREPJecRK2SL8zJu2A?dl=1 [following]
# --2020-06-30 09:30:47--  https://uc77f6a6e60b6716ebe66f6f38d0.dl.dropboxusercontent.com/zip_download_get/AeBLin5wfEDs0Nx1_1yzJL-PJHshfmn_pkzqRl-GzoxNqj-OLbjugSahNQqZAyPjdvziTh6ZMIHc0-etfyInHtp2s3iceREPJecRK2SL8zJu2A?dl=1
# Resolving uc77f6a6e60b6716ebe66f6f38d0.dl.dropboxusercontent.com (uc77f6a6e60b6716ebe66f6f38d0.dl.dropboxusercontent.com)... 162.125.5.15, 2620:100:601d:15::a27d:50f
# Connecting to uc77f6a6e60b6716ebe66f6f38d0.dl.dropboxusercontent.com (uc77f6a6e60b6716ebe66f6f38d0.dl.dropboxusercontent.com)|162.125.5.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17639 (17K) [application/zip]
# Saving to: ‘yolov3-ambulance-code.zip’
#
# yolov3-ambulance-co 100%[===================>]  17.23K  --.-KB/s    in 0.04s
#
# 2020-06-30 09:30:47 (444 KB/s) - ‘yolov3-ambulance-code.zip’ saved [17639/17639]
#
# Archive:  yolov3-ambulance-code.zip
# warning:  stripped absolute path spec from /
# mapname:  conversion of  failed
#  extracting: class.names
#  extracting: yolov3-ambulance-test.cfg
#  extracting: yolov3-ambulance-train.cfg
#  extracting: yolov3-ambulance-setup.data

# %% [markdown]
# You can see there are 4 files which have been downloaded. We will go through each file in the next section.

# %% [markdown]
# # <font style="color:blue">6. Download weights for Convolutional backbone</font>
# When you train your own object detector, it is a good idea to leverage existing models trained on very large datasets even though the large dataset may not contain the object you are trying to detect. This process is called transfer learning.
#
# Instead of learning from scratch, we use a pre-trained model which contains convolutional weights trained on ImageNet. Using these weights as our starting weights, our network can learn faster. We will use the pre-trained convolutional backbone.
#
# We will download the weights file from our server as the author's server seemed slow. If you face any issues, you can download the file from the link given in the code below.

# %%
# Original File : https://pjreddie.com/media/files/darknet53.conv.74
# !wget "https://www.dropbox.com/s/18dwbfth7prbf0h/darknet53.conv.74?dl=1" -O darknet53.conv.74
# Out:
# --2020-06-30 09:34:50--  https://www.dropbox.com/s/18dwbfth7prbf0h/darknet53.conv.74?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.1, 2620:100:601d:1::a27d:501
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/18dwbfth7prbf0h/darknet53.conv.74 [following]
# --2020-06-30 09:34:51--  https://www.dropbox.com/s/dl/18dwbfth7prbf0h/darknet53.conv.74
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc88654fb080abdb33cca7af8aca.dl.dropboxusercontent.com/cd/0/get/A6p18D7dWfiyjwZii39egZiWoPsW2_CxQPuqIO6DlTrjP5MoJXj0mfgNhFmyr0KeSEgrkFH4tWZ4z4B1hZX5Ik6OvQAilzn3mNbdgW3JTvq0wXw4qcjMSr895Ss2y9le1gU/file?dl=1# [following]
# --2020-06-30 09:34:51--  https://uc88654fb080abdb33cca7af8aca.dl.dropboxusercontent.com/cd/0/get/A6p18D7dWfiyjwZii39egZiWoPsW2_CxQPuqIO6DlTrjP5MoJXj0mfgNhFmyr0KeSEgrkFH4tWZ4z4B1hZX5Ik6OvQAilzn3mNbdgW3JTvq0wXw4qcjMSr895Ss2y9le1gU/file?dl=1
# Resolving uc88654fb080abdb33cca7af8aca.dl.dropboxusercontent.com (uc88654fb080abdb33cca7af8aca.dl.dropboxusercontent.com)... 162.125.5.15, 2620:100:601d:15::a27d:50f
# Connecting to uc88654fb080abdb33cca7af8aca.dl.dropboxusercontent.com (uc88654fb080abdb33cca7af8aca.dl.dropboxusercontent.com)|162.125.5.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/binary]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  50.2MB/s    in 3.1s
#
# 2020-06-30 09:34:55 (50.2 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %% [markdown]
# # <font style="color:blue">7. Training Configuration</font>
# As explained in the theory section, we will use the config file to specify the various training parameters. A gist of all the parameters is given below:
#
# ## <font style="color:blue">7.1. Data Setup</font>
# In the file **`yolov3-ambulance-setup.data`**(included in our code), we need to provide information about the specifications for our object detector and some relevant paths.
#
# The contents of the file are as follows:
# ```
# classes = 1
# train  = data_train.txt
# valid  = data_test.txt
# names = class.names
# backup = backup/
# ```
# The classes parameter needs the number of classes. In our case, it is 1.
#
# You need to provide the absolute paths of the files **`data_train.txt`** and **`data_test.txt`** generated earlier, which have the list of files to be used for training(train parameter) and validation(valid parameter) respectively.
#
# The names field represents the path of a file which contains the names of all the classes. We have included the **`class.names`** file which contains the class name **`Ambulance`**. You will need to provide its absolute path in your machine here.
#
# Lastly, for the **`backup`** parameter, we need to give the path to an existing directory where we can store the intermediate weights files as the training progresses.
#
# ## <font style="color:blue">7.2. Training Config File</font>
# Along with the yolov3-ambulance-setup.data and class.names files, YOLOv3 also needs a configuration file **`yolov3-ambulance-train.cfg`**. It is based on the demo configuration file, yolov3-voc.cfg (comes with darknet code), which was used to train on the VOC dataset. All the important training parameters are stored in this configuration file. Let us understand what they mean and what values to set them to.
#
# ### <font style="color:green">7.2.1 Batch hyper-parameter in YOLOv3</font>
# Let’s learn more about batch and subdivision parameter.
# ```
# [net]
# # Testing
# # batch=1
# # subdivisions=1
# # Training
# batch=64
# subdivisions=16
# ```
# The batch parameter indicates the batch size used during training.
#
# Our training set contains a few hundred images, but it is not uncommon to train on million of images. The training process involves iteratively updating the weights of the neural network based on how many mistakes it is making on the training dataset.
#
# It is impractical (and unnecessary) to use all images in the training set at once to update the weights. So, a small subset of images is used in one iteration, and this subset is called the batch size.
#
# When the batch size is set to 64, it means 64 images are used in one iteration to update the parameters of the neural network.
#
# ### <font style="color:green">7.2.2 Subdivisions configuration parameter in YOLOv3</font>
# Even though you may want to use a batch size of 64 for training your neural network, you may not have a GPU with enough memory to use a batch size of 64. Fortunately, Darknet allows you to specify a variable called subdivisions that lets you process a fraction of the batch size at one time on your GPU.
#
# You can start the training with subdivisions=1, and if you get an Out of memory error, increase the subdivisions parameter by multiples of 2(e.g. 2, 4, 8, 16) till the training proceeds successfully. The GPU will process batch/subdivision number of images at any time, but the full batch or iteration would be complete only after all the 64 (as set above) images are processed.
#
# During testing, both batch and subdivision are set to 1.
#
# ### <font style="color:green">7.2.3 Width, Height, Channels</font>
# These configuration parameters specify the input image size and the number of channels.
#
# ```
# width=416
# height=416
# channels=3
# ```
# The input training images are first resized to width x height before training. Here we use the default values of 416×416. The results might improve if we increase it to 608×608, but it would take longer to train too. channels=3 indicates that we would be processing 3-channel RGB input images.
#
# ### <font style="color:green">7.2.4 Momentum and Decay</font>
# The configuration file contains a few parameters that control how the weight is updated.
# ```
# momentum=0.9
# decay=0.0005
# ```
# In the previous section, we mentioned how the weights of a neural network are updated based on a small batch of images and not the entire dataset. Because of this reason, the weight updates fluctuate quite a bit. That is why a parameter momentum is used to penalize large weight changes between iterations.
#
# A typical neural network has millions of weights and therefore they can easily overfit any training data. Overfitting simply means it will do very well on training data and poorly on test data. It is almost like the neural network has memorized the answer to all images in the training set, but really not learned the underlying concept. One of the ways to mitigate this problem is to penalize large value for weights. The parameter decay controls this penalty term. The default value works just fine, but you may want to tweak this if you notice overfitting.
#
# ### <font style="color:green">7.2.5 Learning Rate, Steps, Scales, Burn In (warm-up)</font>
# ```
# learning_rate=0.001
# policy=steps
# steps=800
# scales=.1
# burn_in=100
# ```
# The parameter learning rate controls how aggressively we should learn based on the current batch of data. Typically this is a number between 0.01 and 0.0001.
#
# At the beginning of the training process, we are starting with zero information and so the learning rate needs to be high. But as the neural network sees a lot of data, the weights need to change less aggressively. In other words, the learning rate needs to be decreased over time. In the configuration file, this decrease in learning rate is accomplished by first specifying that our learning rate decreasing policy is steps. In the above example, the learning rate will start from 0.001 and remain constant for 800 iterations, and then it will multiply by scales to get the new learning rate. We could have also specified multiple steps and scales.
#
# In the previous paragraph, we mentioned that the learning rate needs to be high in the beginning and low later on. While that statement is largely true, it has been empirically found that the training speed tends to increase if we have a lower learning rate for a short period of time at the very beginning. This is controlled by the burn_in parameter. Sometimes this **`burn-in`** period is also called warm-up period.
#
# ### <font style="color:green">7.2.6 Data augmentation</font>
# We know data collection takes a long time and it is difficult to find high quality annotated data. We want to make maximum use of this data by cooking up new data. This process is called data augmentation. For example, an image of the ambulance rotated by 5 degrees is still an image of a ambulance. The angle parameter in the configuration file allows you to randomly rotate the given image by ± angle.
#
# Similarly, if we transform the colors of the entire picture using saturation, exposure, and hue, it is still a picture of the ambulance.
# ```
# angle=0
# saturation = 1.5
# exposure = 1.5
# hue=.1
# ```
# We used the default values for training.
#
# ### <font style="color:green">7.2.7 Number of iterations</font>
# Finally, we need to specify how many iterations should the training process be run for.
# ```
# max_batches=1000
# ```
#
# For multi-class object detectors, the max_batches number is higher, i.e. we need to run for more number of batches(e.g. in yolov3-voc.cfg). For an n-classes object detector, it is advisable to run the training for at least 2000*n batches. In our case with only 1 class, 1000 seemed like a safe number for max_batches.
#
# You should try to change the parameter and see how it performs.
#
# ### <font style="color:green">7.2.8 Change filters parameter in conv layers [Important for multiple objects]</font>
# Change the filters parameter in the convolutional layer just before the yolo layer according to the formula
#
# **`filters=( classes + 5 ) * 3`**
#
# Since we are using classes = 1, thus, #filters in our case is 18. You should make this change if you are dealing with more classes.
#
#
# ## <font color="blue">7.3. Names file </font>
# We need to specify the names of the classes in the **`.names`** file. In our case, there is only 1 class and thus, only Ambulance is added to that file.

# %% [markdown]
# # <font style="color:blue">8. Start Training </font>
# For starting training using darknet, we need to execute the following command. Here we are specifying the
# 1. path to the setup file,
# 1. path to config file,
# 1. path to convolutional weights file
#
# and also passing some flags such as:
#
# - **`dont_show`** which wont display the graphs. This is required for Colab since it does not have a display and it will crash if it tries to display, not if you run the notebook on your local system.
# - **`map`** - this will calculate mAP - mean average precision for the test data which we have specified using the data_test.txt file which contains 20% of our data.

# %%
# This is for Ambulance training
#!./darknet detector train yolov3-ambulance-setup.data yolov3-ambulance-train.cfg ./darknet53.conv.74 -dont_show -map 2> train_log.txt

# This is for MASK training
#!./darknet detector train yolov3-mask-setup.data yolov3-mask-train.cfg ./darknet53.conv.74 -dont_show -map 2> train_log.txt


# This is for MASK training using YoloV4
# !./darknet detector train yolov3-mask-setup.data yolov3-mask-train.cfg ./yolov4.conv.137 -dont_show -map 2> train_log.txt
# Out:
# Streaming output truncated to the last 5000 lines.
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  109: 4.803411, 4.562279 avg loss, 0.001000 rate, 12.061156 seconds, 6976 images, 5.665752 hours left
# Loaded: 0.000052 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  110: 3.354853, 4.441536 avg loss, 0.001000 rate, 11.767167 seconds, 7040 images, 5.638946 hours left
# Resizing, random_coef = 1.40
#
#  512 x 512
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.000062 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  111: 2.673720, 4.264755 avg loss, 0.001000 rate, 19.160819 seconds, 7104 images, 5.611648 hours left
# Loaded: 0.000056 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  112: 5.464955, 4.384775 avg loss, 0.001000 rate, 19.962497 seconds, 7168 images, 5.602848 hours left
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  113: 4.398705, 4.386168 avg loss, 0.001000 rate, 20.259563 seconds, 7232 images, 5.596061 hours left
# Loaded: 0.000038 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  114: 2.777035, 4.225254 avg loss, 0.001000 rate, 19.919019 seconds, 7296 images, 5.590018 hours left
# Loaded: 0.000049 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  115: 5.413814, 4.344110 avg loss, 0.001000 rate, 20.183820 seconds, 7360 images, 5.583141 hours left
# Loaded: 0.000073 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  116: 3.473467, 4.257046 avg loss, 0.001000 rate, 20.003661 seconds, 7424 images, 5.576928 hours left
# Loaded: 0.000041 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  117: 3.617514, 4.193092 avg loss, 0.001000 rate, 20.047241 seconds, 7488 images, 5.570279 hours left
# Loaded: 0.000046 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  118: 4.277908, 4.201574 avg loss, 0.001000 rate, 20.174263 seconds, 7552 images, 5.563748 hours left
# Loaded: 0.000042 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  119: 2.733989, 4.054815 avg loss, 0.001000 rate, 19.847451 seconds, 7616 images, 5.557537 hours left
# Loaded: 0.000087 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  120: 4.191000, 4.068434 avg loss, 0.001000 rate, 20.021087 seconds, 7680 images, 5.550533 hours left
# Resizing, random_coef = 1.40
#
#  512 x 512
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.247462 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  121: 4.421261, 4.103716 avg loss, 0.001000 rate, 19.687461 seconds, 7744 images, 5.543969 hours left
# Loaded: 0.000098 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  122: 3.959312, 4.089276 avg loss, 0.001000 rate, 20.232398 seconds, 7808 images, 5.537203 hours left
# Loaded: 0.000073 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  123: 23.634329, 6.043781 avg loss, 0.001000 rate, 20.039844 seconds, 7872 images, 5.531176 hours left
# Loaded: 0.000040 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  124: 6.257647, 6.065168 avg loss, 0.001000 rate, 20.474228 seconds, 7936 images, 5.524684 hours left
# Loaded: 0.000046 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  125: 10.037543, 6.462405 avg loss, 0.001000 rate, 20.227243 seconds, 8000 images, 5.519258 hours left
# Loaded: 0.000053 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  126: 5.203438, 6.336508 avg loss, 0.001000 rate, 20.304704 seconds, 8064 images, 5.513229 hours left
# Loaded: 0.000048 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  127: 3.252823, 6.028140 avg loss, 0.001000 rate, 19.927891 seconds, 8128 images, 5.507392 hours left
# Loaded: 0.000068 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  128: 6.414006, 6.066726 avg loss, 0.001000 rate, 19.895953 seconds, 8192 images, 5.500644 hours left
# Loaded: 0.000044 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  129: 4.336471, 5.893701 avg loss, 0.001000 rate, 20.137803 seconds, 8256 images, 5.493830 hours left
# Loaded: 0.000047 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  130: 7.448545, 6.049185 avg loss, 0.001000 rate, 20.431184 seconds, 8320 images, 5.487614 hours left
# Resizing, random_coef = 1.40
#
#  448 x 448
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.317161 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  131: 7.696259, 6.213892 avg loss, 0.001000 rate, 15.167717 seconds, 8384 images, 5.482113 hours left
# Loaded: 0.000092 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  132: 4.565245, 6.049028 avg loss, 0.001000 rate, 15.436714 seconds, 8448 images, 5.464671 hours left
# Loaded: 0.000074 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  133: 3.775507, 5.821676 avg loss, 0.001000 rate, 15.199583 seconds, 8512 images, 5.447244 hours left
# Loaded: 0.000036 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  134: 4.421421, 5.681650 avg loss, 0.001000 rate, 15.492514 seconds, 8576 images, 5.429378 hours left
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  135: 3.155408, 5.429026 avg loss, 0.001000 rate, 15.279997 seconds, 8640 images, 5.412352 hours left
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  136: 5.040780, 5.390202 avg loss, 0.001000 rate, 15.667986 seconds, 8704 images, 5.394943 hours left
# Loaded: 0.000048 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  137: 4.484987, 5.299680 avg loss, 0.001000 rate, 15.253285 seconds, 8768 images, 5.378597 hours left
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  138: 3.528953, 5.122608 avg loss, 0.001000 rate, 15.327822 seconds, 8832 images, 5.361377 hours left
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  139: 4.083852, 5.018732 avg loss, 0.001000 rate, 15.345209 seconds, 8896 images, 5.344465 hours left
# Loaded: 0.000039 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  140: 6.059017, 5.122761 avg loss, 0.001000 rate, 15.283463 seconds, 8960 images, 5.327721 hours left
# Resizing, random_coef = 1.40
#
#  608 x 608
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.000051 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  141: 5.588220, 5.169307 avg loss, 0.001000 rate, 28.252645 seconds, 9024 images, 5.310954 hours left
# Loaded: 0.000069 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  142: 6.200036, 5.272380 avg loss, 0.001000 rate, 28.217679 seconds, 9088 images, 5.325259 hours left
# Loaded: 0.000047 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  143: 7.060692, 5.451211 avg loss, 0.001000 rate, 28.116574 seconds, 9152 images, 5.339259 hours left
# Loaded: 0.000072 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  144: 8.108446, 5.716935 avg loss, 0.001000 rate, 27.860978 seconds, 9216 images, 5.352799 hours left
# Loaded: 0.000048 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  145: 21.590004, 7.304242 avg loss, 0.001000 rate, 28.236156 seconds, 9280 images, 5.365519 hours left
# Loaded: 0.000039 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  146: 3.996253, 6.973443 avg loss, 0.001000 rate, 28.016698 seconds, 9344 images, 5.378924 hours left
# Loaded: 0.000052 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  147: 5.442605, 6.820359 avg loss, 0.001000 rate, 28.012365 seconds, 9408 images, 5.391597 hours left
# Loaded: 0.000044 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  148: 3.509608, 6.489284 avg loss, 0.001000 rate, 28.018837 seconds, 9472 images, 5.404055 hours left
# Loaded: 0.000040 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  149: 3.761538, 6.216509 avg loss, 0.001000 rate, 27.895247 seconds, 9536 images, 5.416326 hours left
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  150: 9.483305, 6.543189 avg loss, 0.001000 rate, 28.544742 seconds, 9600 images, 5.428104 hours left
# Resizing, random_coef = 1.40
#
#  352 x 352
#  try to allocate additional workspace_size = 8.92 MB
#  CUDA allocate done!
# Loaded: 0.000096 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  151: 4.301662, 6.319036 avg loss, 0.001000 rate, 9.946318 seconds, 9664 images, 5.441220 hours left
# Loaded: 0.000048 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  152: 5.222628, 6.209395 avg loss, 0.001000 rate, 10.200984 seconds, 9728 images, 5.410265 hours left
# Loaded: 0.000041 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  153: 5.484735, 6.136930 avg loss, 0.001000 rate, 10.064843 seconds, 9792 images, 5.380192 hours left
# Loaded: 0.000075 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  154: 4.274511, 5.950688 avg loss, 0.001000 rate, 10.146115 seconds, 9856 images, 5.350070 hours left
# Loaded: 0.000068 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  155: 4.262228, 5.781842 avg loss, 0.001000 rate, 10.152402 seconds, 9920 images, 5.320413 hours left
# Loaded: 0.000042 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  156: 4.082092, 5.611867 avg loss, 0.001000 rate, 10.236464 seconds, 9984 images, 5.291039 hours left
# Loaded: 0.000040 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  157: 9.037557, 5.954436 avg loss, 0.001000 rate, 10.104507 seconds, 10048 images, 5.262128 hours left
# Loaded: 0.000073 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  158: 3.582048, 5.717197 avg loss, 0.001000 rate, 9.999086 seconds, 10112 images, 5.233168 hours left
# Loaded: 0.000069 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  159: 2.886609, 5.434138 avg loss, 0.001000 rate, 10.154246 seconds, 10176 images, 5.204223 hours left
# Loaded: 0.000058 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  160: 4.512249, 5.341949 avg loss, 0.001000 rate, 10.213437 seconds, 10240 images, 5.175903 hours left
# Resizing, random_coef = 1.40
#
#  384 x 384
#  try to allocate additional workspace_size = 10.62 MB
#  CUDA allocate done!
# Loaded: 0.000053 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  161: 12.588596, 6.066614 avg loss, 0.001000 rate, 11.785091 seconds, 10304 images, 5.147975 hours left
# Loaded: 0.000035 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  162: 4.479226, 5.907875 avg loss, 0.001000 rate, 11.957910 seconds, 10368 images, 5.123961 hours left
# Loaded: 0.000039 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  163: 5.690126, 5.886100 avg loss, 0.001000 rate, 11.899957 seconds, 10432 images, 5.100557 hours left
# Loaded: 0.000080 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  164: 4.549603, 5.752450 avg loss, 0.001000 rate, 11.862804 seconds, 10496 images, 5.077219 hours left
# Loaded: 0.000047 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  165: 4.257580, 5.602963 avg loss, 0.001000 rate, 11.788069 seconds, 10560 images, 5.053995 hours left
# Loaded: 0.000037 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  166: 3.727165, 5.415383 avg loss, 0.001000 rate, 11.749840 seconds, 10624 images, 5.030797 hours left
# Loaded: 0.000047 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  167: 3.778654, 5.251710 avg loss, 0.001000 rate, 12.033991 seconds, 10688 images, 5.007710 hours left
# Loaded: 0.000065 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  168: 6.221165, 5.348656 avg loss, 0.001000 rate, 11.967277 seconds, 10752 images, 4.985478 hours left
# Loaded: 0.000038 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  169: 5.593458, 5.373136 avg loss, 0.001000 rate, 12.016125 seconds, 10816 images, 4.963281 hours left
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  170: 10.368315, 5.872654 avg loss, 0.001000 rate, 11.909972 seconds, 10880 images, 4.941386 hours left
# Resizing, random_coef = 1.40
#
#  512 x 512
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.000087 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  171: 7.615702, 6.046959 avg loss, 0.001000 rate, 19.832348 seconds, 10944 images, 4.919431 hours left
# Loaded: 0.000046 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  172: 6.127745, 6.055037 avg loss, 0.001000 rate, 20.505793 seconds, 11008 images, 4.915907 hours left
# Loaded: 0.000039 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  173: 3.817815, 5.831315 avg loss, 0.001000 rate, 20.024250 seconds, 11072 images, 4.913911 hours left
# Loaded: 0.000055 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  174: 6.212399, 5.869423 avg loss, 0.001000 rate, 20.276166 seconds, 11136 images, 4.910772 hours left
# Loaded: 0.000049 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  175: 4.213346, 5.703815 avg loss, 0.001000 rate, 20.063471 seconds, 11200 images, 4.908187 hours left
# Loaded: 0.000044 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  176: 3.119673, 5.445401 avg loss, 0.001000 rate, 19.855465 seconds, 11264 images, 4.905084 hours left
# Loaded: 0.000068 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  177: 4.185418, 5.319403 avg loss, 0.001000 rate, 20.199404 seconds, 11328 images, 4.901480 hours left
# Loaded: 0.000040 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  178: 5.323755, 5.319838 avg loss, 0.001000 rate, 20.480735 seconds, 11392 images, 4.898644 hours left
# Loaded: 0.000042 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  179: 34.079472, 8.195802 avg loss, 0.001000 rate, 20.276461 seconds, 11456 images, 4.896422 hours left
# Loaded: 0.000058 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  180: 3.640843, 7.740306 avg loss, 0.001000 rate, 20.144318 seconds, 11520 images, 4.893699 hours left
# Resizing, random_coef = 1.40
#
#  480 x 480
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.017353 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  181: 4.747900, 7.441065 avg loss, 0.001000 rate, 17.802395 seconds, 11584 images, 4.890647 hours left
# Loaded: 0.000077 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  182: 4.046453, 7.101604 avg loss, 0.001000 rate, 18.215132 seconds, 11648 images, 4.882280 hours left
# Loaded: 0.000069 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  183: 22.470472, 8.638491 avg loss, 0.001000 rate, 18.070676 seconds, 11712 images, 4.874847 hours left
# Loaded: 0.000044 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  184: 3.262564, 8.100898 avg loss, 0.001000 rate, 17.990607 seconds, 11776 images, 4.867109 hours left
# Loaded: 0.000043 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  185: 4.051277, 7.695936 avg loss, 0.001000 rate, 18.238010 seconds, 11840 images, 4.859217 hours left
# Loaded: 0.000046 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  186: 4.021719, 7.328514 avg loss, 0.001000 rate, 17.957906 seconds, 11904 images, 4.851913 hours left
# Loaded: 0.000073 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  187: 5.033900, 7.099053 avg loss, 0.001000 rate, 18.296042 seconds, 11968 images, 4.843999 hours left
# Loaded: 0.000037 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  188: 4.892688, 6.878417 avg loss, 0.001000 rate, 18.129199 seconds, 12032 images, 4.836878 hours left
# Loaded: 0.000049 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  189: 9.635883, 7.154163 avg loss, 0.001000 rate, 18.640256 seconds, 12096 images, 4.829401 hours left
# Loaded: 0.000038 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  190: 5.397976, 6.978545 avg loss, 0.001000 rate, 18.096670 seconds, 12160 images, 4.823099 hours left
# Resizing, random_coef = 1.40
#
#  416 x 416
#  try to allocate additional workspace_size = 12.46 MB
#  CUDA allocate done!
# Loaded: 0.036716 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  191: 4.423983, 6.723088 avg loss, 0.001000 rate, 13.401607 seconds, 12224 images, 4.815586 hours left
# Loaded: 0.000061 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  192: 4.878790, 6.538659 avg loss, 0.001000 rate, 13.690934 seconds, 12288 images, 4.797629 hours left
# Loaded: 0.000038 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  193: 6.029178, 6.487710 avg loss, 0.001000 rate, 13.827732 seconds, 12352 images, 4.780381 hours left
# Loaded: 0.000049 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  194: 4.432461, 6.282186 avg loss, 0.001000 rate, 13.634609 seconds, 12416 images, 4.763575 hours left
# Loaded: 0.000044 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  195: 5.482918, 6.202259 avg loss, 0.001000 rate, 13.723830 seconds, 12480 images, 4.746466 hours left
# Loaded: 0.000079 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  196: 2.912469, 5.873280 avg loss, 0.001000 rate, 13.591712 seconds, 12544 images, 4.729689 hours left
# Loaded: 0.000047 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  197: 4.021305, 5.688082 avg loss, 0.001000 rate, 13.865122 seconds, 12608 images, 4.712747 hours left
# Loaded: 0.000051 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  198: 6.876661, 5.806940 avg loss, 0.001000 rate, 13.711619 seconds, 12672 images, 4.696547 hours left
# Loaded: 0.000084 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  199: 11.462734, 6.372519 avg loss, 0.001000 rate, 13.671665 seconds, 12736 images, 4.680128 hours left
# Loaded: 0.000091 seconds
#
#  (next mAP calculation at 200 iterations)
#  Last accuracy mAP@0.5 = 0.00 %, best = 0.00 %
#  200: 4.086339, 6.143901 avg loss, 0.001000 rate, 13.676548 seconds, 12800 images, 4.663746 hours left
# Resizing to initial size: 416 x 416  try to allocate additional workspace_size = 12.46 MB
#  CUDA allocate done!
#
#  calculation mAP (mean average precision)...
#
#  detections_count = 66, unique_truth_count = 2147
# class_id = 0, name = Mask, ap = 0.00%   	 (TP = 0, FP = 0)
# class_id = 1, name = No_mask, ap = 0.00%   	 (TP = 0, FP = 0)
#
#  for conf_thresh = 0.25, precision = -nan, recall = 0.00, F1-score = -nan
#  for conf_thresh = 0.25, TP = 0, FP = 0, FN = 2147, average IoU = 0.00 %
#
#  IoU threshold = 50 %, used Area-Under-Curve for each unique Recall
#  mean average precision (mAP@0.50) = 0.000000, or 0.00 %
#
# Set -points flag:
#  `-points 101` for MS COCO
#  `-points 11` for PascalVOC 2007 (uncomment `difficult` in voc.data)
#  `-points 0` (AUC) for ImageNet, PascalVOC 2010-2012, your custom dataset
#
#  mean_average_precision (mAP@0.5) = 0.000000
# Resizing, random_coef = 1.40
#
#  416 x 416
#  try to allocate additional workspace_size = 12.46 MB
#  CUDA allocate done!
# Loaded: 0.885980 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 300 iterations)
#  201: 5.007518, 6.030263 avg loss, 0.001000 rate, 13.616872 seconds, 12864 images, 4.697615 hours left
# Loaded: 0.000057 seconds
#
#  (next mAP calculation at 300 iterations)
#  202: 3.750207, 5.802258 avg loss, 0.001000 rate, 13.655754 seconds, 12928 images, 4.682827 hours left
# Loaded: 0.000044 seconds
#
#  (next mAP calculation at 300 iterations)
#  203: 4.068250, 5.628857 avg loss, 0.001000 rate, 13.729702 seconds, 12992 images, 4.666269 hours left
# Loaded: 0.000069 seconds
#
#  (next mAP calculation at 300 iterations)
#  204: 2.315384, 5.297509 avg loss, 0.001000 rate, 13.612004 seconds, 13056 images, 4.650003 hours left
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 300 iterations)
#  205: 4.289280, 5.196686 avg loss, 0.001000 rate, 13.901499 seconds, 13120 images, 4.633600 hours left
# Loaded: 0.000068 seconds
#
#  (next mAP calculation at 300 iterations)
#  206: 3.558200, 5.032838 avg loss, 0.001000 rate, 13.687138 seconds, 13184 images, 4.617964 hours left
# Loaded: 0.000039 seconds
#
#  (next mAP calculation at 300 iterations)
#  207: 4.548388, 4.984393 avg loss, 0.001000 rate, 13.866598 seconds, 13248 images, 4.601972 hours left
# Loaded: 0.000043 seconds
#
#  (next mAP calculation at 300 iterations)
#  208: 5.082707, 4.994225 avg loss, 0.001000 rate, 13.848274 seconds, 13312 images, 4.586497 hours left
# Loaded: 0.000073 seconds
#
#  (next mAP calculation at 300 iterations)
#  209: 8.561492, 5.350951 avg loss, 0.001000 rate, 13.982748 seconds, 13376 images, 4.571099 hours left
# Loaded: 0.000073 seconds
#
#  (next mAP calculation at 300 iterations)
#  210: 3.762579, 5.192114 avg loss, 0.001000 rate, 13.715953 seconds, 13440 images, 4.556111 hours left
# Resizing, random_coef = 1.40
#
#  384 x 384
#  try to allocate additional workspace_size = 10.62 MB
#  CUDA allocate done!
# Loaded: 0.754527 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 300 iterations)
#  211: 4.639039, 5.136806 avg loss, 0.001000 rate, 12.143458 seconds, 13504 images, 4.540649 hours left
# Loaded: 0.000071 seconds
#
#  (next mAP calculation at 300 iterations)
#  212: 4.079808, 5.031106 avg loss, 0.001000 rate, 11.916541 seconds, 13568 images, 4.523511 hours left
# Loaded: 0.000044 seconds
#
#  (next mAP calculation at 300 iterations)
#  213: 5.494131, 5.077409 avg loss, 0.001000 rate, 12.018367 seconds, 13632 images, 4.504360 hours left
# Loaded: 0.000056 seconds
#
#  (next mAP calculation at 300 iterations)
#  214: 3.422135, 4.911881 avg loss, 0.001000 rate, 11.747939 seconds, 13696 images, 4.485590 hours left
# Loaded: 0.000042 seconds
#
#  (next mAP calculation at 300 iterations)
#  215: 4.752478, 4.895941 avg loss, 0.001000 rate, 12.097971 seconds, 13760 images, 4.466384 hours left
# Loaded: 0.000041 seconds
#
#  (next mAP calculation at 300 iterations)
#  216: 4.307253, 4.837072 avg loss, 0.001000 rate, 11.909063 seconds, 13824 images, 4.448100 hours left
# Loaded: 0.000043 seconds
#
#  (next mAP calculation at 300 iterations)
#  217: 3.431196, 4.696485 avg loss, 0.001000 rate, 11.808532 seconds, 13888 images, 4.429555 hours left
# Loaded: 0.000055 seconds
#
#  (next mAP calculation at 300 iterations)
#  218: 4.049225, 4.631759 avg loss, 0.001000 rate, 11.744870 seconds, 13952 images, 4.410943 hours left
# Loaded: 0.000046 seconds
#
#  (next mAP calculation at 300 iterations)
#  219: 3.676877, 4.536271 avg loss, 0.001000 rate, 11.820492 seconds, 14016 images, 4.392346 hours left
# Loaded: 0.000064 seconds
#
#  (next mAP calculation at 300 iterations)
#  220: 3.666738, 4.449317 avg loss, 0.001000 rate, 12.101222 seconds, 14080 images, 4.374067 hours left
# Resizing, random_coef = 1.40
#
#  352 x 352
#  try to allocate additional workspace_size = 8.92 MB
#  CUDA allocate done!
# Loaded: 0.000049 seconds
#
#  (next mAP calculation at 300 iterations)
#  221: 3.230056, 4.327391 avg loss, 0.001000 rate, 9.913144 seconds, 14144 images, 4.356546 hours left
# Loaded: 0.000049 seconds
#
#  (next mAP calculation at 300 iterations)
#  222: 6.494631, 4.544115 avg loss, 0.001000 rate, 10.678379 seconds, 14208 images, 4.334431 hours left
# Loaded: 0.000067 seconds
#
#  (next mAP calculation at 300 iterations)
#  223: 4.843967, 4.574100 avg loss, 0.001000 rate, 10.307272 seconds, 14272 images, 4.314164 hours left
# Loaded: 0.000039 seconds
#
#  (next mAP calculation at 300 iterations)
#  224: 4.967752, 4.613466 avg loss, 0.001000 rate, 10.181661 seconds, 14336 images, 4.293269 hours left
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 300 iterations)
#  225: 3.764985, 4.528618 avg loss, 0.001000 rate, 10.144131 seconds, 14400 images, 4.272284 hours left
# Loaded: 0.000046 seconds
#
#  (next mAP calculation at 300 iterations)
#  226: 3.499830, 4.425739 avg loss, 0.001000 rate, 10.057387 seconds, 14464 images, 4.251399 hours left
# Loaded: 0.000063 seconds
#
#  (next mAP calculation at 300 iterations)
#  227: 3.434897, 4.326655 avg loss, 0.001000 rate, 10.097603 seconds, 14528 images, 4.230509 hours left
# Loaded: 0.000040 seconds
#
#  (next mAP calculation at 300 iterations)
#  228: 3.870007, 4.280990 avg loss, 0.001000 rate, 10.274275 seconds, 14592 images, 4.209886 hours left
# Loaded: 0.000043 seconds
#
#  (next mAP calculation at 300 iterations)
#  229: 203.389297, 24.191820 avg loss, 0.001000 rate, 10.169276 seconds, 14656 images, 4.189820 hours left
# Loaded: 0.000050 seconds
#
#  (next mAP calculation at 300 iterations)
#  230: 5.182134, 22.290852 avg loss, 0.001000 rate, 10.281355 seconds, 14720 images, 4.169701 hours left
# Resizing, random_coef = 1.40
#
#  544 x 544
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.000042 seconds
#
#  (next mAP calculation at 300 iterations)
#  231: 4.386254, 20.500391 avg loss, 0.001000 rate, 22.371823 seconds, 14784 images, 4.149995 hours left
# Loaded: 0.000046 seconds
#
#  (next mAP calculation at 300 iterations)
#  232: 4.728555, 18.923208 avg loss, 0.001000 rate, 22.783042 seconds, 14848 images, 4.156283 hours left
# Loaded: 0.000043 seconds
#
#  (next mAP calculation at 300 iterations)
#  233: 4.259441, 17.456831 avg loss, 0.001000 rate, 22.625612 seconds, 14912 images, 4.163325 hours left
# Loaded: 0.000046 seconds
#
#  (next mAP calculation at 300 iterations)
#  234: 7.569685, 16.468117 avg loss, 0.001000 rate, 23.026764 seconds, 14976 images, 4.169897 hours left
# Loaded: 0.000048 seconds
#
#  (next mAP calculation at 300 iterations)
#  235: 6.404949, 15.461800 avg loss, 0.001000 rate, 23.086082 seconds, 15040 images, 4.177194 hours left
# Loaded: 0.000055 seconds
#
#  (next mAP calculation at 300 iterations)
#  236: 7.655795, 14.681199 avg loss, 0.001000 rate, 23.164313 seconds, 15104 images, 4.184480 hours left
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 300 iterations)
#  237: 5.622365, 13.775315 avg loss, 0.001000 rate, 23.171019 seconds, 15168 images, 4.191795 hours left
# Loaded: 0.000044 seconds
#
#  (next mAP calculation at 300 iterations)
#  238: 10.060742, 13.403858 avg loss, 0.001000 rate, 23.309564 seconds, 15232 images, 4.198987 hours left
# Loaded: 0.000049 seconds
#
#  (next mAP calculation at 300 iterations)
#  239: 5.838736, 12.647346 avg loss, 0.001000 rate, 22.837972 seconds, 15296 images, 4.206336 hours left
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 300 iterations)
#  240: 6.566585, 12.039269 avg loss, 0.001000 rate, 22.911590 seconds, 15360 images, 4.212549 hours left
# Resizing, random_coef = 1.40
#
#  320 x 320
#  try to allocate additional workspace_size = 7.37 MB
#  CUDA allocate done!
# Loaded: 0.000084 seconds
#
#  (next mAP calculation at 300 iterations)
#  241: 6.874468, 11.522789 avg loss, 0.001000 rate, 8.180184 seconds, 15424 images, 4.218793 hours left
# Loaded: 0.000048 seconds
#
#  (next mAP calculation at 300 iterations)
#  242: 5.392088, 10.909719 avg loss, 0.001000 rate, 8.450929 seconds, 15488 images, 4.193852 hours left
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 300 iterations)
#  243: 137.822952, 23.601042 avg loss, 0.001000 rate, 8.476733 seconds, 15552 images, 4.169707 hours left
# Loaded: 0.000049 seconds
#
#  (next mAP calculation at 300 iterations)
#  244: 11.906038, 22.431541 avg loss, 0.001000 rate, 8.589474 seconds, 15616 images, 4.145835 hours left
# Loaded: 0.000055 seconds
#
#  (next mAP calculation at 300 iterations)
#  245: 31.756472, 23.364035 avg loss, 0.001000 rate, 8.560665 seconds, 15680 images, 4.122415 hours left
# Loaded: 0.000057 seconds
#
#  (next mAP calculation at 300 iterations)
#  246: 5.160958, 21.543728 avg loss, 0.001000 rate, 8.561509 seconds, 15744 images, 4.099144 hours left
# Loaded: 0.000070 seconds
#
#  (next mAP calculation at 300 iterations)
#  247: 7.568014, 20.146156 avg loss, 0.001000 rate, 8.446821 seconds, 15808 images, 4.076085 hours left
# Loaded: 0.000054 seconds
#
#  (next mAP calculation at 300 iterations)
#  248: 4.604871, 18.592028 avg loss, 0.001000 rate, 8.458823 seconds, 15872 images, 4.052992 hours left
# Loaded: 0.000421 seconds
#
#  (next mAP calculation at 300 iterations)
#  249: 5.753073, 17.308132 avg loss, 0.001000 rate, 8.605647 seconds, 15936 images, 4.030132 hours left
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 300 iterations)
#  250: 4.063124, 15.983631 avg loss, 0.001000 rate, 8.448839 seconds, 16000 images, 4.007784 hours left
# Resizing, random_coef = 1.40
#
#  384 x 384
#  try to allocate additional workspace_size = 10.62 MB
#  CUDA allocate done!
# Loaded: 0.000098 seconds
#
#  (next mAP calculation at 300 iterations)
#  251: 4.539893, 14.839257 avg loss, 0.001000 rate, 11.626037 seconds, 16064 images, 3.985308 hours left
# Loaded: 0.000036 seconds
#
#  (next mAP calculation at 300 iterations)
#  252: 4.365850, 13.791917 avg loss, 0.001000 rate, 11.711808 seconds, 16128 images, 3.969644 hours left
# Loaded: 0.000053 seconds
#
#  (next mAP calculation at 300 iterations)
#  253: 6.290581, 13.041783 avg loss, 0.001000 rate, 11.906661 seconds, 16192 images, 3.954282 hours left
# Loaded: 0.000039 seconds
#
#  (next mAP calculation at 300 iterations)
#  254: 4.460398, 12.183645 avg loss, 0.001000 rate, 11.998578 seconds, 16256 images, 3.939446 hours left
# Loaded: 0.000037 seconds
#
#  (next mAP calculation at 300 iterations)
#  255: 8.045943, 11.769876 avg loss, 0.001000 rate, 12.007601 seconds, 16320 images, 3.924915 hours left
# Loaded: 0.000047 seconds
#
#  (next mAP calculation at 300 iterations)
#  256: 8.560229, 11.448911 avg loss, 0.001000 rate, 11.889261 seconds, 16384 images, 3.910515 hours left
# Loaded: 0.000055 seconds
#
#  (next mAP calculation at 300 iterations)
#  257: 14.761942, 11.780214 avg loss, 0.001000 rate, 11.884223 seconds, 16448 images, 3.895981 hours left
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 300 iterations)
#  258: 6.881621, 11.290355 avg loss, 0.001000 rate, 12.095999 seconds, 16512 images, 3.881549 hours left
# Loaded: 0.000039 seconds
#
#  (next mAP calculation at 300 iterations)
#  259: 3.790292, 10.540348 avg loss, 0.001000 rate, 11.786631 seconds, 16576 images, 3.867665 hours left
# Loaded: 0.000047 seconds
#
#  (next mAP calculation at 300 iterations)
#  260: 5.700769, 10.056390 avg loss, 0.001000 rate, 11.852420 seconds, 16640 images, 3.853249 hours left
# Resizing, random_coef = 1.40
#
#  416 x 416
#  try to allocate additional workspace_size = 12.46 MB
#  CUDA allocate done!
# Loaded: 0.000163 seconds
#
#  (next mAP calculation at 300 iterations)
#  261: 4.028533, 9.453604 avg loss, 0.001000 rate, 13.442052 seconds, 16704 images, 3.839080 hours left
# Loaded: 0.000065 seconds
#
#  (next mAP calculation at 300 iterations)
#  262: 4.218902, 8.930134 avg loss, 0.001000 rate, 13.737620 seconds, 16768 images, 3.828283 hours left
# Loaded: 0.000060 seconds
#
#  (next mAP calculation at 300 iterations)
#  263: 4.366038, 8.473724 avg loss, 0.001000 rate, 13.543892 seconds, 16832 images, 3.818163 hours left
# Loaded: 0.000062 seconds
#
#  (next mAP calculation at 300 iterations)
#  264: 3.618968, 7.988249 avg loss, 0.001000 rate, 13.836347 seconds, 16896 images, 3.807709 hours left
# Loaded: 0.000046 seconds
#
#  (next mAP calculation at 300 iterations)
#  265: 3.576802, 7.547104 avg loss, 0.001000 rate, 13.798434 seconds, 16960 images, 3.797919 hours left
# Loaded: 0.000059 seconds
#
#  (next mAP calculation at 300 iterations)
#  266: 3.584741, 7.150868 avg loss, 0.001000 rate, 13.821441 seconds, 17024 images, 3.788112 hours left
# Loaded: 0.000056 seconds
#
#  (next mAP calculation at 300 iterations)
#  267: 4.988075, 6.934588 avg loss, 0.001000 rate, 13.894617 seconds, 17088 images, 3.778412 hours left
# Loaded: 0.000062 seconds
#
#  (next mAP calculation at 300 iterations)
#  268: 5.251150, 6.766244 avg loss, 0.001000 rate, 13.843148 seconds, 17152 images, 3.768919 hours left
# Loaded: 0.000053 seconds
#
#  (next mAP calculation at 300 iterations)
#  269: 5.222510, 6.611871 avg loss, 0.001000 rate, 14.092594 seconds, 17216 images, 3.759377 hours left
# Loaded: 0.000095 seconds
#
#  (next mAP calculation at 300 iterations)
#  270: 4.121053, 6.362790 avg loss, 0.001000 rate, 13.689577 seconds, 17280 images, 3.750400 hours left
# Resizing, random_coef = 1.40
#
#  352 x 352
#  try to allocate additional workspace_size = 8.92 MB
#  CUDA allocate done!
# Loaded: 0.273609 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 300 iterations)
#  271: 4.691966, 6.195707 avg loss, 0.001000 rate, 10.344699 seconds, 17344 images, 3.740655 hours left
# Loaded: 0.000042 seconds
#
#  (next mAP calculation at 300 iterations)
#  272: 5.852971, 6.161434 avg loss, 0.001000 rate, 10.282482 seconds, 17408 images, 3.724751 hours left
# Loaded: 0.000072 seconds
#
#  (next mAP calculation at 300 iterations)
#  273: 6.075311, 6.152822 avg loss, 0.001000 rate, 10.324509 seconds, 17472 images, 3.708297 hours left
# Loaded: 0.000065 seconds
#
#  (next mAP calculation at 300 iterations)
#  274: 4.562747, 5.993814 avg loss, 0.001000 rate, 10.254505 seconds, 17536 images, 3.692064 hours left
# Loaded: 0.000072 seconds
#
#  (next mAP calculation at 300 iterations)
#  275: 5.495963, 5.944029 avg loss, 0.001000 rate, 10.291648 seconds, 17600 images, 3.675823 hours left
# Loaded: 0.000073 seconds
#
#  (next mAP calculation at 300 iterations)
#  276: 3.927492, 5.742375 avg loss, 0.001000 rate, 10.039655 seconds, 17664 images, 3.659791 hours left
# Loaded: 0.000059 seconds
#
#  (next mAP calculation at 300 iterations)
#  277: 2.882527, 5.456390 avg loss, 0.001000 rate, 10.008224 seconds, 17728 images, 3.643385 hours left
# Loaded: 0.000074 seconds
#
#  (next mAP calculation at 300 iterations)
#  278: 3.259874, 5.236739 avg loss, 0.001000 rate, 10.094500 seconds, 17792 images, 3.627051 hours left
# Loaded: 0.000063 seconds
#
#  (next mAP calculation at 300 iterations)
#  279: 4.330328, 5.146098 avg loss, 0.001000 rate, 10.131547 seconds, 17856 images, 3.611026 hours left
# Loaded: 0.000055 seconds
#
#  (next mAP calculation at 300 iterations)
#  280: 6.096962, 5.241184 avg loss, 0.001000 rate, 10.294689 seconds, 17920 images, 3.595207 hours left
# Resizing, random_coef = 1.40
#
#  352 x 352
#  try to allocate additional workspace_size = 8.92 MB
#  CUDA allocate done!
# Loaded: 0.390220 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 300 iterations)
#  281: 3.630980, 5.080164 avg loss, 0.001000 rate, 9.998755 seconds, 17984 images, 3.579844 hours left
# Loaded: 0.000046 seconds
#
#  (next mAP calculation at 300 iterations)
#  282: 2.977989, 4.869946 avg loss, 0.001000 rate, 10.148481 seconds, 18048 images, 3.564795 hours left
# Loaded: 0.000043 seconds
#
#  (next mAP calculation at 300 iterations)
#  283: 5.052331, 4.888185 avg loss, 0.001000 rate, 10.191513 seconds, 18112 images, 3.549388 hours left
# Loaded: 0.000083 seconds
#
#  (next mAP calculation at 300 iterations)
#  284: 3.790825, 4.778449 avg loss, 0.001000 rate, 10.075150 seconds, 18176 images, 3.534192 hours left
# Loaded: 0.000095 seconds
#
#  (next mAP calculation at 300 iterations)
#  285: 3.144620, 4.615066 avg loss, 0.001000 rate, 10.026734 seconds, 18240 images, 3.518889 hours left
# Loaded: 0.000051 seconds
#
#  (next mAP calculation at 300 iterations)
#  286: 3.101301, 4.463690 avg loss, 0.001000 rate, 10.052833 seconds, 18304 images, 3.503614 hours left
# Loaded: 0.000048 seconds
#
#  (next mAP calculation at 300 iterations)
#  287: 3.348825, 4.352203 avg loss, 0.001000 rate, 10.156866 seconds, 18368 images, 3.488516 hours left
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 300 iterations)
#  288: 4.624638, 4.379447 avg loss, 0.001000 rate, 10.216458 seconds, 18432 images, 3.473748 hours left
# Loaded: 0.000054 seconds
#
#  (next mAP calculation at 300 iterations)
#  289: 3.916116, 4.333114 avg loss, 0.001000 rate, 10.121162 seconds, 18496 images, 3.459216 hours left
# Loaded: 0.000052 seconds
#
#  (next mAP calculation at 300 iterations)
#  290: 4.386424, 4.338445 avg loss, 0.001000 rate, 10.153859 seconds, 18560 images, 3.444613 hours left
# Resizing, random_coef = 1.40
#
#  448 x 448
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.000051 seconds
#
#  (next mAP calculation at 300 iterations)
#  291: 4.130272, 4.317627 avg loss, 0.001000 rate, 14.994670 seconds, 18624 images, 3.430193 hours left
# Loaded: 0.000061 seconds
#
#  (next mAP calculation at 300 iterations)
#  292: 3.889074, 4.274772 avg loss, 0.001000 rate, 15.312397 seconds, 18688 images, 3.425422 hours left
# Loaded: 0.000052 seconds
#
#  (next mAP calculation at 300 iterations)
#  293: 3.092232, 4.156518 avg loss, 0.001000 rate, 15.345983 seconds, 18752 images, 3.421283 hours left
# Loaded: 0.000044 seconds
#
#  (next mAP calculation at 300 iterations)
#  294: 3.193698, 4.060236 avg loss, 0.001000 rate, 15.056605 seconds, 18816 images, 3.417208 hours left
# Loaded: 0.000076 seconds
#
#  (next mAP calculation at 300 iterations)
#  295: 3.603849, 4.014597 avg loss, 0.001000 rate, 15.322549 seconds, 18880 images, 3.412564 hours left
# Loaded: 0.000072 seconds
#
#  (next mAP calculation at 300 iterations)
#  296: 4.445659, 4.057703 avg loss, 0.001000 rate, 15.453267 seconds, 18944 images, 3.408445 hours left
# Loaded: 0.000049 seconds
#
#  (next mAP calculation at 300 iterations)
#  297: 7.135553, 4.365489 avg loss, 0.001000 rate, 15.836728 seconds, 19008 images, 3.404580 hours left
# Loaded: 0.000044 seconds
#
#  (next mAP calculation at 300 iterations)
#  298: 3.005124, 4.229452 avg loss, 0.001000 rate, 15.199899 seconds, 19072 images, 3.401460 hours left
# Loaded: 0.000070 seconds
#
#  (next mAP calculation at 300 iterations)
#  299: 4.416546, 4.248161 avg loss, 0.001000 rate, 15.634285 seconds, 19136 images, 3.397086 hours left
# Loaded: 0.000037 seconds
#
#  (next mAP calculation at 300 iterations)
#  300: 5.388113, 4.362156 avg loss, 0.001000 rate, 15.557172 seconds, 19200 images, 3.393558 hours left
# Resizing to initial size: 416 x 416  try to allocate additional workspace_size = 12.46 MB
#  CUDA allocate done!
#
#  calculation mAP (mean average precision)...
#
#  detections_count = 8229, unique_truth_count = 2147
# class_id = 0, name = Mask, ap = 0.91%   	 (TP = 0, FP = 0)
# class_id = 1, name = No_mask, ap = 0.10%   	 (TP = 0, FP = 0)
#
#  for conf_thresh = 0.25, precision = -nan, recall = 0.00, F1-score = -nan
#  for conf_thresh = 0.25, TP = 0, FP = 0, FN = 2147, average IoU = 0.00 %
#
#  IoU threshold = 50 %, used Area-Under-Curve for each unique Recall
#  mean average precision (mAP@0.50) = 0.005062, or 0.51 %
#
# Set -points flag:
#  `-points 101` for MS COCO
#  `-points 11` for PascalVOC 2007 (uncomment `difficult` in voc.data)
#  `-points 0` (AUC) for ImageNet, PascalVOC 2010-2012, your custom dataset
#
#  mean_average_precision (mAP@0.5) = 0.005062
# New best mAP!
# Resizing, random_coef = 1.40
#
#  352 x 352
#  try to allocate additional workspace_size = 8.92 MB
#  CUDA allocate done!
# Loaded: 0.885770 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 0.51 %, best = 0.51 %
#  301: 4.989726, 4.424913 avg loss, 0.001000 rate, 10.308196 seconds, 19264 images, 3.436076 hours left
# Loaded: 0.000047 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 0.51 %, best = 0.51 %
#  302: 5.320964, 4.514518 avg loss, 0.001000 rate, 10.491437 seconds, 19328 images, 3.423451 hours left
# Loaded: 0.000070 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 0.51 %, best = 0.51 %
#  303: 5.019121, 4.564979 avg loss, 0.001000 rate, 10.241053 seconds, 19392 images, 3.409558 hours left
# Loaded: 0.000082 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 0.51 %, best = 0.51 %
#  304: 3.765227, 4.485003 avg loss, 0.001000 rate, 10.230697 seconds, 19456 images, 3.395290 hours left
# Loaded: 0.000068 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 0.51 %, best = 0.51 %
#  305: 3.437456, 4.380249 avg loss, 0.001000 rate, 10.043590 seconds, 19520 images, 3.381117 hours left
# Loaded: 0.000043 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 0.51 %, best = 0.51 %
#  306: 4.611483, 4.403372 avg loss, 0.001000 rate, 10.127306 seconds, 19584 images, 3.366696 hours left
# Loaded: 0.000033 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 0.51 %, best = 0.51 %
#  307: 3.885348, 4.351569 avg loss, 0.001000 rate, 10.236362 seconds, 19648 images, 3.352552 hours left
# Loaded: 0.000041 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 0.51 %, best = 0.51 %
#  308: 2.787029, 4.195115 avg loss, 0.001000 rate, 9.957379 seconds, 19712 images, 3.338732 hours left
# Loaded: 0.000060 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 0.51 %, best = 0.51 %
#  309: 3.667501, 4.142354 avg loss, 0.001000 rate, 10.171288 seconds, 19776 images, 3.324485 hours left
# Loaded: 0.000046 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 0.51 %, best = 0.51 %
#  310: 3.087744, 4.036892 avg loss, 0.001000 rate, 10.079714 seconds, 19840 images, 3.310763 hours left
# Resizing, random_coef = 1.40
#
#  416 x 416
#  try to allocate additional workspace_size = 12.46 MB
#  CUDA allocate done!
# Loaded: 0.000062 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 0.51 %, best = 0.51 %
#  311: 4.036877, 4.036891 avg loss, 0.001000 rate, 13.554025 seconds, 19904 images, 3.296975 hours left
# Loaded: 0.000075 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 0.51 %, best = 0.51 %
#  312: 5.069498, 4.140152 avg loss, 0.001000 rate, 14.309888 seconds, 19968 images, 3.289946 hours left
# Loaded: 0.000059 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 0.51 %, best = 0.51 %
#  313: 3.084288, 4.034565 avg loss, 0.001000 rate, 13.804658 seconds, 20032 images, 3.284395 hours left
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 0.51 %, best = 0.51 %
#  314: 4.893563, 4.120465 avg loss, 0.001000 rate, 14.238076 seconds, 20096 images, 3.277895 hours left
# Loaded: 0.000051 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 0.51 %, best = 0.51 %
#  315: 3.377570, 4.046175 avg loss, 0.001000 rate, 13.676409 seconds, 20160 images, 3.272248 hours left
# Loaded: 0.000068 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 0.51 %, best = 0.51 %
#  316: 5.014799, 4.143038 avg loss, 0.001000 rate, 13.944637 seconds, 20224 images, 3.265548 hours left
# Loaded: 0.000078 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 0.51 %, best = 0.51 %
#  317: 7.432205, 4.471954 avg loss, 0.001000 rate, 14.719351 seconds, 20288 images, 3.259388 hours left
# Loaded: 0.000044 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 0.51 %, best = 0.51 %
#  318: 3.152988, 4.340058 avg loss, 0.001000 rate, 13.746419 seconds, 20352 images, 3.254720 hours left
# Loaded: 0.000080 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 0.51 %, best = 0.51 %
#  319: 3.442325, 4.250285 avg loss, 0.001000 rate, 13.712234 seconds, 20416 images, 3.248215 hours left
# Loaded: 0.000049 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 0.51 %, best = 0.51 %
#  320: 5.042455, 4.329502 avg loss, 0.001000 rate, 13.902354 seconds, 20480 images, 3.241672 hours left
# Resizing, random_coef = 1.40
#
#  448 x 448
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.000064 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 0.51 %, best = 0.51 %
#  321: 4.290569, 4.325608 avg loss, 0.001000 rate, 15.036229 seconds, 20544 images, 3.235515 hours left
# Loaded: 0.000038 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 0.51 %, best = 0.51 %
#  322: 3.202823, 4.213330 avg loss, 0.001000 rate, 15.206882 seconds, 20608 images, 3.231520 hours left
# Loaded: 0.000053 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 0.51 %, best = 0.51 %
#  323: 3.441785, 4.136175 avg loss, 0.001000 rate, 15.307956 seconds, 20672 images, 3.227845 hours left
# Loaded: 0.000044 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 0.51 %, best = 0.51 %
#  324: 3.465132, 4.069071 avg loss, 0.001000 rate, 15.396308 seconds, 20736 images, 3.224354 hours left
# Loaded: 0.000037 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 0.51 %, best = 0.51 %
#  325: 4.746984, 4.136862 avg loss, 0.001000 rate, 15.594177 seconds, 20800 images, 3.221021 hours left
# Loaded: 0.000068 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 0.51 %, best = 0.51 %
#  326: 5.425949, 4.265771 avg loss, 0.001000 rate, 16.089380 seconds, 20864 images, 3.218050 hours left
# Loaded: 0.000043 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 0.51 %, best = 0.51 %
# ...
#  936: 2.626688, 2.579997 avg loss, 0.000100 rate, 28.082273 seconds, 59904 images, 0.875934 hours left
# Loaded: 0.000075 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  937: 3.115485, 2.633546 avg loss, 0.000100 rate, 28.185329 seconds, 59968 images, 0.872167 hours left
# Loaded: 0.000078 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  938: 3.256501, 2.695841 avg loss, 0.000100 rate, 28.339242 seconds, 60032 images, 0.868378 hours left
# Loaded: 0.000044 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  939: 2.774148, 2.703672 avg loss, 0.000100 rate, 28.278953 seconds, 60096 images, 0.864575 hours left
# Loaded: 0.000048 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  940: 2.480231, 2.681328 avg loss, 0.000100 rate, 28.255267 seconds, 60160 images, 0.860721 hours left
# Resizing, random_coef = 1.40
#
#  608 x 608
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.000068 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  941: 3.545409, 2.767736 avg loss, 0.000100 rate, 27.577760 seconds, 60224 images, 0.856823 hours left
# Loaded: 0.000058 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  942: 4.075830, 2.898545 avg loss, 0.000100 rate, 28.350004 seconds, 60288 images, 0.852775 hours left
# Loaded: 0.000053 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  943: 1.762457, 2.784936 avg loss, 0.000100 rate, 27.721400 seconds, 60352 images, 0.848814 hours left
# Loaded: 0.000047 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  944: 3.205972, 2.827040 avg loss, 0.000100 rate, 28.384515 seconds, 60416 images, 0.844715 hours left
# Loaded: 0.000047 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  945: 2.451161, 2.789452 avg loss, 0.000100 rate, 27.934600 seconds, 60480 images, 0.840684 hours left
# Loaded: 0.000039 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  946: 3.371714, 2.847678 avg loss, 0.000100 rate, 28.392251 seconds, 60544 images, 0.836545 hours left
# Loaded: 0.000035 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  947: 2.660431, 2.828954 avg loss, 0.000100 rate, 27.941075 seconds, 60608 images, 0.832438 hours left
# Loaded: 0.000049 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  948: 2.642736, 2.810332 avg loss, 0.000100 rate, 28.086028 seconds, 60672 images, 0.828227 hours left
# Loaded: 0.000061 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  949: 2.487180, 2.778017 avg loss, 0.000100 rate, 28.212679 seconds, 60736 images, 0.824002 hours left
# Loaded: 0.000049 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  950: 2.649671, 2.765182 avg loss, 0.000100 rate, 28.066981 seconds, 60800 images, 0.819759 hours left
# Resizing, random_coef = 1.40
#
#  608 x 608
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.001542 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  951: 2.910434, 2.779707 avg loss, 0.000100 rate, 27.617356 seconds, 60864 images, 0.815459 hours left
# Loaded: 0.000036 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  952: 3.012764, 2.803013 avg loss, 0.000100 rate, 28.070414 seconds, 60928 images, 0.811064 hours left
# Loaded: 0.000077 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  953: 3.529942, 2.875706 avg loss, 0.000100 rate, 28.352274 seconds, 60992 images, 0.806696 hours left
# Loaded: 0.000077 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  954: 4.832775, 3.071413 avg loss, 0.000100 rate, 28.590825 seconds, 61056 images, 0.802331 hours left
# Loaded: 0.000061 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  955: 2.095901, 2.973861 avg loss, 0.000100 rate, 27.945651 seconds, 61120 images, 0.797960 hours left
# Loaded: 0.000057 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  956: 2.677884, 2.944264 avg loss, 0.000100 rate, 28.064473 seconds, 61184 images, 0.793474 hours left
# Loaded: 0.000073 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  957: 2.298352, 2.879673 avg loss, 0.000100 rate, 27.922938 seconds, 61248 images, 0.788969 hours left
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  958: 2.594109, 2.851116 avg loss, 0.000100 rate, 28.019346 seconds, 61312 images, 0.784415 hours left
# Loaded: 0.000046 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  959: 2.969878, 2.862992 avg loss, 0.000100 rate, 28.304126 seconds, 61376 images, 0.779840 hours left
# Loaded: 0.000046 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  960: 3.506852, 2.927378 avg loss, 0.000100 rate, 28.170836 seconds, 61440 images, 0.775265 hours left
# Resizing, random_coef = 1.40
#
#  608 x 608
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.000059 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  961: 3.231178, 2.957758 avg loss, 0.000100 rate, 27.875801 seconds, 61504 images, 0.770642 hours left
# Loaded: 0.000075 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  962: 2.202443, 2.882227 avg loss, 0.000100 rate, 27.897051 seconds, 61568 images, 0.765956 hours left
# Loaded: 0.000036 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  963: 1.978841, 2.791888 avg loss, 0.000100 rate, 27.827228 seconds, 61632 images, 0.761241 hours left
# Loaded: 0.000047 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  964: 2.771232, 2.789823 avg loss, 0.000100 rate, 28.201476 seconds, 61696 images, 0.756489 hours left
# Loaded: 0.000082 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  965: 2.754558, 2.786296 avg loss, 0.000100 rate, 28.248279 seconds, 61760 images, 0.751744 hours left
# Loaded: 0.000046 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  966: 4.165865, 2.924253 avg loss, 0.000100 rate, 28.628059 seconds, 61824 images, 0.746973 hours left
# Loaded: 0.000059 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  967: 1.809597, 2.812788 avg loss, 0.000100 rate, 27.825471 seconds, 61888 images, 0.742207 hours left
# Loaded: 0.000068 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  968: 2.163199, 2.747829 avg loss, 0.000100 rate, 27.956737 seconds, 61952 images, 0.737335 hours left
# Loaded: 0.000057 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  969: 2.773128, 2.750359 avg loss, 0.000100 rate, 28.353833 seconds, 62016 images, 0.732447 hours left
# Loaded: 0.000113 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  970: 4.003491, 2.875672 avg loss, 0.000100 rate, 28.596046 seconds, 62080 images, 0.727564 hours left
# Resizing, random_coef = 1.40
#
#  608 x 608
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.089982 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  971: 3.129794, 2.901084 avg loss, 0.000100 rate, 27.631563 seconds, 62144 images, 0.722672 hours left
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  972: 2.108669, 2.821842 avg loss, 0.000100 rate, 27.856651 seconds, 62208 images, 0.717678 hours left
# Loaded: 0.000047 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  973: 2.661259, 2.805784 avg loss, 0.000100 rate, 27.956126 seconds, 62272 images, 0.712668 hours left
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  974: 2.170230, 2.742229 avg loss, 0.000100 rate, 27.907146 seconds, 62336 images, 0.707638 hours left
# Loaded: 0.000043 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  975: 2.750773, 2.743083 avg loss, 0.000100 rate, 28.218474 seconds, 62400 images, 0.702577 hours left
# Loaded: 0.000081 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  976: 2.880455, 2.756820 avg loss, 0.000100 rate, 28.054288 seconds, 62464 images, 0.697511 hours left
# Loaded: 0.000042 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  977: 3.259462, 2.807084 avg loss, 0.000100 rate, 28.310033 seconds, 62528 images, 0.692406 hours left
# Loaded: 0.000055 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  978: 2.210473, 2.747423 avg loss, 0.000100 rate, 27.906476 seconds, 62592 images, 0.687291 hours left
# Loaded: 0.000084 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  979: 3.537463, 2.826427 avg loss, 0.000100 rate, 28.381123 seconds, 62656 images, 0.682123 hours left
# Loaded: 0.000042 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  980: 1.934852, 2.737270 avg loss, 0.000100 rate, 27.921431 seconds, 62720 images, 0.676958 hours left
# Resizing, random_coef = 1.40
#
#  608 x 608
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.000051 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  981: 2.951944, 2.758737 avg loss, 0.000100 rate, 27.480010 seconds, 62784 images, 0.671739 hours left
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  982: 2.500313, 2.732895 avg loss, 0.000100 rate, 27.924449 seconds, 62848 images, 0.666472 hours left
# Loaded: 0.000039 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  983: 3.678987, 2.827504 avg loss, 0.000100 rate, 28.273218 seconds, 62912 images, 0.661204 hours left
# Loaded: 0.000043 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  984: 2.189952, 2.763749 avg loss, 0.000100 rate, 28.027185 seconds, 62976 images, 0.655927 hours left
# Loaded: 0.000058 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  985: 3.496323, 2.837006 avg loss, 0.000100 rate, 28.037916 seconds, 63040 images, 0.650613 hours left
# Loaded: 0.000050 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  986: 2.459742, 2.799280 avg loss, 0.000100 rate, 28.158704 seconds, 63104 images, 0.645275 hours left
# Loaded: 0.000076 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  987: 3.426924, 2.862044 avg loss, 0.000100 rate, 28.279017 seconds, 63168 images, 0.639918 hours left
# Loaded: 0.000062 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  988: 2.713033, 2.847143 avg loss, 0.000100 rate, 28.230197 seconds, 63232 images, 0.634540 hours left
# Loaded: 0.000046 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  989: 2.090786, 2.771507 avg loss, 0.000100 rate, 27.856450 seconds, 63296 images, 0.629135 hours left
# Loaded: 0.000050 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  990: 2.657449, 2.760101 avg loss, 0.000100 rate, 28.204169 seconds, 63360 images, 0.623695 hours left
# Resizing, random_coef = 1.40
#
#  608 x 608
#  try to allocate additional workspace_size = 0.04 MB
#  CUDA allocate done!
# Loaded: 0.096601 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  991: 3.874684, 2.871560 avg loss, 0.000100 rate, 27.712072 seconds, 63424 images, 0.618242 hours left
# Loaded: 0.000052 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  992: 2.735485, 2.857952 avg loss, 0.000100 rate, 28.148678 seconds, 63488 images, 0.612754 hours left
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  993: 3.356499, 2.907807 avg loss, 0.000100 rate, 28.019419 seconds, 63552 images, 0.607252 hours left
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  994: 2.366930, 2.853719 avg loss, 0.000100 rate, 28.091716 seconds, 63616 images, 0.601725 hours left
# Loaded: 0.000049 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  995: 3.070698, 2.875417 avg loss, 0.000100 rate, 28.268073 seconds, 63680 images, 0.596176 hours left
# Loaded: 0.000077 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  996: 3.607606, 2.948636 avg loss, 0.000100 rate, 28.537161 seconds, 63744 images, 0.590606 hours left
# Loaded: 0.000043 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  997: 2.478313, 2.901603 avg loss, 0.000100 rate, 28.205553 seconds, 63808 images, 0.585017 hours left
# Loaded: 0.000046 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  998: 3.280326, 2.939476 avg loss, 0.000100 rate, 28.296098 seconds, 63872 images, 0.579402 hours left
# Loaded: 0.000076 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  999: 2.861378, 2.931666 avg loss, 0.000100 rate, 28.279049 seconds, 63936 images, 0.573765 hours left
# Loaded: 0.000066 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 35.41 %, best = 35.41 %
#  1000: 3.925566, 3.031056 avg loss, 0.000100 rate, 28.558601 seconds, 64000 images, 0.568106 hours left
# Resizing to initial size: 416 x 416  try to allocate additional workspace_size = 12.46 MB
#  CUDA allocate done!
#
#  calculation mAP (mean average precision)...
#
#  detections_count = 17911, unique_truth_count = 2147
# class_id = 0, name = Mask, ap = 61.73%   	 (TP = 203, FP = 92)
# class_id = 1, name = No_mask, ap = 12.22%   	 (TP = 168, FP = 240)
#
#  for conf_thresh = 0.25, precision = 0.53, recall = 0.17, F1-score = 0.26
#  for conf_thresh = 0.25, TP = 371, FP = 332, FN = 1776, average IoU = 37.37 %
#
#  IoU threshold = 50 %, used Area-Under-Curve for each unique Recall
#  mean average precision (mAP@0.50) = 0.369789, or 36.98 %
#
# Set -points flag:
#  `-points 101` for MS COCO
#  `-points 11` for PascalVOC 2007 (uncomment `difficult` in voc.data)
#  `-points 0` (AUC) for ImageNet, PascalVOC 2010-2012, your custom dataset
#
#  mean_average_precision (mAP@0.5) = 0.369789
# New best mAP!

# %% [markdown]
# # <font style="color:blue">Notes on Training</font>
# From the above training process we can make the following observations:
# 1. The images are resized after every 10 iterations
# It takes around 11 seconds per iteration which consists of 64 images for an image size of 576.
# 1. We can see that the training started very slowly in the first few iterations and then very gradually, the loss started reducing.
# 1. As we can see the learning rate increases gradually from 0 to 0.001 by the 100th batch ( burn_in was set to 100 ). It would stay there till the 1500th batch when it would again change to 0.0001.
# 1. mAP is calculated for every 100 iterations. It reaches >80% after 200 iterations.
# 1. You can check out the training graph for mAP v/s iterations which is saved in the file **chart.png**

# %% [markdown]
# ## <font style="color:blue">Download our trained weights</font>
# You can download our weights which we trained using the link below.

# %%
# !wget "https://www.dropbox.com/s/qeno1qc1habd03d/yolov3-ambulance_last.weights?dl=1" -O yolov3-ambulance.weights
# Out:
# --2020-07-07 03:51:54--  https://www.dropbox.com/s/qeno1qc1habd03d/yolov3-ambulance_last.weights?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.1.1, 2620:100:6016:1::a27d:101
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.1.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/qeno1qc1habd03d/yolov3-ambulance_last.weights [following]
# --2020-07-07 03:51:55--  https://www.dropbox.com/s/dl/qeno1qc1habd03d/yolov3-ambulance_last.weights
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc349c71947a6fe37d2224bb75f2.dl.dropboxusercontent.com/cd/0/get/A7Dq_STtBh_YX3PEC4Yd5dRXfOF9UsocDiY3uWdtCQ58rO8hY0hAfSL-mwPKKfe-s_ap3saixkKembzc7hfSF6ONPvYy0DMnQA5rsTc_8-FFQtSpV0cScT3DUzz2DUho19E/file?dl=1# [following]
# --2020-07-07 03:51:55--  https://uc349c71947a6fe37d2224bb75f2.dl.dropboxusercontent.com/cd/0/get/A7Dq_STtBh_YX3PEC4Yd5dRXfOF9UsocDiY3uWdtCQ58rO8hY0hAfSL-mwPKKfe-s_ap3saixkKembzc7hfSF6ONPvYy0DMnQA5rsTc_8-FFQtSpV0cScT3DUzz2DUho19E/file?dl=1
# Resolving uc349c71947a6fe37d2224bb75f2.dl.dropboxusercontent.com (uc349c71947a6fe37d2224bb75f2.dl.dropboxusercontent.com)... 162.125.1.15, 2620:100:6016:15::a27d:10f
# Connecting to uc349c71947a6fe37d2224bb75f2.dl.dropboxusercontent.com (uc349c71947a6fe37d2224bb75f2.dl.dropboxusercontent.com)|162.125.1.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 246239852 (235M) [application/binary]
# Saving to: ‘yolov3-ambulance.weights’
#
# yolov3-ambulance.we 100%[===================>] 234.83M  36.4MB/s    in 6.3s
#
# 2020-07-07 03:52:02 (37.1 MB/s) - ‘yolov3-ambulance.weights’ saved [246239852/246239852]

# %% [markdown]
# # <font style="color:blue">9. Perform Inference</font>
# Finally, let us use the trained model to perform inference on some unseen images from the internet.

# %% [markdown]
# We have written a simple utility function which can be used to display the input and output similar to what we did in the previous section
#
# We are already familiar with the inference code which we saw in the previous section.

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

def display_output(imagePath):
    src = cv2.imread(imagePath,1)
    output = cv2.imread("predictions.jpg")

    plt.figure(figsize=[20,8])
    plt.subplot(121)
    plt.imshow(src[:,:,::-1])
    plt.title("Original Image")
    plt.subplot(122)
    plt.imshow(output[:,:,::-1])
    plt.title("Predictions")
    plt.show()

# %% [markdown]
# ### <font style="color:green">9.1. Test Image 1</font>

# %%
# !wget "https://www.dropbox.com/s/aad0pw7pf4ygs4b/traffic_1.jpg?dl=1" -O test1.jpg
# Out:
# --2020-07-07 03:32:13--  https://www.dropbox.com/s/aad0pw7pf4ygs4b/traffic_1.jpg?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.1.1, 2620:100:6016:1::a27d:101
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.1.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/aad0pw7pf4ygs4b/traffic_1.jpg [following]
# --2020-07-07 03:32:13--  https://www.dropbox.com/s/dl/aad0pw7pf4ygs4b/traffic_1.jpg
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc8252dd6bba9737a290f4ab3c1a.dl.dropboxusercontent.com/cd/0/get/A7DN7aRI-ssAX9kYrgS8BEss0lrTNK6fDqVEeX3L-98m7Dxu6BZUvrjNKUwSQ6BSHvsx9BYgsev2CUWCsmB4qSuHKD0TV0PJeod9aCp2C9kE4NHWDYKClVYCAL1_FQYVGAw/file?dl=1# [following]
# --2020-07-07 03:32:13--  https://uc8252dd6bba9737a290f4ab3c1a.dl.dropboxusercontent.com/cd/0/get/A7DN7aRI-ssAX9kYrgS8BEss0lrTNK6fDqVEeX3L-98m7Dxu6BZUvrjNKUwSQ6BSHvsx9BYgsev2CUWCsmB4qSuHKD0TV0PJeod9aCp2C9kE4NHWDYKClVYCAL1_FQYVGAw/file?dl=1
# Resolving uc8252dd6bba9737a290f4ab3c1a.dl.dropboxusercontent.com (uc8252dd6bba9737a290f4ab3c1a.dl.dropboxusercontent.com)... 162.125.1.15, 2620:100:6016:15::a27d:10f
# Connecting to uc8252dd6bba9737a290f4ab3c1a.dl.dropboxusercontent.com (uc8252dd6bba9737a290f4ab3c1a.dl.dropboxusercontent.com)|162.125.1.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 179153 (175K) [application/binary]
# Saving to: ‘test1.jpg’
#
# test1.jpg           100%[===================>] 174.95K  --.-KB/s    in 0.03s
#
# 2020-07-07 03:32:13 (6.59 MB/s) - ‘test1.jpg’ saved [179153/179153]

# %%
# !pwd
#Testing Ambulance
#!./darknet detector test yolov3-ambulance-setup.data yolov3-ambulance-test.cfg backup/yolov3-ambulance-train_best.weights test1.jpg -thresh .6 2> /dev/null
#!./darknet detector test yolov3-ambulance-setup.data yolov3-ambulance-test.cfg backup/yolov3-ambulance-train_last.weights test1.jpg -thresh .6 2> /dev/null
#!./darknet detector test yolov3-ambulance-setup.data yolov3-ambulance-test.cfg yolov3-ambulance.weights test1.jpg -thresh 0.5
#!./darknet detect cfg/yolov3.cfg yolov3.weights traffic.jpg -thresh 0.5

#Testing MASK
# !./darknet detector test yolov3-mask-setup.data yolov3-mask-test.cfg backup/yolov3-mask-train_last.weights test-image1.jpg -thresh .4 2> /dev/null

display_output("test-image1.jpg")
# Out:
# /content/drive/My Drive/darknet
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#
#  seen 64, trained: 64 K-images (1 Kilo-batches_64)
# test-image1.jpg: Predicted in 107.809000 milli-seconds.
# Mask: 82%

# %% [markdown]
# We can see that the Ambulance from our previous example is now getting detected.
#
# Let us see some more examples!

# %% [markdown]
# ### <font style="color:green">9.2. Test Image 2</font>

# %%
# !wget https://d1muy2ct2wkbaz.cloudfront.net/video/259000/258637/580x325/0.jpg -O test2.jpg
# Out:
# --2020-07-07 04:25:11--  https://d1muy2ct2wkbaz.cloudfront.net/video/259000/258637/580x325/0.jpg
# Resolving d1muy2ct2wkbaz.cloudfront.net (d1muy2ct2wkbaz.cloudfront.net)... 13.224.2.70, 13.224.2.6, 13.224.2.136, ...
# Connecting to d1muy2ct2wkbaz.cloudfront.net (d1muy2ct2wkbaz.cloudfront.net)|13.224.2.70|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 31241 (31K) [image/jpeg]
# Saving to: ‘test2.jpg’
#
# test2.jpg           100%[===================>]  30.51K  --.-KB/s    in 0.1s
#
# 2020-07-07 04:25:11 (268 KB/s) - ‘test2.jpg’ saved [31241/31241]

# %%
# Testing Ambulance
#!./darknet detector test yolov3-ambulance-setup.data yolov3-ambulance-test.cfg backup/yolov3-ambulance-train_best.weights test2.jpg -thresh .6  2> /dev/null
#!./darknet detector test yolov3-ambulance-setup.data yolov3-ambulance-test.cfg backup/yolov3-ambulance-train_last.weights test2.jpg -thresh .6  2> /dev/null
#!./darknet detector test yolov3-ambulance-setup.data yolov3-ambulance-test.cfg yolov3-ambulance.weights test2.jpg -thresh .6  2> /dev/null

#display_output("test2.jpg")

#Testing MASK
# !./darknet detector test yolov3-mask-setup.data yolov3-mask-test.cfg backup/yolov3-mask-train_best.weights test-image2.jpg -thresh .4 2> /dev/null

display_output("test-image2.jpg")
# Out:
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#
#  seen 64, trained: 64 K-images (1 Kilo-batches_64)
# test-image2.jpg: Predicted in 104.320000 milli-seconds.
# No_mask: 57%
# No_mask: 58%

# %% [markdown]
# ### <font style="color:green">9.3. Test Image 3</font>

# %%
# !wget https://www.straitstimes.com/sites/default/files/styles/article_pictrure_780x520_/public/articles/2020/01/18/ST_20200118_AMBULANCE_5390028.jpg -O test3.jpg
# Out:
# --2020-07-07 04:30:52--  https://www.straitstimes.com/sites/default/files/styles/article_pictrure_780x520_/public/articles/2020/01/18/ST_20200118_AMBULANCE_5390028.jpg
# Resolving www.straitstimes.com (www.straitstimes.com)... 152.195.55.6
# Connecting to www.straitstimes.com (www.straitstimes.com)|152.195.55.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 102238 (100K) [image/jpeg]
# Saving to: ‘test3.jpg’
#
# test3.jpg           100%[===================>]  99.84K  --.-KB/s    in 0.009s
#
# 2020-07-07 04:30:52 (10.3 MB/s) - ‘test3.jpg’ saved [102238/102238]

# %%
# Testing Ambulance
#!./darknet detector test yolov3-ambulance-setup.data yolov3-ambulance-test.cfg backup/yolov3-ambulance-train_best.weights test3.jpg -thresh .6  2> /dev/null
#display_output("test3.jpg")

#Testing MASK
# !./darknet detector test yolov3-mask-setup.data yolov3-mask-test.cfg backup/yolov3-mask-train_final.weights test-image3.jpg -thresh .4 2> /dev/null

display_output("test-image3.jpg")
# Out:
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#
#  seen 64, trained: 64 K-images (1 Kilo-batches_64)
# test-image3.jpg: Predicted in 103.806000 milli-seconds.
# Mask: 71%
# Mask: 91%
# Mask: 93%
# Mask: 63%
# Mask: 71%
# Mask: 91%
# Mask: 57%
# Mask: 99%
# Mask: 99%
# Mask: 99%
# Mask: 75%

# %% [markdown]
# ### <font style="color:green">9.4. Test Image 4</font>

# %%
# !wget https://www.zhl.org.in/blog/wp-content/uploads/2019/09/Ambulance-Service.jpg -O test4.jpg
# Out:
# --2020-07-07 04:32:03--  https://www.zhl.org.in/blog/wp-content/uploads/2019/09/Ambulance-Service.jpg
# Resolving www.zhl.org.in (www.zhl.org.in)... 13.232.106.231
# Connecting to www.zhl.org.in (www.zhl.org.in)|13.232.106.231|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 294313 (287K) [image/jpeg]
# Saving to: ‘test4.jpg’
#
# test4.jpg           100%[===================>] 287.42K   307KB/s    in 0.9s
#
# 2020-07-07 04:32:05 (307 KB/s) - ‘test4.jpg’ saved [294313/294313]

# %%
# Testing Ambulance
#!./darknet detector test yolov3-ambulance-setup.data yolov3-ambulance-test.cfg backup/yolov3-ambulance-train_best.weights test4.jpg -thresh .6 2> /dev/null
#!./darknet detector test yolov3-ambulance-setup.data yolov3-ambulance-test.cfg backup/yolov3-ambulance-train_last.weights test4.jpg -thresh .6 2> /dev/null
#!./darknet detector test yolov3-ambulance-setup.data yolov3-ambulance-test.cfg yolov3-ambulance.weights test4.jpg -thresh .6 2> /dev/null

#display_output("test4.jpg")

#Testing MASK
# !./darknet detector test yolov3-mask-setup.data yolov3-mask-test.cfg backup/yolov3-mask-train_final.weights test-image4.jpg -thresh .4 2> /dev/null

display_output("test-image4.jpg")
# Out:
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#
#  seen 64, trained: 64 K-images (1 Kilo-batches_64)
# test-image4.jpg: Predicted in 105.661000 milli-seconds.
# No_mask: 46%
# Mask: 99%
# Mask: 99%

# %% [markdown]
# In the last example, we can see that there is a false positive - It classifies a Car as Ambulance. This is bound to happen since many ambulances are of the shape of a car.

# %%
#Testing MASK
# !./darknet detector demo yolov3-mask-setup.data yolov3-mask-test.cfg backup/yolov3-mask-train_final.weights test-video1.mp4 -thresh .4 -out_filename out-vid1.avi -dont_show
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
# Demo
#  0 : compute_capability = 370, cudnn_half = 0, GPU: Tesla K80
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5,  wt = 0, wn = 0, outputs: 104 x 104 x 128 0.001 BF
#    9 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#   10 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#   11 Shortcut Layer: 8,  wt = 0, wn = 0, outputs: 104 x 104 x 128 0.001 BF
#   12 conv    256       3 x 3/ 2    104 x 104 x 128 ->   52 x  52 x 256 1.595 BF
#   13 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   14 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   15 Shortcut Layer: 12,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   16 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   17 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   18 Shortcut Layer: 15,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   19 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   20 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   21 Shortcut Layer: 18,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   22 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   23 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   24 Shortcut Layer: 21,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   25 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   26 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   27 Shortcut Layer: 24,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   28 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   29 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   30 Shortcut Layer: 27,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   31 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   32 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   33 Shortcut Layer: 30,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   34 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   35 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   36 Shortcut Layer: 33,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   37 conv    512       3 x 3/ 2     52 x  52 x 256 ->   26 x  26 x 512 1.595 BF
#   38 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   39 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   40 Shortcut Layer: 37,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   41 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   42 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   43 Shortcut Layer: 40,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   44 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   45 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   46 Shortcut Layer: 43,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   47 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   48 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   49 Shortcut Layer: 46,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   50 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   51 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   52 Shortcut Layer: 49,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   53 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   54 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   55 Shortcut Layer: 52,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   56 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   57 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   58 Shortcut Layer: 55,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   59 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   60 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   61 Shortcut Layer: 58,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   62 conv   1024       3 x 3/ 2     26 x  26 x 512 ->   13 x  13 x1024 1.595 BF
#   63 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   64 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   65 Shortcut Layer: 62,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   66 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   67 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   68 Shortcut Layer: 65,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   69 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   70 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   71 Shortcut Layer: 68,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   72 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   73 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   74 Shortcut Layer: 71,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   75 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   76 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   77 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   78 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   79 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   80 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   81 conv     21       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x  21 0.007 BF
#   82 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, cls_norm: 1.00, scale_x_y: 1.00
#   83 route  79 		                           ->   13 x  13 x 512
#   84 conv    256       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 256 0.044 BF
#   85 upsample                 2x    13 x  13 x 256 ->   26 x  26 x 256
#   86 route  85 61 	                           ->   26 x  26 x 768
#   87 conv    256       1 x 1/ 1     26 x  26 x 768 ->   26 x  26 x 256 0.266 BF
#   88 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   89 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   90 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   91 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   92 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   93 conv     21       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x  21 0.015 BF
#   94 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, cls_norm: 1.00, scale_x_y: 1.00
#   95 route  91 		                           ->   26 x  26 x 256
#   96 conv    128       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 128 0.044 BF
#   97 upsample                 4x    26 x  26 x 128 ->  104 x 104 x 128
#   98 route  97 11 	                           ->  104 x 104 x 256
#   99 conv    128       1 x 1/ 1    104 x 104 x 256 ->  104 x 104 x 128 0.709 BF
#  100 conv    256       3 x 3/ 1    104 x 104 x 128 ->  104 x 104 x 256 6.380 BF
#  101 conv    128       1 x 1/ 1    104 x 104 x 256 ->  104 x 104 x 128 0.709 BF
#  102 conv    256       3 x 3/ 1    104 x 104 x 128 ->  104 x 104 x 256 6.380 BF
#  103 conv    128       1 x 1/ 1    104 x 104 x 256 ->  104 x 104 x 128 0.709 BF
#  104 conv    256       3 x 3/ 1    104 x 104 x 128 ->  104 x 104 x 256 6.380 BF
#  105 conv     21       1 x 1/ 1    104 x 104 x 256 ->  104 x 104 x  21 0.116 BF
#  106 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, cls_norm: 1.00, scale_x_y: 1.00
# Total BFLOPS 81.259
# avg_outputs = 633320
#  Allocate additional workspace_size = 12.46 MB
# Loading weights from backup/yolov3-mask-train_final.weights...
#  seen 64, trained: 64 K-images (1 Kilo-batches_64)
# Done! Loaded 107 layers from weights-file
# video file: test-video1.mp4
# Video stream: 1600 x 842
# Objects:
#
#
# FPS:0.0 	 AVG_FPS:0.0
# Objects:
#
# No_mask: 87%
# No_mask: 77%
#
# FPS:1.0 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 87%
# No_mask: 73%
#
# FPS:1.8 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 86%
# No_mask: 70%
#
# FPS:2.6 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 85%
# No_mask: 67%
#
# FPS:3.3 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 85%
# No_mask: 64%
#
# FPS:4.0 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 85%
# No_mask: 64%
#
# FPS:4.6 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 83%
# No_mask: 62%
#
# FPS:5.1 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 84%
# No_mask: 62%
#
# FPS:5.6 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 83%
# No_mask: 59%
#
# FPS:6.2 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 81%
# No_mask: 62%
#
# FPS:6.7 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 81%
# No_mask: 62%
#
# FPS:7.1 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 81%
# No_mask: 61%
#
# FPS:7.6 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 81%
# No_mask: 63%
#
# FPS:8.0 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 81%
# No_mask: 63%
#
# FPS:8.3 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 80%
# No_mask: 62%
#
# FPS:8.6 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 81%
# No_mask: 63%
#
# FPS:8.9 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 82%
# No_mask: 65%
#
# FPS:9.0 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 82%
# No_mask: 65%
#
# FPS:9.2 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 82%
# No_mask: 67%
#
# FPS:9.3 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 84%
# No_mask: 72%
#
# FPS:9.5 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 84%
# No_mask: 71%
#
# FPS:8.6 	 AVG_FPS:6.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 85%
# No_mask: 70%
#
# FPS:8.9 	 AVG_FPS:6.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 88%
# No_mask: 66%
#
# FPS:9.1 	 AVG_FPS:6.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 89%
# No_mask: 66%
#
# FPS:9.4 	 AVG_FPS:6.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 91%
# No_mask: 51%
#
# FPS:9.4 	 AVG_FPS:6.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 92%
# No_mask: 54%
#
# FPS:9.7 	 AVG_FPS:6.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 89%
# No_mask: 65%
#
# FPS:9.9 	 AVG_FPS:6.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 87%
# No_mask: 62%
#
# FPS:10.1 	 AVG_FPS:6.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 85%
# No_mask: 55%
#
# FPS:10.1 	 AVG_FPS:6.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 86%
# No_mask: 55%
#
# FPS:10.3 	 AVG_FPS:6.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 84%
# No_mask: 47%
#
# FPS:10.3 	 AVG_FPS:6.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 85%
# No_mask: 53%
#
# FPS:10.4 	 AVG_FPS:6.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 79%
# No_mask: 63%
# Mask: 44%
#
# FPS:10.4 	 AVG_FPS:6.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 73%
# No_mask: 69%
# Mask: 90%
#
# FPS:10.5 	 AVG_FPS:6.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 72%
# No_mask: 53%
# Mask: 95%
# Mask: 70%
#
# FPS:10.6 	 AVG_FPS:6.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 72%
# No_mask: 52%
# Mask: 95%
# Mask: 69%
#
# FPS:10.6 	 AVG_FPS:6.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 75%
# No_mask: 42%
# Mask: 98%
# Mask: 74%
#
# FPS:10.6 	 AVG_FPS:6.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 78%
# No_mask: 50%
# Mask: 98%
# Mask: 84%
#
# FPS:10.8 	 AVG_FPS:6.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 75%
# No_mask: 43%
# Mask: 99%
# Mask: 75%
#
# FPS:10.9 	 AVG_FPS:6.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 74%
# No_mask: 56%
# Mask: 99%
# Mask: 76%
#
# FPS:10.9 	 AVG_FPS:6.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 68%
# No_mask: 63%
# Mask: 99%
# Mask: 81%
#
# FPS:10.9 	 AVG_FPS:6.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 68%
# No_mask: 63%
# Mask: 99%
# Mask: 81%
#
# FPS:11.0 	 AVG_FPS:6.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 68%
# No_mask: 60%
# Mask: 98%
# Mask: 63%
#
# FPS:10.9 	 AVG_FPS:6.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 50%
# No_mask: 40%
# Mask: 99%
# Mask: 63%
#
# FPS:11.0 	 AVG_FPS:6.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 84%
# Mask: 47%
#
# FPS:11.0 	 AVG_FPS:6.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 97%
# Mask: 65%
#
# FPS:11.0 	 AVG_FPS:6.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 98%
# Mask: 47%
# Mask: 46%
#
# FPS:10.9 	 AVG_FPS:6.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 98%
# Mask: 48%
# Mask: 46%
#
# FPS:10.8 	 AVG_FPS:6.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 97%
# Mask: 63%
#
# FPS:10.7 	 AVG_FPS:6.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 96%
# Mask: 79%
#
# FPS:10.8 	 AVG_FPS:6.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 93%
# Mask: 71%
#
# FPS:10.8 	 AVG_FPS:6.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 95%
# Mask: 70%
#
# FPS:10.9 	 AVG_FPS:6.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 95%
# Mask: 90%
#
# FPS:10.9 	 AVG_FPS:6.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 95%
# Mask: 90%
#
# FPS:11.0 	 AVG_FPS:6.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 96%
# Mask: 87%
#
# FPS:11.0 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 97%
# Mask: 88%
#
# FPS:11.0 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 97%
# Mask: 87%
#
# FPS:11.0 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 97%
# Mask: 91%
#
# FPS:11.0 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 92%
#
# FPS:11.0 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 92%
#
# FPS:11.0 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 97%
#
# FPS:10.9 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 96%
#
# FPS:10.8 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 97%
#
# FPS:10.8 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 96%
#
# FPS:10.9 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 92%
#
# FPS:10.9 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 92%
#
# FPS:11.1 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 91%
# Mask: 41%
#
# FPS:11.1 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 95%
#
# FPS:11.1 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 93%
#
# FPS:11.1 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 85%
#
# FPS:11.1 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 83%
#
# FPS:10.9 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 83%
#
# FPS:11.0 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 87%
#
# FPS:11.0 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 88%
#
# FPS:11.0 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 91%
#
# FPS:10.9 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 92%
#
# FPS:11.0 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 92%
#
# FPS:11.1 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 92%
#
# FPS:11.2 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 92%
#
# FPS:11.1 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 92%
#
# FPS:11.1 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 99%
# Mask: 95%
#
# FPS:11.1 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 99%
# Mask: 92%
#
# FPS:11.2 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 94%
# Mask: 40%
#
# FPS:11.3 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 94%
#
# FPS:11.3 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 93%
#
# FPS:11.3 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 88%
#
# FPS:11.4 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 85%
#
# FPS:11.4 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 87%
#
# FPS:11.4 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 96%
# Mask: 78%
#
# FPS:11.3 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 96%
# Mask: 78%
#
# FPS:11.4 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 96%
# Mask: 87%
#
# FPS:11.3 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 94%
# Mask: 91%
# Mask: 51%
#
# FPS:11.4 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 92%
# Mask: 90%
# Mask: 52%
#
# FPS:11.5 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 94%
# Mask: 92%
# Mask: 48%
#
# FPS:11.5 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 94%
# Mask: 90%
#
# FPS:11.5 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 94%
# Mask: 91%
#
# FPS:11.5 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 93%
# Mask: 92%
#
# FPS:11.4 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 95%
# Mask: 93%
#
# FPS:11.4 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 95%
# Mask: 93%
#
# FPS:11.2 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 95%
# Mask: 94%
#
# FPS:11.1 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 96%
# Mask: 95%
# Mask: 41%
#
# FPS:11.1 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 96%
# Mask: 95%
# Mask: 40%
#
# FPS:11.2 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 96%
# Mask: 95%
# Mask: 49%
#
# FPS:11.1 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 96%
# Mask: 95%
# Mask: 54%
#
# FPS:11.1 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 95%
# Mask: 94%
# Mask: 68%
#
# FPS:11.1 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 97%
# Mask: 93%
# Mask: 86%
#
# FPS:11.1 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 96%
# Mask: 90%
#
# FPS:11.0 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 96%
# Mask: 89%
#
# FPS:11.0 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 97%
# Mask: 93%
#
# FPS:11.0 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 97%
# Mask: 95%
#
# FPS:10.9 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 97%
# Mask: 96%
#
# FPS:10.8 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 97%
# Mask: 96%
#
# FPS:10.9 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 96%
# Mask: 95%
#
# FPS:10.9 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 96%
# Mask: 95%
#
# FPS:10.9 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 96%
# Mask: 96%
#
# FPS:10.9 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 97%
# Mask: 96%
#
# FPS:11.0 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 97%
# Mask: 96%
#
# FPS:11.0 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 97%
# Mask: 94%
#
# FPS:10.9 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 97%
# Mask: 88%
#
# FPS:10.9 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 97%
# Mask: 88%
#
# FPS:10.9 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 96%
# Mask: 89%
#
# FPS:10.9 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 95%
# Mask: 88%
#
# FPS:10.9 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 96%
# Mask: 87%
#
# FPS:10.9 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 96%
# Mask: 84%
#
# FPS:10.9 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 95%
# Mask: 87%
#
# FPS:10.9 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 95%
# Mask: 87%
#
# FPS:11.0 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 100%
# Mask: 96%
# Mask: 88%
#
# FPS:10.9 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 100%
# Mask: 93%
# Mask: 90%
#
# FPS:11.0 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 100%
# Mask: 90%
# Mask: 85%
#
# FPS:11.0 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 100%
# Mask: 91%
# Mask: 85%
#
# FPS:11.0 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 100%
# Mask: 91%
# Mask: 80%
#
# FPS:11.0 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 100%
# Mask: 91%
# Mask: 80%
#
# FPS:11.0 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 100%
# Mask: 91%
# Mask: 69%
#
# FPS:11.1 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 100%
# Mask: 91%
# Mask: 63%
#
# FPS:11.2 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 90%
# Mask: 55%
#
# FPS:11.1 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 100%
# Mask: 91%
# Mask: 43%
#
# FPS:11.1 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 91%
# Mask: 61%
#
# FPS:11.1 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 91%
# Mask: 61%
#
# FPS:11.1 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 92%
# Mask: 62%
#
# FPS:11.1 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 90%
# Mask: 57%
#
# FPS:11.1 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 91%
#
# FPS:11.1 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 99%
# Mask: 91%
#
# FPS:11.2 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 99%
# Mask: 89%
# Mask: 52%
#
# FPS:11.1 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 99%
# Mask: 89%
# Mask: 53%
#
# FPS:11.1 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 99%
# Mask: 90%
# Mask: 64%
#
# FPS:11.1 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 98%
# Mask: 91%
# Mask: 53%
#
# FPS:11.2 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 97%
# Mask: 92%
# Mask: 48%
#
# FPS:11.3 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 97%
# Mask: 94%
# Mask: 48%
#
# FPS:11.3 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 97%
# Mask: 96%
# Mask: 43%
#
# FPS:11.2 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 97%
# Mask: 96%
# Mask: 43%
#
# FPS:11.3 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 96%
# Mask: 44%
#
# FPS:11.1 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 95%
# Mask: 41%
#
# FPS:11.1 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 95%
# Mask: 43%
#
# FPS:11.1 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 95%
# Mask: 41%
#
# FPS:11.2 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 95%
#
# FPS:11.2 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 95%
#
# FPS:11.3 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 95%
#
# FPS:11.2 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 95%
# Mask: 44%
#
# FPS:11.2 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 96%
# Mask: 48%
#
# FPS:11.2 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 96%
# Mask: 86%
# Mask: 51%
#
# FPS:11.2 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 48%
# Mask: 100%
# Mask: 96%
# Mask: 51%
# Mask: 45%
#
# FPS:11.2 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 47%
# Mask: 100%
# Mask: 96%
# Mask: 52%
# Mask: 45%
#
# FPS:11.2 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 70%
# Mask: 100%
# Mask: 96%
# Mask: 41%
#
# FPS:11.2 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 71%
# Mask: 100%
# Mask: 96%
# Mask: 41%
#
# FPS:11.2 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 79%
# Mask: 100%
# Mask: 96%
#
# FPS:11.2 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 83%
# Mask: 100%
# Mask: 97%
#
# FPS:11.3 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 84%
# Mask: 100%
# Mask: 96%
#
# FPS:11.1 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 84%
# Mask: 100%
# Mask: 96%
#
# FPS:11.2 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 86%
# Mask: 100%
# Mask: 96%
#
# FPS:11.2 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 83%
# Mask: 100%
# Mask: 96%
#
# FPS:11.2 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 74%
# Mask: 100%
# Mask: 97%
#
# FPS:11.2 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 81%
# Mask: 100%
# Mask: 97%
#
# FPS:11.1 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 75%
# Mask: 100%
# Mask: 97%
#
# FPS:11.1 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 75%
# Mask: 100%
# Mask: 97%
#
# FPS:11.0 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 78%
# Mask: 100%
# Mask: 97%
#
# FPS:11.0 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 65%
# Mask: 100%
# Mask: 96%
#
# FPS:11.0 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 53%
# Mask: 100%
# Mask: 96%
#
# FPS:10.9 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 62%
# Mask: 100%
# Mask: 97%
#
# FPS:10.9 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 47%
# Mask: 100%
# Mask: 95%
#
# FPS:10.8 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 47%
# Mask: 100%
# Mask: 95%
#
# FPS:10.8 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 65%
# Mask: 100%
# Mask: 94%
# Mask: 41%
#
# FPS:10.8 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 55%
# Mask: 100%
# Mask: 93%
#
# FPS:10.7 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 56%
# Mask: 100%
# Mask: 93%
#
# FPS:10.8 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 55%
# Mask: 100%
# Mask: 91%
#
# FPS:10.9 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 59%
# Mask: 100%
# Mask: 90%
#
# FPS:10.8 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 59%
# Mask: 100%
# Mask: 91%
#
# FPS:10.8 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 90%
#
# FPS:10.8 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 91%
#
# FPS:10.8 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 40%
# Mask: 100%
# Mask: 92%
#
# FPS:10.8 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 92%
#
# FPS:10.8 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 91%
#
# FPS:10.9 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 91%
#
# FPS:10.8 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 92%
#
# FPS:10.8 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 91%
#
# FPS:10.8 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 90%
# Mask: 42%
#
# FPS:10.8 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 89%
# Mask: 43%
#
# FPS:10.8 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 88%
#
# FPS:10.9 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 88%
# Mask: 40%
#
# FPS:10.9 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 84%
# Mask: 41%
#
# FPS:11.0 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 83%
# Mask: 44%
#
# FPS:10.9 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 82%
# Mask: 47%
#
# FPS:11.0 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 85%
# Mask: 48%
#
# FPS:11.0 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 86%
# Mask: 51%
#
# FPS:11.0 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 86%
# Mask: 51%
#
# FPS:11.0 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 86%
# Mask: 56%
#
# FPS:11.0 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 85%
# Mask: 57%
#
# FPS:11.0 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 84%
# Mask: 58%
#
# FPS:11.0 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 84%
# Mask: 57%
#
# FPS:11.0 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 84%
# Mask: 57%
#
# FPS:11.1 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 84%
# Mask: 57%
#
# FPS:11.0 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 84%
# Mask: 58%
#
# FPS:11.1 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 84%
# Mask: 58%
#
# FPS:11.1 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 84%
# Mask: 56%
#
# FPS:11.1 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 86%
# Mask: 56%
#
# FPS:11.0 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 84%
# Mask: 55%
#
# FPS:11.1 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 84%
# Mask: 55%
#
# FPS:10.8 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 81%
# Mask: 55%
#
# FPS:10.9 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 77%
# Mask: 51%
#
# FPS:11.0 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 75%
# Mask: 50%
#
# FPS:11.1 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 74%
# Mask: 51%
#
# FPS:11.1 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 79%
# Mask: 52%
#
# FPS:11.1 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 79%
# Mask: 51%
#
# FPS:11.0 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 81%
# Mask: 50%
#
# FPS:11.1 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 82%
# Mask: 48%
#
# FPS:11.0 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 82%
# Mask: 46%
#
# FPS:11.1 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 83%
#
# FPS:11.0 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 83%
# Mask: 43%
#
# FPS:11.1 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 83%
# Mask: 43%
#
# FPS:11.1 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 84%
# Mask: 43%
#
# FPS:11.2 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 84%
# Mask: 43%
#
# FPS:11.1 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 84%
# Mask: 44%
#
# FPS:11.2 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 84%
# Mask: 42%
#
# FPS:11.1 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 86%
# Mask: 42%
#
# FPS:11.0 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 86%
# Mask: 42%
#
# FPS:10.9 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 86%
# Mask: 43%
#
# FPS:10.8 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 89%
# Mask: 46%
#
# FPS:10.8 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 89%
# Mask: 54%
#
# FPS:10.8 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 89%
# Mask: 56%
#
# FPS:10.8 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 87%
# Mask: 59%
#
# FPS:10.8 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 88%
# Mask: 58%
#
# FPS:10.8 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 84%
# Mask: 59%
#
# FPS:10.8 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 85%
# Mask: 55%
#
# FPS:10.8 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 84%
# Mask: 50%
#
# FPS:10.8 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 83%
# Mask: 46%
#
# FPS:10.8 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 83%
# Mask: 45%
#
# FPS:10.7 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 84%
# Mask: 44%
#
# FPS:10.7 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 84%
# Mask: 46%
#
# FPS:10.7 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 83%
# Mask: 45%
#
# FPS:10.7 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 82%
# Mask: 43%
#
# FPS:10.7 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 81%
# Mask: 43%
#
# FPS:10.7 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 84%
# Mask: 43%
#
# FPS:10.7 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 85%
# Mask: 42%
#
# FPS:10.7 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 85%
# Mask: 44%
#
# FPS:10.7 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 85%
# Mask: 48%
#
# FPS:10.6 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 83%
# Mask: 46%
#
# FPS:10.6 	 AVG_FPS:10.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 83%
# Mask: 47%
#
# FPS:10.6 	 AVG_FPS:10.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 85%
# Mask: 46%
#
# FPS:10.6 	 AVG_FPS:10.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 85%
# Mask: 45%
#
# FPS:10.6 	 AVG_FPS:10.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 84%
# Mask: 46%
#
# FPS:10.6 	 AVG_FPS:10.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 86%
# Mask: 44%
#
# FPS:10.5 	 AVG_FPS:10.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 88%
# Mask: 50%
#
# FPS:10.5 	 AVG_FPS:10.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 42%
# Mask: 100%
# Mask: 85%
# Mask: 55%
#
# FPS:10.6 	 AVG_FPS:10.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 84%
# Mask: 55%
#
# FPS:10.6 	 AVG_FPS:10.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 84%
# Mask: 55%
#
# FPS:10.6 	 AVG_FPS:10.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 84%
# Mask: 55%
#
# FPS:10.6 	 AVG_FPS:10.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 46%
# Mask: 100%
# Mask: 86%
# Mask: 54%
#
# FPS:10.6 	 AVG_FPS:10.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 44%
# Mask: 100%
# Mask: 84%
# Mask: 60%
#
# FPS:10.6 	 AVG_FPS:10.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 84%
# Mask: 62%
#
# FPS:10.7 	 AVG_FPS:10.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 83%
# Mask: 62%
#
# FPS:10.8 	 AVG_FPS:10.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 82%
# Mask: 62%
#
# FPS:10.7 	 AVG_FPS:10.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 84%
# Mask: 66%
#
# FPS:10.8 	 AVG_FPS:10.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 51%
# Mask: 99%
# Mask: 84%
# Mask: 70%
#
# FPS:10.7 	 AVG_FPS:10.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 62%
# Mask: 99%
# Mask: 87%
# Mask: 73%
#
# FPS:10.8 	 AVG_FPS:10.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 58%
# Mask: 99%
# Mask: 89%
# Mask: 72%
#
# FPS:10.8 	 AVG_FPS:10.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 63%
# Mask: 99%
# Mask: 89%
# Mask: 70%
#
# FPS:10.9 	 AVG_FPS:10.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 63%
# Mask: 99%
# Mask: 89%
# Mask: 70%
#
# FPS:10.9 	 AVG_FPS:10.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 65%
# Mask: 99%
# Mask: 89%
# Mask: 70%
#
# FPS:11.0 	 AVG_FPS:10.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 57%
# Mask: 99%
# Mask: 88%
# Mask: 66%
#
# FPS:10.9 	 AVG_FPS:10.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 49%
# Mask: 100%
# Mask: 88%
# Mask: 60%
#
# FPS:11.0 	 AVG_FPS:10.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 51%
# Mask: 100%
# Mask: 88%
# Mask: 47%
#
# FPS:11.0 	 AVG_FPS:10.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 48%
# Mask: 100%
# Mask: 90%
#
# FPS:11.0 	 AVG_FPS:10.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 48%
# Mask: 100%
# Mask: 90%
#
# FPS:11.0 	 AVG_FPS:10.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 56%
# Mask: 100%
# Mask: 96%
# Mask: 54%
#
# FPS:11.1 	 AVG_FPS:10.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 69%
# Mask: 100%
# Mask: 95%
# Mask: 42%
#
# FPS:11.0 	 AVG_FPS:10.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 59%
# Mask: 100%
# Mask: 94%
# Mask: 40%
#
# FPS:11.1 	 AVG_FPS:10.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 46%
# Mask: 100%
# Mask: 94%
# Mask: 42%
#
# FPS:11.0 	 AVG_FPS:10.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 95%
# Mask: 45%
#
# FPS:11.0 	 AVG_FPS:10.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 94%
# Mask: 45%
#
# FPS:11.0 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 94%
# Mask: 82%
#
# FPS:11.0 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 93%
#
# FPS:11.0 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 94%
#
# FPS:11.0 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 97%
# Mask: 94%
#
# FPS:10.9 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 97%
# Mask: 95%
#
# FPS:11.0 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 97%
# Mask: 95%
#
# FPS:11.0 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 95%
# Mask: 94%
#
# FPS:11.1 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 96%
# Mask: 95%
#
# FPS:11.0 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 95%
# Mask: 94%
#
# FPS:11.1 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 96%
# Mask: 94%
#
# FPS:11.0 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 97%
# Mask: 94%
#
# FPS:11.0 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 97%
# Mask: 94%
#
# FPS:11.0 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 98%
# Mask: 94%
#
# FPS:11.1 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 98%
# Mask: 98%
# Mask: 94%
#
# FPS:11.2 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 98%
# Mask: 98%
# Mask: 92%
#
# FPS:11.1 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 97%
# Mask: 92%
#
# FPS:11.1 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 95%
# Mask: 91%
#
# FPS:11.1 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 96%
# Mask: 91%
#
# FPS:11.0 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 91%
# Mask: 91%
#
# FPS:11.1 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 93%
# Mask: 91%
#
# FPS:11.0 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 95%
# Mask: 92%
#
# FPS:11.1 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 92%
# Mask: 89%
#
# FPS:11.0 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 93%
# Mask: 90%
#
# FPS:11.0 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 93%
# Mask: 90%
#
# FPS:11.0 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 92%
# Mask: 85%
#
# FPS:11.0 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 92%
# Mask: 90%
#
# FPS:11.0 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 92%
# Mask: 92%
#
# FPS:11.0 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 94%
# Mask: 91%
#
# FPS:10.9 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 96%
# Mask: 91%
#
# FPS:10.9 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 96%
# Mask: 91%
#
# FPS:10.9 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 97%
# Mask: 90%
#
# FPS:11.0 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 98%
# Mask: 90%
#
# FPS:10.9 	 AVG_FPS:10.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 99%
# Mask: 89%
#
# FPS:11.0 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 99%
# Mask: 89%
#
# FPS:11.1 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 99%
# Mask: 91%
#
# FPS:11.1 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 99%
# Mask: 91%
#
# FPS:11.1 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 99%
# Mask: 92%
#
# FPS:11.1 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 99%
# Mask: 92%
#
# FPS:11.0 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 98%
# Mask: 93%
#
# FPS:11.1 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 98%
# Mask: 97%
# Mask: 93%
#
# FPS:11.0 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 98%
# Mask: 98%
# Mask: 94%
#
# FPS:11.1 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 98%
# Mask: 98%
# Mask: 94%
#
# FPS:11.0 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 97%
# Mask: 94%
#
# FPS:11.0 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 98%
# Mask: 94%
#
# FPS:11.0 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 98%
# Mask: 98%
# Mask: 92%
#
# FPS:11.1 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 98%
# Mask: 88%
#
# FPS:11.0 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 98%
# Mask: 89%
#
# FPS:11.1 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 98%
# Mask: 89%
#
# FPS:11.2 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
# Mask: 99%
# Mask: 88%
#
# FPS:11.2 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 88%
#
# FPS:11.2 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 100%
# Mask: 90%
#
# FPS:11.3 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 100%
# Mask: 91%
#
# FPS:11.3 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 100%
# Mask: 90%
#
# FPS:11.3 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 100%
# Mask: 90%
#
# FPS:11.3 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 89%
#
# FPS:11.3 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 89%
#
# FPS:11.3 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 89%
#
# FPS:11.3 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 89%
#
# FPS:11.3 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 97%
# Mask: 89%
#
# FPS:11.2 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 97%
# Mask: 89%
#
# FPS:11.2 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 97%
# Mask: 89%
#
# FPS:11.2 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 90%
#
# FPS:11.3 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 89%
#
# FPS:11.2 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 89%
#
# FPS:11.2 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 90%
#
# FPS:11.1 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 90%
#
# FPS:11.2 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 90%
#
# FPS:11.2 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 90%
#
# FPS:11.2 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 100%
# Mask: 91%
#
# FPS:11.1 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 92%
#
# FPS:11.1 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 94%
#
# FPS:11.0 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 94%
#
# FPS:11.1 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 97%
# Mask: 95%
#
# FPS:11.0 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 95%
#
# FPS:11.1 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 97%
# Mask: 96%
#
# FPS:11.1 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 96%
#
# FPS:11.1 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 96%
#
# FPS:11.1 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 96%
#
# FPS:11.1 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 97%
# Mask: 96%
#
# FPS:11.1 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 95%
# Mask: 94%
#
# FPS:11.1 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 94%
# Mask: 94%
#
# FPS:11.1 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 95%
# Mask: 94%
#
# FPS:11.1 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 96%
# Mask: 94%
#
# FPS:11.0 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 96%
# Mask: 94%
#
# FPS:11.1 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 97%
# Mask: 95%
# Mask: 41%
#
# FPS:11.0 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 96%
# Mask: 96%
# Mask: 41%
#
# FPS:11.1 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 97%
# Mask: 96%
# Mask: 42%
#
# FPS:11.1 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 95%
#
# FPS:11.1 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 96%
#
# FPS:11.0 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 96%
#
# FPS:11.1 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 96%
#
# FPS:11.0 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 96%
#
# FPS:11.1 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 96%
#
# FPS:11.0 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 96%
#
# FPS:11.1 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 95%
#
# FPS:11.0 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 95%
#
# FPS:11.0 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 94%
#
# FPS:11.0 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 94%
#
# FPS:11.0 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 94%
#
# FPS:11.0 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 95%
#
# FPS:11.0 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 95%
#
# FPS:11.0 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 95%
#
# FPS:11.0 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 95%
#
# FPS:10.9 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 95%
#
# FPS:11.0 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 95%
#
# FPS:11.1 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 95%
#
# FPS:11.1 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 95%
#
# FPS:11.2 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 95%
#
# FPS:11.2 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 94%
#
# FPS:11.2 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 95%
#
# FPS:11.2 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 94%
#
# FPS:11.3 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 95%
#
# FPS:11.3 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 95%
#
# FPS:11.3 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 95%
#
# FPS:11.3 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 95%
#
# FPS:11.3 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 95%
#
# FPS:11.3 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 95%
#
# FPS:11.3 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 95%
#
# FPS:11.3 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 96%
#
# FPS:11.3 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 96%
#
# FPS:11.3 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 96%
#
# FPS:11.3 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 96%
#
# FPS:11.3 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 97%
# Mask: 96%
# Mask: 44%
#
# FPS:11.4 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 96%
# Mask: 96%
# Mask: 42%
#
# FPS:11.4 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 96%
# Mask: 93%
#
# FPS:11.4 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 96%
# Mask: 93%
#
# FPS:11.4 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 95%
# Mask: 92%
# Mask: 44%
#
# FPS:11.4 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 94%
# Mask: 92%
#
# FPS:11.5 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 94%
# Mask: 81%
# Mask: 59%
#
# FPS:11.4 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 95%
# Mask: 80%
# Mask: 68%
#
# FPS:11.4 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 95%
# Mask: 82%
# Mask: 67%
#
# FPS:11.4 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 95%
# Mask: 82%
# Mask: 68%
#
# FPS:11.4 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 95%
# Mask: 81%
# Mask: 66%
#
# FPS:11.3 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 95%
# Mask: 80%
# Mask: 66%
#
# FPS:11.4 	 AVG_FPS:11.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 97%
# Mask: 80%
# Mask: 66%
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 80%
# Mask: 65%
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 81%
# Mask: 63%
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 81%
# Mask: 63%
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 81%
# Mask: 61%
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 82%
# Mask: 63%
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 80%
# Mask: 64%
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 81%
# Mask: 63%
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 81%
# Mask: 64%
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 82%
# Mask: 63%
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 100%
# Mask: 81%
# Mask: 63%
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 100%
# Mask: 76%
# Mask: 61%
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 100%
# Mask: 78%
# Mask: 58%
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 80%
# Mask: 58%
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 82%
# Mask: 58%
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 82%
# Mask: 58%
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 82%
# Mask: 59%
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 83%
# Mask: 61%
#
# FPS:11.5 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 84%
# Mask: 62%
#
# FPS:11.5 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 100%
# Mask: 85%
# Mask: 61%
#
# FPS:11.5 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 100%
# Mask: 85%
# Mask: 59%
#
# FPS:11.5 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 100%
# Mask: 85%
# Mask: 59%
#
# FPS:11.6 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 100%
# Mask: 85%
# Mask: 57%
#
# FPS:11.5 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 100%
# Mask: 86%
# Mask: 54%
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 100%
# Mask: 85%
# Mask: 53%
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 100%
# Mask: 84%
# Mask: 54%
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 100%
# Mask: 86%
# Mask: 51%
#
# FPS:11.5 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 100%
# Mask: 85%
# Mask: 51%
#
# FPS:11.5 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 85%
# Mask: 54%
#
# FPS:11.5 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 84%
# Mask: 58%
#
# FPS:11.6 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 84%
# Mask: 59%
#
# FPS:11.6 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 84%
# Mask: 58%
#
# FPS:11.6 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 83%
# Mask: 57%
#
# FPS:11.7 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 84%
# Mask: 57%
#
# FPS:11.7 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 84%
# Mask: 58%
#
# FPS:11.7 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 84%
# Mask: 60%
#
# FPS:11.8 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 84%
# Mask: 61%
#
# FPS:11.8 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 99%
# Mask: 83%
# Mask: 60%
#
# FPS:11.8 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 81%
# Mask: 62%
#
# FPS:11.8 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 81%
# Mask: 62%
#
# FPS:11.8 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 81%
# Mask: 62%
#
# FPS:11.8 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 80%
# Mask: 62%
#
# FPS:11.9 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 81%
# Mask: 62%
#
# FPS:11.9 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 98%
# Mask: 81%
# Mask: 61%
#
# FPS:11.9 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 97%
# Mask: 81%
# Mask: 60%
#
# FPS:11.8 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 97%
# Mask: 81%
# Mask: 61%
#
# FPS:11.8 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 97%
# Mask: 79%
# Mask: 61%
#
# FPS:11.8 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 97%
# Mask: 80%
# Mask: 62%
#
# FPS:11.7 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 97%
# Mask: 80%
# Mask: 62%
#
# FPS:11.7 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 95%
# Mask: 81%
# Mask: 65%
#
# FPS:11.6 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 95%
# Mask: 81%
# Mask: 65%
#
# FPS:11.5 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 95%
# Mask: 81%
# Mask: 65%
#
# FPS:11.5 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 94%
# Mask: 82%
# Mask: 64%
#
# FPS:11.5 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 94%
# Mask: 83%
# Mask: 66%
#
# FPS:11.5 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 94%
# Mask: 83%
# Mask: 66%
#
# FPS:11.4 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 95%
# Mask: 82%
# Mask: 65%
#
# FPS:11.5 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 95%
# Mask: 82%
# Mask: 61%
#
# FPS:11.4 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 95%
# Mask: 82%
# Mask: 61%
#
# FPS:11.4 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 95%
# Mask: 83%
# Mask: 59%
#
# FPS:11.3 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 95%
# Mask: 83%
# Mask: 57%
#
# FPS:11.3 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 96%
# Mask: 83%
# Mask: 56%
#
# FPS:11.1 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 95%
# Mask: 83%
# Mask: 52%
#
# FPS:11.1 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 95%
# Mask: 83%
# Mask: 48%
#
# FPS:11.1 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 95%
# Mask: 83%
# Mask: 48%
#
# FPS:11.2 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 94%
# Mask: 85%
# Mask: 50%
#
# FPS:11.2 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 94%
# Mask: 88%
# Mask: 49%
#
# FPS:11.2 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 93%
# Mask: 86%
# Mask: 53%
#
# FPS:11.2 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 89%
# Mask: 84%
# Mask: 60%
#
# FPS:11.2 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 88%
# Mask: 84%
# Mask: 64%
#
# FPS:11.2 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 88%
# Mask: 84%
# Mask: 65%
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
# Mask: 90%
# Mask: 84%
# Mask: 66%
#
# FPS:11.3 	 AVG_FPS:11.3
# Stream closed.
#
#  cvWriteFrame
# input video stream closed.
#  closing... closed!output_video_writer closed.

# %%
#Testing MASK
# !./darknet detector demo yolov3-mask-setup.data yolov3-mask-test.cfg backup/yolov3-mask-train_best.weights test-video2.mp4 -thresh .4 -out_filename out-vid2.avi -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
# FPS:11.5 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No_mask: 45%
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
# No_mask: 45%
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
# Mask: 49%
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.1 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.1 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
# No_mask: 44%
#
# FPS:11.5 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
# Mask: 58%
#
# FPS:11.6 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
# Mask: 42%
#
# FPS:11.7 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
# Mask: 42%
#
# FPS:11.7 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
# Mask: 42%
#
# FPS:11.8 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
# No_mask: 55%
#
# FPS:11.9 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
# Mask: 83%
#
# FPS:11.9 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.0 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
# Mask: 76%
#
# FPS:12.0 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
# Mask: 66%
#
# FPS:12.0 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
# Mask: 53%
#
# FPS:11.9 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.0 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.0 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.0 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.0 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 46%
#
# FPS:11.5 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 46%
#
# FPS:11.5 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 47%
#
# FPS:11.4 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 59%
#
# FPS:11.3 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 68%
#
# FPS:11.3 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 71%
#
# FPS:11.2 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 48%
#
# FPS:11.1 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 96%
#
# FPS:11.1 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 82%
#
# FPS:11.1 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 55%
#
# FPS:11.2 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 45%
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 43%
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 55%
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
# No_mask: 53%
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
# No_mask: 57%
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
# No_mask: 67%
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
# No_mask: 56%
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
# No_mask: 56%
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 60%
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 47%
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 48%
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 62%
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.1 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 74%
#
# FPS:11.2 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 72%
#
# FPS:11.2 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 96%
#
# FPS:11.3 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 98%
#
# FPS:11.2 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
#
# FPS:11.3 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
#
# FPS:11.3 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 95%
#
# FPS:11.3 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
#
# FPS:11.4 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 93%
#
# FPS:11.4 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 77%
#
# FPS:11.4 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 42%
#
# FPS:11.2 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 42%
#
# FPS:11.0 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.0 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.0 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.1 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.1 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:10.9 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.0 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.0 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:10.9 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.0 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.1 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.0 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.0 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.0 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.1 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.1 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.1 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
# No_mask: 53%
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
# No_mask: 60%
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
# No_mask: 54%
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
# No_mask: 46%
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
# No_mask: 68%
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
# No_mask: 64%
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 55%
# No_mask: 40%
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 43%
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 41%
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# Mask: 64%
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# Mask: 66%
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 44%
#
# FPS:11.6 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 43%
#
# FPS:11.5 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 50%
#
# FPS:11.5 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 41%
#
# FPS:11.5 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 40%
#
# FPS:11.5 	 AVG_FPS:11.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 51%
#
# FPS:11.5 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No_mask: 53%
#
# FPS:11.5 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No_mask: 50%
#
# FPS:11.5 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No_mask: 53%
#
# FPS:11.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No_mask: 51%
#
# FPS:11.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No_mask: 50%
#
# FPS:11.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No_mask: 50%
#
# FPS:11.5 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# Mask: 61%
#
# FPS:11.2 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# Mask: 79%
#
# FPS:11.3 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# Mask: 70%
# Mask: 50%
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# Mask: 60%
# Mask: 59%
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 49%
# Mask: 68%
#
# FPS:11.5 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# Mask: 44%
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# Mask: 43%
#
# FPS:11.5 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# Mask: 51%
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# Mask: 83%
#
# FPS:11.5 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# Mask: 48%
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
# Mask: 42%
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 58%
#
# FPS:11.5 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 45%
#
# FPS:11.6 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 42%
#
# FPS:11.5 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 49%
#
# FPS:11.5 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 48%
#
# FPS:11.4 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 50%
#
# FPS:11.4 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.1 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.1 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.1 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 52%
#
# FPS:11.3 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 40%
# Mask: 54%
#
# FPS:11.3 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 46%
# Mask: 65%
#
# FPS:11.2 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 45%
# Mask: 60%
#
# FPS:11.3 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 61%
#
# FPS:11.3 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 51%
#
# FPS:11.3 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 51%
#
# FPS:11.3 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.2 	 AVG_FPS:11.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.3
# Stream closed.
#
#  cvWriteFrame
# input video stream closed.
#  closing... closed!output_video_writer closed.
