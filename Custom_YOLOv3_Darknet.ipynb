# %% [markdown]
# <a href="https://colab.research.google.com/github/FarzamIHPC/YoloV3_mask/blob/master/Custom_YOLOv3_Darknet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font style="color:blue">Train a Custom Object Detector using DarkNet YOLOv3</font>
# In this notebook, we will learn how train a object detector for an object of our choice. We will use DarkNet framework and YOLO v3 architecture.
#
# We will use images of Ambulance from Open Images Dataset.
#
# # <font style="color:blue">Change Runtime Type</font>
# Before proceeding, make sure that the notebook is running on the GPU. Go to Runtime -> Change runtime type -> Select hardware Accelerator as GPU.

# %% [markdown]
# # <font style="color:blue">1. Link Google Drive [ Optional ]</font>
# Since it will take considerable amount of time to train the network, it is a good idea to link your Google Drive with Colab so that everything is backed up. So, if the runtime gets disconnected in the middle of something, you can simply re-link the drive and start working. To link drive, just run the cell below and follow the 2 steps.
#
# 1. It will generate a link. Click on the link to login to your google account
# 1. Get the authorization code and paste it in the box under the cell.
#
# You may however choose to do everything without linking google drive and everything will work as usual.

# %% [markdown]
# ### <font style="color:green">Uncomment the 2 cells below to link google drive</font>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
 # %cd /content/drive/My\ Drive
# Out:
# /content/drive/My Drive

# %% [markdown]
# # <font style="color:blue">2. Clone the DarkNet Repository </font>
# We will use Alexey's darknet fork which has many modifications and improvements and is actively maintained by him.

# %%
# !git clone https://github.com/AlexeyAB/darknet.git
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 13778 (delta 0), reused 1 (delta 0), pack-reused 13775
# Receiving objects: 100% (13778/13778), 12.37 MiB | 6.64 MiB/s, done.
# Resolving deltas: 100% (9402/9402), done.
# Checking out files: 100% (2006/2006), done.

# %% [markdown]
# # <font style="color:blue">3. Compile DarkNet</font>
# We will first make some changes to the Makefile before we compile. Specifically, we will enable the following:
# 1. Build darknet with OpenCV
# 1. Build with CUDA enabled
# 1. Build with cuDNN enabled.

# %%
# %cd darknet
# Out:
# /content/drive/My Drive/darknet

# %%
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile

print("Building. . . It might take 2-3 minutes")

# !make &> build_log.txt
# Out:
# Building. . . It might take 2-3 minutes

# %% [markdown]
# # <font style="color:blue">4. Download Data from Open Images Dataset</font>
# Given below is the script for downloading data from open images dataset.
#
# It downloads 2 files from Open Images.
#
# 1. **train-annotations-bbox.csv** contains the bounding box labels for all images present in the training data of Open Images
# 1. **class-descriptions-boxable.csv** contains the classes which have bounding box annotations available in the dataset.
#
# Using these 2 files we can get a list of all files corresponding to a particular class.
#
# You can specify which classes you want to download and it will download the data. One thing to note here is that YOLO expects the bounding boxes to be in a specific format as given below.
#
# ```
# <object-class> <x_center> <y_center> <width> <height>
# ```
#
# The first field object-class-id is an integer representing the class of the object. It ranges from 0 to (number of classes – 1). In our current case, since we have only one class of snowman, it is always set to 0.
#
# The second and third entry, center-x and center-y are respectively the x and y coordinates of the center of the bounding box, normalized (divided) by the image width and height respectively.
#
# The fourth and fifth entry, width and height are respectively the width and height of the bounding box, again normalized (divided) by the image width and height respectively.
#
# Let’s consider an example with the following notations:
# ```
# x – x-coordinate(in pixels) of the center of the bounding box
# y – y-coordinate(in pixels) of the center of the bounding box
# w – width(in pixels) of the bounding box
# h – height(in pixels) of the bounding box
# W – width(in pixels) of the whole image
# H – height(in pixels) of the whole image
# ```
# Then we compute the annotation values in the label files as follows:
# ```
# center-x = x / W
# center-y = y / H
# width = w / W
# height = h / H
# ```
# The above four entries are all floating point values between 0 to 1.
#
# Note that the 2nd and 3rd elements are centers and NOT the top/bottom left corners. This is different from most datasets available on the internet.
#
# Thus, we reformat the bounding boxes according to YOLO in the last line of code in the function below.
#
# **NOTE:** Downloading the data from aws takes considerable amount of time ( ~7 seconds per image ). Thus, we have provided a zip file for the dataset which you can download in the next cell. You can use the script to download other classes when you experiment further.

# %%
def download_open_images_data(classes=["Ambulance"],maxImages=500):
    import csv
    import subprocess
    import os,time

    if not os.path.exists("train-annotations-bbox.csv"):
        print("Downloading annotation files. . .\n")
        # !wget https://storage.googleapis.com/openimages/2018_04/train/train-annotations-bbox.csv
        # !wget https://storage.googleapis.com/openimages/2018_04/class-descriptions-boxable.csv
    
    # !pip install awscli &> /dev/null

    runMode = "train"
    dataPath = "OID-data"

    with open('class-descriptions-boxable.csv', mode='r') as infile:
        reader = csv.reader(infile)
        dict_list = {rows[1]:rows[0] for rows in reader}

    subprocess.run(['rm', '-rf', dataPath])
    subprocess.run([ 'mkdir', dataPath])

    for ind in range(0, len(classes)):
        
        className = classes[ind]
        print("Class " + str(ind) + " : " + className)

        commandStr = "grep " + dict_list[className] + " " + runMode + "-annotations-bbox.csv"
        print(commandStr)
        class_annotations = subprocess.run(commandStr.split(), stdout=subprocess.PIPE).stdout.decode('utf-8')
        class_annotations = class_annotations.splitlines()

        totalNumOfAnnotations = len(class_annotations)
        print("Total number of annotations : "+str(totalNumOfAnnotations))
        cnt = 0
        for line in class_annotations[0:min(maxImages,totalNumOfAnnotations)]:

            cnt = cnt + 1
            print("annotation count : " + str(cnt))
            lineParts = line.split(',')
            subprocess.run([ 'aws', 's3', '--no-sign-request', '--only-show-errors', 'cp', 's3://open-images-dataset/'+runMode+'/'+lineParts[0]+".jpg", dataPath + '/'+lineParts[0]+".jpg"])
            with open(dataPath + '/%s.txt'%(lineParts[0]),'a') as f:
                f.write(' '.join([str(ind),str((float(lineParts[5]) + float(lineParts[4]))/2), str((float(lineParts[7]) + float(lineParts[6]))/2), str(float(lineParts[5])-float(lineParts[4])),str(float(lineParts[7])-float(lineParts[6]))])+'\n')

# %%
classes = ["Ambulance"]
maxImages = 400

# %% [markdown]
# Uncomment the cell below if you want to download a new class. You can download the data using the cell below.

# %%
## It might ask you to restart runtime, but it is not required.
# download_open_images_data(classes, maxImages)

# %% [markdown]
# ## <font style="color:blue">4.1. Download Data</font>
# Download the data which we have shared using the dropbox link. This is a faster way. You can use the above process for downloading any other category.

# %%
# !wget "https://www.dropbox.com/s/84jr6gxlvrw3azy/OID-data.zip?dl=1" -O OID-data.zip
# !unzip OID-data.zip &> /dev/null
# Out:
# --2020-06-30 09:25:56--  https://www.dropbox.com/s/84jr6gxlvrw3azy/OID-data.zip?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.1, 2620:100:601d:1::a27d:501
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/84jr6gxlvrw3azy/OID-data.zip [following]
# --2020-06-30 09:25:56--  https://www.dropbox.com/s/dl/84jr6gxlvrw3azy/OID-data.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc15cc66568f4448468a317be3a4.dl.dropboxusercontent.com/cd/0/get/A6ohqJgALBCyga-s_8VEPRWJLxd3HPbdC6ePsrMb5FP42Y9QN1FTKkcpRVrxcJdnu-lPW8_IcbRlz5jkoPWkuem2oSrFQfwSrk8ndLYRF7xSysFyk7aE_w56Npx6n4tbuqo/file?dl=1# [following]
# --2020-06-30 09:25:57--  https://uc15cc66568f4448468a317be3a4.dl.dropboxusercontent.com/cd/0/get/A6ohqJgALBCyga-s_8VEPRWJLxd3HPbdC6ePsrMb5FP42Y9QN1FTKkcpRVrxcJdnu-lPW8_IcbRlz5jkoPWkuem2oSrFQfwSrk8ndLYRF7xSysFyk7aE_w56Npx6n4tbuqo/file?dl=1
# Resolving uc15cc66568f4448468a317be3a4.dl.dropboxusercontent.com (uc15cc66568f4448468a317be3a4.dl.dropboxusercontent.com)... 162.125.5.15, 2620:100:601d:15::a27d:50f
# Connecting to uc15cc66568f4448468a317be3a4.dl.dropboxusercontent.com (uc15cc66568f4448468a317be3a4.dl.dropboxusercontent.com)|162.125.5.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 116188863 (111M) [application/binary]
# Saving to: ‘OID-data.zip’
#
# OID-data.zip        100%[===================>] 110.81M  49.5MB/s    in 2.2s
#
# 2020-06-30 09:26:00 (49.5 MB/s) - ‘OID-data.zip’ saved [116188863/116188863]

# %% [markdown]
# ## <font style="color:blue">4.2. Prepare dataset files</font>
# We need to create a txt file which contains the path to the images. These files will be used while setting up the training.
#
# The data is split into train and test in the ratio of 80:20. So, we will use 80% of the data for training and the rest for testing after a few iterations of training.

# %%
import random
import os
import subprocess
import sys

#image_dir = "./OID-data"  # This is for Ambulance object detection
image_dir = "./kaggle_and_no-mask_dataset"  # This is for mask detection

f_val = open("data_test.txt", 'w')
f_train = open("data_train.txt", 'w')

path, dirs, files = next(os.walk(image_dir))
data_size = len(files)

ind = 0
data_test_size = int(0.2 * data_size)
test_array = random.sample(range(data_size), k=data_test_size)

for f in os.listdir(image_dir):
    if(f.split(".")[-1] == "jpg"):
        ind += 1
        
        if ind in test_array:
            f_val.write(image_dir+'/'+f+'\n')
        else:
            f_train.write(image_dir+'/'+f+'\n')

f_train.close()
f_val.close()

# %% [markdown]
# # <font style="color:blue">5. Download Code for YOLO Training</font>
# We have shared the code for training in the link below. Explanation of each file follows next.

# %%
# !wget "https://www.dropbox.com/sh/jfyj1wetf28bgpr/AACGJHIlPyKRO70B9DlAVqWPa?dl=1" -O yolov3-ambulance-code.zip
# !unzip yolov3-ambulance-code.zip
# Out:
# --2020-06-30 09:30:46--  https://www.dropbox.com/sh/jfyj1wetf28bgpr/AACGJHIlPyKRO70B9DlAVqWPa?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.1, 2620:100:601d:1::a27d:501
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /sh/dl/jfyj1wetf28bgpr/AACGJHIlPyKRO70B9DlAVqWPa [following]
# --2020-06-30 09:30:46--  https://www.dropbox.com/sh/dl/jfyj1wetf28bgpr/AACGJHIlPyKRO70B9DlAVqWPa
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc77f6a6e60b6716ebe66f6f38d0.dl.dropboxusercontent.com/zip_download_get/AeBLin5wfEDs0Nx1_1yzJL-PJHshfmn_pkzqRl-GzoxNqj-OLbjugSahNQqZAyPjdvziTh6ZMIHc0-etfyInHtp2s3iceREPJecRK2SL8zJu2A?dl=1 [following]
# --2020-06-30 09:30:47--  https://uc77f6a6e60b6716ebe66f6f38d0.dl.dropboxusercontent.com/zip_download_get/AeBLin5wfEDs0Nx1_1yzJL-PJHshfmn_pkzqRl-GzoxNqj-OLbjugSahNQqZAyPjdvziTh6ZMIHc0-etfyInHtp2s3iceREPJecRK2SL8zJu2A?dl=1
# Resolving uc77f6a6e60b6716ebe66f6f38d0.dl.dropboxusercontent.com (uc77f6a6e60b6716ebe66f6f38d0.dl.dropboxusercontent.com)... 162.125.5.15, 2620:100:601d:15::a27d:50f
# Connecting to uc77f6a6e60b6716ebe66f6f38d0.dl.dropboxusercontent.com (uc77f6a6e60b6716ebe66f6f38d0.dl.dropboxusercontent.com)|162.125.5.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17639 (17K) [application/zip]
# Saving to: ‘yolov3-ambulance-code.zip’
#
# yolov3-ambulance-co 100%[===================>]  17.23K  --.-KB/s    in 0.04s
#
# 2020-06-30 09:30:47 (444 KB/s) - ‘yolov3-ambulance-code.zip’ saved [17639/17639]
#
# Archive:  yolov3-ambulance-code.zip
# warning:  stripped absolute path spec from /
# mapname:  conversion of  failed
#  extracting: class.names
#  extracting: yolov3-ambulance-test.cfg
#  extracting: yolov3-ambulance-train.cfg
#  extracting: yolov3-ambulance-setup.data

# %% [markdown]
# You can see there are 4 files which have been downloaded. We will go through each file in the next section.

# %% [markdown]
# # <font style="color:blue">6. Download weights for Convolutional backbone</font>
# When you train your own object detector, it is a good idea to leverage existing models trained on very large datasets even though the large dataset may not contain the object you are trying to detect. This process is called transfer learning.
#
# Instead of learning from scratch, we use a pre-trained model which contains convolutional weights trained on ImageNet. Using these weights as our starting weights, our network can learn faster. We will use the pre-trained convolutional backbone.
#
# We will download the weights file from our server as the author's server seemed slow. If you face any issues, you can download the file from the link given in the code below.

# %%
# Original File : https://pjreddie.com/media/files/darknet53.conv.74
# !wget "https://www.dropbox.com/s/18dwbfth7prbf0h/darknet53.conv.74?dl=1" -O darknet53.conv.74
# Out:
# --2020-06-30 09:34:50--  https://www.dropbox.com/s/18dwbfth7prbf0h/darknet53.conv.74?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.1, 2620:100:601d:1::a27d:501
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/18dwbfth7prbf0h/darknet53.conv.74 [following]
# --2020-06-30 09:34:51--  https://www.dropbox.com/s/dl/18dwbfth7prbf0h/darknet53.conv.74
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc88654fb080abdb33cca7af8aca.dl.dropboxusercontent.com/cd/0/get/A6p18D7dWfiyjwZii39egZiWoPsW2_CxQPuqIO6DlTrjP5MoJXj0mfgNhFmyr0KeSEgrkFH4tWZ4z4B1hZX5Ik6OvQAilzn3mNbdgW3JTvq0wXw4qcjMSr895Ss2y9le1gU/file?dl=1# [following]
# --2020-06-30 09:34:51--  https://uc88654fb080abdb33cca7af8aca.dl.dropboxusercontent.com/cd/0/get/A6p18D7dWfiyjwZii39egZiWoPsW2_CxQPuqIO6DlTrjP5MoJXj0mfgNhFmyr0KeSEgrkFH4tWZ4z4B1hZX5Ik6OvQAilzn3mNbdgW3JTvq0wXw4qcjMSr895Ss2y9le1gU/file?dl=1
# Resolving uc88654fb080abdb33cca7af8aca.dl.dropboxusercontent.com (uc88654fb080abdb33cca7af8aca.dl.dropboxusercontent.com)... 162.125.5.15, 2620:100:601d:15::a27d:50f
# Connecting to uc88654fb080abdb33cca7af8aca.dl.dropboxusercontent.com (uc88654fb080abdb33cca7af8aca.dl.dropboxusercontent.com)|162.125.5.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/binary]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  50.2MB/s    in 3.1s
#
# 2020-06-30 09:34:55 (50.2 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %% [markdown]
# # <font style="color:blue">7. Training Configuration</font>
# As explained in the theory section, we will use the config file to specify the various training parameters. A gist of all the parameters is given below:
#
# ## <font style="color:blue">7.1. Data Setup</font>
# In the file **`yolov3-ambulance-setup.data`**(included in our code), we need to provide information about the specifications for our object detector and some relevant paths.
#
# The contents of the file are as follows:
# ```
# classes = 1
# train  = data_train.txt
# valid  = data_test.txt
# names = class.names
# backup = backup/
# ```
# The classes parameter needs the number of classes. In our case, it is 1.
#
# You need to provide the absolute paths of the files **`data_train.txt`** and **`data_test.txt`** generated earlier, which have the list of files to be used for training(train parameter) and validation(valid parameter) respectively.
#
# The names field represents the path of a file which contains the names of all the classes. We have included the **`class.names`** file which contains the class name **`Ambulance`**. You will need to provide its absolute path in your machine here.
#
# Lastly, for the **`backup`** parameter, we need to give the path to an existing directory where we can store the intermediate weights files as the training progresses.
#
# ## <font style="color:blue">7.2. Training Config File</font>
# Along with the yolov3-ambulance-setup.data and class.names files, YOLOv3 also needs a configuration file **`yolov3-ambulance-train.cfg`**. It is based on the demo configuration file, yolov3-voc.cfg (comes with darknet code), which was used to train on the VOC dataset. All the important training parameters are stored in this configuration file. Let us understand what they mean and what values to set them to.
#
# ### <font style="color:green">7.2.1 Batch hyper-parameter in YOLOv3</font>
# Let’s learn more about batch and subdivision parameter.
# ```
# [net]
# # Testing
# # batch=1
# # subdivisions=1
# # Training
# batch=64
# subdivisions=16
# ```
# The batch parameter indicates the batch size used during training.
#
# Our training set contains a few hundred images, but it is not uncommon to train on million of images. The training process involves iteratively updating the weights of the neural network based on how many mistakes it is making on the training dataset.
#
# It is impractical (and unnecessary) to use all images in the training set at once to update the weights. So, a small subset of images is used in one iteration, and this subset is called the batch size.
#
# When the batch size is set to 64, it means 64 images are used in one iteration to update the parameters of the neural network.
#
# ### <font style="color:green">7.2.2 Subdivisions configuration parameter in YOLOv3</font>
# Even though you may want to use a batch size of 64 for training your neural network, you may not have a GPU with enough memory to use a batch size of 64. Fortunately, Darknet allows you to specify a variable called subdivisions that lets you process a fraction of the batch size at one time on your GPU.
#
# You can start the training with subdivisions=1, and if you get an Out of memory error, increase the subdivisions parameter by multiples of 2(e.g. 2, 4, 8, 16) till the training proceeds successfully. The GPU will process batch/subdivision number of images at any time, but the full batch or iteration would be complete only after all the 64 (as set above) images are processed.
#
# During testing, both batch and subdivision are set to 1.
#
# ### <font style="color:green">7.2.3 Width, Height, Channels</font>
# These configuration parameters specify the input image size and the number of channels.
#
# ```
# width=416
# height=416
# channels=3
# ```
# The input training images are first resized to width x height before training. Here we use the default values of 416×416. The results might improve if we increase it to 608×608, but it would take longer to train too. channels=3 indicates that we would be processing 3-channel RGB input images.
#
# ### <font style="color:green">7.2.4 Momentum and Decay</font>
# The configuration file contains a few parameters that control how the weight is updated.
# ```
# momentum=0.9
# decay=0.0005
# ```
# In the previous section, we mentioned how the weights of a neural network are updated based on a small batch of images and not the entire dataset. Because of this reason, the weight updates fluctuate quite a bit. That is why a parameter momentum is used to penalize large weight changes between iterations.
#
# A typical neural network has millions of weights and therefore they can easily overfit any training data. Overfitting simply means it will do very well on training data and poorly on test data. It is almost like the neural network has memorized the answer to all images in the training set, but really not learned the underlying concept. One of the ways to mitigate this problem is to penalize large value for weights. The parameter decay controls this penalty term. The default value works just fine, but you may want to tweak this if you notice overfitting.
#
# ### <font style="color:green">7.2.5 Learning Rate, Steps, Scales, Burn In (warm-up)</font>
# ```
# learning_rate=0.001
# policy=steps
# steps=800
# scales=.1
# burn_in=100
# ```
# The parameter learning rate controls how aggressively we should learn based on the current batch of data. Typically this is a number between 0.01 and 0.0001.
#
# At the beginning of the training process, we are starting with zero information and so the learning rate needs to be high. But as the neural network sees a lot of data, the weights need to change less aggressively. In other words, the learning rate needs to be decreased over time. In the configuration file, this decrease in learning rate is accomplished by first specifying that our learning rate decreasing policy is steps. In the above example, the learning rate will start from 0.001 and remain constant for 800 iterations, and then it will multiply by scales to get the new learning rate. We could have also specified multiple steps and scales.
#
# In the previous paragraph, we mentioned that the learning rate needs to be high in the beginning and low later on. While that statement is largely true, it has been empirically found that the training speed tends to increase if we have a lower learning rate for a short period of time at the very beginning. This is controlled by the burn_in parameter. Sometimes this **`burn-in`** period is also called warm-up period.
#
# ### <font style="color:green">7.2.6 Data augmentation</font>
# We know data collection takes a long time and it is difficult to find high quality annotated data. We want to make maximum use of this data by cooking up new data. This process is called data augmentation. For example, an image of the ambulance rotated by 5 degrees is still an image of a ambulance. The angle parameter in the configuration file allows you to randomly rotate the given image by ± angle.
#
# Similarly, if we transform the colors of the entire picture using saturation, exposure, and hue, it is still a picture of the ambulance.
# ```
# angle=0
# saturation = 1.5
# exposure = 1.5
# hue=.1
# ```
# We used the default values for training.
#
# ### <font style="color:green">7.2.7 Number of iterations</font>
# Finally, we need to specify how many iterations should the training process be run for.
# ```
# max_batches=1000
# ```
#
# For multi-class object detectors, the max_batches number is higher, i.e. we need to run for more number of batches(e.g. in yolov3-voc.cfg). For an n-classes object detector, it is advisable to run the training for at least 2000*n batches. In our case with only 1 class, 1000 seemed like a safe number for max_batches.
#
# You should try to change the parameter and see how it performs.
#
# ### <font style="color:green">7.2.8 Change filters parameter in conv layers [Important for multiple objects]</font>
# Change the filters parameter in the convolutional layer just before the yolo layer according to the formula
#
# **`filters=( classes + 5 ) * 3`**
#
# Since we are using classes = 1, thus, #filters in our case is 18. You should make this change if you are dealing with more classes.
#
#
# ## <font color="blue">7.3. Names file </font>
# We need to specify the names of the classes in the **`.names`** file. In our case, there is only 1 class and thus, only Ambulance is added to that file.

# %% [markdown]
# # <font style="color:blue">8. Start Training </font>
# For starting training using darknet, we need to execute the following command. Here we are specifying the
# 1. path to the setup file,
# 1. path to config file,
# 1. path to convolutional weights file
#
# and also passing some flags such as:
#
# - **`dont_show`** which wont display the graphs. This is required for Colab since it does not have a display and it will crash if it tries to display, not if you run the notebook on your local system.
# - **`map`** - this will calculate mAP - mean average precision for the test data which we have specified using the data_test.txt file which contains 20% of our data.

# %%
# This is for Ambulance training
#!./darknet detector train yolov3-ambulance-setup.data yolov3-ambulance-train.cfg ./darknet53.conv.74 -dont_show -map 2> train_log.txt

# This is for MASK training
# !./darknet detector train yolov3-mask-setup.data yolov3-mask-train.cfg ./darknet53.conv.74 -dont_show -map 2> train_log.txt
# Out:
# Streaming output truncated to the last 5000 lines.
#  CUDA allocate done!
# Loaded: 0.000031 seconds
#
#  (next mAP calculation at 200 iterations)
#  111: 3.486079, 4.251071 avg loss, 0.001000 rate, 11.815688 seconds, 7104 images, 3.831838 hours left
# Loaded: 0.000042 seconds
#
#  (next mAP calculation at 200 iterations)
#  112: 3.494290, 4.175393 avg loss, 0.001000 rate, 12.096981 seconds, 7168 images, 3.822698 hours left
# Loaded: 0.000060 seconds
#
#  (next mAP calculation at 200 iterations)
#  113: 4.744265, 4.232280 avg loss, 0.001000 rate, 12.542551 seconds, 7232 images, 3.814310 hours left
# Loaded: 0.000038 seconds
#
#  (next mAP calculation at 200 iterations)
#  114: 5.000625, 4.309115 avg loss, 0.001000 rate, 12.277229 seconds, 7296 images, 3.807071 hours left
# Loaded: 0.000041 seconds
#
#  (next mAP calculation at 200 iterations)
#  115: 4.701808, 4.348384 avg loss, 0.001000 rate, 12.383246 seconds, 7360 images, 3.799216 hours left
# Loaded: 0.000056 seconds
#
#  (next mAP calculation at 200 iterations)
#  116: 5.308283, 4.444374 avg loss, 0.001000 rate, 12.140006 seconds, 7424 images, 3.791666 hours left
# Loaded: 0.000033 seconds
#
#  (next mAP calculation at 200 iterations)
#  117: 3.500703, 4.350007 avg loss, 0.001000 rate, 12.021216 seconds, 7488 images, 3.783560 hours left
# Loaded: 0.000031 seconds
#
#  (next mAP calculation at 200 iterations)
#  118: 6.827497, 4.597756 avg loss, 0.001000 rate, 12.905449 seconds, 7552 images, 3.775210 hours left
# Loaded: 0.000067 seconds
#
#  (next mAP calculation at 200 iterations)
#  119: 5.414845, 4.679465 avg loss, 0.001000 rate, 12.423138 seconds, 7616 images, 3.769076 hours left
# Loaded: 0.000049 seconds
#
#  (next mAP calculation at 200 iterations)
#  120: 3.740567, 4.585575 avg loss, 0.001000 rate, 12.091809 seconds, 7680 images, 3.761788 hours left
# Resizing, random_coef = 1.40
#
#  416 x 416
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.000030 seconds
#
#  (next mAP calculation at 200 iterations)
#  121: 3.485227, 4.475540 avg loss, 0.001000 rate, 6.449492 seconds, 7744 images, 3.753728 hours left
# Loaded: 0.000053 seconds
#
#  (next mAP calculation at 200 iterations)
#  122: 5.414214, 4.569407 avg loss, 0.001000 rate, 6.605384 seconds, 7808 images, 3.731938 hours left
# Loaded: 0.000041 seconds
#
#  (next mAP calculation at 200 iterations)
#  123: 5.455523, 4.658019 avg loss, 0.001000 rate, 6.536138 seconds, 7872 images, 3.710729 hours left
# Loaded: 0.000059 seconds
#
#  (next mAP calculation at 200 iterations)
#  124: 4.559340, 4.648151 avg loss, 0.001000 rate, 6.679868 seconds, 7936 images, 3.689545 hours left
# Loaded: 0.000039 seconds
#
#  (next mAP calculation at 200 iterations)
#  125: 5.940815, 4.777418 avg loss, 0.001000 rate, 6.977798 seconds, 8000 images, 3.668904 hours left
# Loaded: 0.000040 seconds
#
#  (next mAP calculation at 200 iterations)
#  126: 2.954783, 4.595154 avg loss, 0.001000 rate, 6.437936 seconds, 8064 images, 3.649175 hours left
# Loaded: 0.000040 seconds
#
#  (next mAP calculation at 200 iterations)
#  127: 3.983597, 4.533998 avg loss, 0.001000 rate, 6.524431 seconds, 8128 images, 3.628313 hours left
# Loaded: 0.000037 seconds
#
#  (next mAP calculation at 200 iterations)
#  128: 3.916351, 4.472234 avg loss, 0.001000 rate, 6.705350 seconds, 8192 images, 3.607852 hours left
# Loaded: 0.000036 seconds
#
#  (next mAP calculation at 200 iterations)
#  129: 6.501113, 4.675122 avg loss, 0.001000 rate, 6.832692 seconds, 8256 images, 3.588015 hours left
# Loaded: 0.000038 seconds
#
#  (next mAP calculation at 200 iterations)
#  130: 3.825460, 4.590156 avg loss, 0.001000 rate, 6.540995 seconds, 8320 images, 3.568666 hours left
# Resizing, random_coef = 1.40
#
#  416 x 416
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.320331 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 200 iterations)
#  131: 4.827562, 4.613896 avg loss, 0.001000 rate, 6.386278 seconds, 8384 images, 3.548787 hours left
# Loaded: 0.000040 seconds
#
#  (next mAP calculation at 200 iterations)
#  132: 5.250701, 4.677577 avg loss, 0.001000 rate, 6.663936 seconds, 8448 images, 3.529488 hours left
# Loaded: 0.000043 seconds
#
#  (next mAP calculation at 200 iterations)
#  133: 3.507555, 4.560575 avg loss, 0.001000 rate, 6.574983 seconds, 8512 images, 3.510261 hours left
# Loaded: 0.000070 seconds
#
#  (next mAP calculation at 200 iterations)
#  134: 3.867187, 4.491236 avg loss, 0.001000 rate, 6.528378 seconds, 8576 images, 3.490993 hours left
# Loaded: 0.000034 seconds
#
#  (next mAP calculation at 200 iterations)
#  135: 5.760092, 4.618122 avg loss, 0.001000 rate, 6.771639 seconds, 8640 images, 3.471788 hours left
# Loaded: 0.000033 seconds
#
#  (next mAP calculation at 200 iterations)
#  136: 5.542219, 4.710531 avg loss, 0.001000 rate, 6.703284 seconds, 8704 images, 3.453341 hours left
# Loaded: 0.000038 seconds
#
#  (next mAP calculation at 200 iterations)
#  137: 4.265750, 4.666053 avg loss, 0.001000 rate, 6.640626 seconds, 8768 images, 3.434896 hours left
# Loaded: 0.000039 seconds
#
#  (next mAP calculation at 200 iterations)
#  138: 5.424685, 4.741917 avg loss, 0.001000 rate, 6.874949 seconds, 8832 images, 3.416466 hours left
# Loaded: 0.000047 seconds
#
#  (next mAP calculation at 200 iterations)
#  139: 5.039303, 4.771655 avg loss, 0.001000 rate, 6.769785 seconds, 8896 images, 3.398763 hours left
# Loaded: 0.000034 seconds
#
#  (next mAP calculation at 200 iterations)
#  140: 3.848043, 4.679294 avg loss, 0.001000 rate, 6.677532 seconds, 8960 images, 3.380966 hours left
# Resizing, random_coef = 1.40
#
#  384 x 384
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.154318 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 200 iterations)
#  141: 7.308849, 4.942250 avg loss, 0.001000 rate, 5.663332 seconds, 9024 images, 3.363109 hours left
# Loaded: 0.000066 seconds
#
#  (next mAP calculation at 200 iterations)
#  142: 4.543406, 4.902365 avg loss, 0.001000 rate, 5.475205 seconds, 9088 images, 3.343359 hours left
# Loaded: 0.000039 seconds
#
#  (next mAP calculation at 200 iterations)
#  143: 5.116211, 4.923750 avg loss, 0.001000 rate, 5.676380 seconds, 9152 images, 3.322975 hours left
# Loaded: 0.000048 seconds
#
#  (next mAP calculation at 200 iterations)
#  144: 5.357561, 4.967131 avg loss, 0.001000 rate, 5.569924 seconds, 9216 images, 3.303258 hours left
# Loaded: 0.000036 seconds
#
#  (next mAP calculation at 200 iterations)
#  145: 7.046180, 5.175036 avg loss, 0.001000 rate, 5.921740 seconds, 9280 images, 3.283470 hours left
# Loaded: 0.000037 seconds
#
#  (next mAP calculation at 200 iterations)
#  146: 5.568387, 5.214371 avg loss, 0.001000 rate, 5.643185 seconds, 9344 images, 3.264700 hours left
# Loaded: 0.000042 seconds
#
#  (next mAP calculation at 200 iterations)
#  147: 3.254808, 5.018415 avg loss, 0.001000 rate, 5.527531 seconds, 9408 images, 3.245440 hours left
# Loaded: 0.000040 seconds
#
#  (next mAP calculation at 200 iterations)
#  148: 4.357245, 4.952298 avg loss, 0.001000 rate, 5.610024 seconds, 9472 images, 3.226082 hours left
# Loaded: 0.000065 seconds
#
#  (next mAP calculation at 200 iterations)
#  149: 3.960603, 4.853128 avg loss, 0.001000 rate, 5.636167 seconds, 9536 images, 3.207099 hours left
# Loaded: 0.000066 seconds
#
#  (next mAP calculation at 200 iterations)
#  150: 3.181508, 4.685966 avg loss, 0.001000 rate, 5.532845 seconds, 9600 images, 3.188351 hours left
# Resizing, random_coef = 1.40
#
#  384 x 384
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.172301 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 200 iterations)
#  151: 4.913167, 4.708687 avg loss, 0.001000 rate, 5.395111 seconds, 9664 images, 3.169532 hours left
# Loaded: 0.000033 seconds
#
#  (next mAP calculation at 200 iterations)
#  152: 3.949087, 4.632727 avg loss, 0.001000 rate, 5.466313 seconds, 9728 images, 3.150966 hours left
# Loaded: 0.000039 seconds
#
#  (next mAP calculation at 200 iterations)
#  153: 4.706669, 4.640121 avg loss, 0.001000 rate, 5.508173 seconds, 9792 images, 3.132333 hours left
# Loaded: 0.000050 seconds
#
#  (next mAP calculation at 200 iterations)
#  154: 4.657998, 4.641909 avg loss, 0.001000 rate, 5.617090 seconds, 9856 images, 3.113969 hours left
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 200 iterations)
#  155: 3.629625, 4.540680 avg loss, 0.001000 rate, 5.533580 seconds, 9920 images, 3.096030 hours left
# Loaded: 0.000037 seconds
#
#  (next mAP calculation at 200 iterations)
#  156: 3.719421, 4.458554 avg loss, 0.001000 rate, 5.547492 seconds, 9984 images, 3.078058 hours left
# Loaded: 0.000053 seconds
#
#  (next mAP calculation at 200 iterations)
#  157: 3.370750, 4.349774 avg loss, 0.001000 rate, 5.387184 seconds, 10048 images, 3.060283 hours left
# Loaded: 0.000062 seconds
#
#  (next mAP calculation at 200 iterations)
#  158: 4.731012, 4.387897 avg loss, 0.001000 rate, 5.695996 seconds, 10112 images, 3.042296 hours left
# Loaded: 0.000032 seconds
#
#  (next mAP calculation at 200 iterations)
#  159: 5.616279, 4.510736 avg loss, 0.001000 rate, 5.558808 seconds, 10176 images, 3.025195 hours left
# Loaded: 0.000059 seconds
#
#  (next mAP calculation at 200 iterations)
#  160: 3.498565, 4.409519 avg loss, 0.001000 rate, 5.478384 seconds, 10240 images, 3.007929 hours left
# Resizing, random_coef = 1.40
#
#  352 x 352
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.336445 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 200 iterations)
#  161: 3.102839, 4.278851 avg loss, 0.001000 rate, 4.758154 seconds, 10304 images, 2.990633 hours left
# Loaded: 0.000053 seconds
#
#  (next mAP calculation at 200 iterations)
#  162: 4.416423, 4.292608 avg loss, 0.001000 rate, 4.906754 seconds, 10368 images, 2.972600 hours left
# Loaded: 0.000052 seconds
#
#  (next mAP calculation at 200 iterations)
#  163: 4.507858, 4.314133 avg loss, 0.001000 rate, 4.896109 seconds, 10432 images, 2.954296 hours left
# Loaded: 0.000037 seconds
#
#  (next mAP calculation at 200 iterations)
#  164: 3.095593, 4.192279 avg loss, 0.001000 rate, 4.731160 seconds, 10496 images, 2.936137 hours left
# Loaded: 0.000038 seconds
#
#  (next mAP calculation at 200 iterations)
#  165: 3.434682, 4.116519 avg loss, 0.001000 rate, 4.739978 seconds, 10560 images, 2.917762 hours left
# Loaded: 0.000039 seconds
#
#  (next mAP calculation at 200 iterations)
#  166: 4.206104, 4.125477 avg loss, 0.001000 rate, 4.932440 seconds, 10624 images, 2.899579 hours left
# Loaded: 0.000035 seconds
#
#  (next mAP calculation at 200 iterations)
#  167: 3.374494, 4.050379 avg loss, 0.001000 rate, 4.761022 seconds, 10688 images, 2.882010 hours left
# Loaded: 0.000032 seconds
#
#  (next mAP calculation at 200 iterations)
#  168: 3.709045, 4.016245 avg loss, 0.001000 rate, 4.896196 seconds, 10752 images, 2.864206 hours left
# Loaded: 0.000038 seconds
#
#  (next mAP calculation at 200 iterations)
#  169: 7.981303, 4.412751 avg loss, 0.001000 rate, 4.886297 seconds, 10816 images, 2.846880 hours left
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 200 iterations)
#  170: 3.889737, 4.360450 avg loss, 0.001000 rate, 4.732638 seconds, 10880 images, 2.829691 hours left
# Resizing, random_coef = 1.40
#
#  416 x 416
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.000040 seconds
#
#  (next mAP calculation at 200 iterations)
#  171: 4.357078, 4.360113 avg loss, 0.001000 rate, 6.312356 seconds, 10944 images, 2.812305 hours left
# Loaded: 0.000033 seconds
#
#  (next mAP calculation at 200 iterations)
#  172: 2.927505, 4.216852 avg loss, 0.001000 rate, 6.595241 seconds, 11008 images, 2.798718 hours left
# Loaded: 0.000070 seconds
#
#  (next mAP calculation at 200 iterations)
#  173: 4.305662, 4.225733 avg loss, 0.001000 rate, 6.652490 seconds, 11072 images, 2.785900 hours left
# Loaded: 0.000034 seconds
#
#  (next mAP calculation at 200 iterations)
#  174: 4.916582, 4.294818 avg loss, 0.001000 rate, 6.621240 seconds, 11136 images, 2.773324 hours left
# Loaded: 0.000068 seconds
#
#  (next mAP calculation at 200 iterations)
#  175: 3.851907, 4.250527 avg loss, 0.001000 rate, 6.713022 seconds, 11200 images, 2.760783 hours left
# Loaded: 0.000041 seconds
#
#  (next mAP calculation at 200 iterations)
#  176: 4.907507, 4.316225 avg loss, 0.001000 rate, 6.622858 seconds, 11264 images, 2.748559 hours left
# Loaded: 0.000066 seconds
#
#  (next mAP calculation at 200 iterations)
#  177: 4.968936, 4.381496 avg loss, 0.001000 rate, 6.696623 seconds, 11328 images, 2.736232 hours left
# Loaded: 0.000042 seconds
#
#  (next mAP calculation at 200 iterations)
#  178: 4.090130, 4.352359 avg loss, 0.001000 rate, 6.649677 seconds, 11392 images, 2.724180 hours left
# Loaded: 0.000030 seconds
#
#  (next mAP calculation at 200 iterations)
#  179: 3.049704, 4.222094 avg loss, 0.001000 rate, 6.627694 seconds, 11456 images, 2.712121 hours left
# Loaded: 0.000036 seconds
#
#  (next mAP calculation at 200 iterations)
#  180: 3.001740, 4.100058 avg loss, 0.001000 rate, 6.504932 seconds, 11520 images, 2.700115 hours left
# Resizing, random_coef = 1.40
#
#  320 x 320
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.379258 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 200 iterations)
#  181: 5.702206, 4.260273 avg loss, 0.001000 rate, 4.194786 seconds, 11584 images, 2.687931 hours left
# Loaded: 0.000037 seconds
#
#  (next mAP calculation at 200 iterations)
#  182: 5.747798, 4.409026 avg loss, 0.001000 rate, 4.256802 seconds, 11648 images, 2.671457 hours left
# Loaded: 0.000062 seconds
#
#  (next mAP calculation at 200 iterations)
#  183: 3.908251, 4.358948 avg loss, 0.001000 rate, 4.157947 seconds, 11712 images, 2.654415 hours left
# Loaded: 0.000031 seconds
#
#  (next mAP calculation at 200 iterations)
#  184: 2.882147, 4.211268 avg loss, 0.001000 rate, 4.127356 seconds, 11776 images, 2.637308 hours left
# Loaded: 0.000056 seconds
#
#  (next mAP calculation at 200 iterations)
#  185: 3.897665, 4.179908 avg loss, 0.001000 rate, 4.146581 seconds, 11840 images, 2.620290 hours left
# Loaded: 0.000050 seconds
#
#  (next mAP calculation at 200 iterations)
#  186: 3.589391, 4.120856 avg loss, 0.001000 rate, 4.247701 seconds, 11904 images, 2.603475 hours left
# Loaded: 0.000037 seconds
#
#  (next mAP calculation at 200 iterations)
#  187: 3.927070, 4.101478 avg loss, 0.001000 rate, 4.082577 seconds, 11968 images, 2.587045 hours left
# Loaded: 0.000056 seconds
#
#  (next mAP calculation at 200 iterations)
#  188: 3.294232, 4.020753 avg loss, 0.001000 rate, 4.136813 seconds, 12032 images, 2.570394 hours left
# Loaded: 0.000032 seconds
#
#  (next mAP calculation at 200 iterations)
#  189: 4.450720, 4.063750 avg loss, 0.001000 rate, 4.294865 seconds, 12096 images, 2.554021 hours left
# Loaded: 0.000064 seconds
#
#  (next mAP calculation at 200 iterations)
#  190: 4.453426, 4.102717 avg loss, 0.001000 rate, 4.221629 seconds, 12160 images, 2.538156 hours left
# Resizing, random_coef = 1.40
#
#  384 x 384
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.000031 seconds
#
#  (next mAP calculation at 200 iterations)
#  191: 3.094174, 4.001863 avg loss, 0.001000 rate, 5.357404 seconds, 12224 images, 2.522274 hours left
# Loaded: 0.000056 seconds
#
#  (next mAP calculation at 200 iterations)
#  192: 3.603162, 3.961993 avg loss, 0.001000 rate, 5.399774 seconds, 12288 images, 2.509090 hours left
# Loaded: 0.000041 seconds
#
#  (next mAP calculation at 200 iterations)
#  193: 3.623194, 3.928113 avg loss, 0.001000 rate, 5.521937 seconds, 12352 images, 2.496119 hours left
# Loaded: 0.000031 seconds
#
#  (next mAP calculation at 200 iterations)
#  194: 3.477001, 3.883002 avg loss, 0.001000 rate, 5.414464 seconds, 12416 images, 2.483536 hours left
# Loaded: 0.000038 seconds
#
#  (next mAP calculation at 200 iterations)
#  195: 3.451392, 3.839841 avg loss, 0.001000 rate, 5.495041 seconds, 12480 images, 2.470823 hours left
# Loaded: 0.000039 seconds
#
#  (next mAP calculation at 200 iterations)
#  196: 4.564650, 3.912322 avg loss, 0.001000 rate, 5.740934 seconds, 12544 images, 2.458403 hours left
# Loaded: 0.000062 seconds
#
#  (next mAP calculation at 200 iterations)
#  197: 4.101742, 3.931264 avg loss, 0.001000 rate, 5.545570 seconds, 12608 images, 2.446640 hours left
# Loaded: 0.000060 seconds
#
#  (next mAP calculation at 200 iterations)
#  198: 4.091886, 3.947326 avg loss, 0.001000 rate, 5.495970 seconds, 12672 images, 2.434544 hours left
# Loaded: 0.000043 seconds
#
#  (next mAP calculation at 200 iterations)
#  199: 3.043256, 3.856919 avg loss, 0.001000 rate, 5.513284 seconds, 12736 images, 2.422442 hours left
# Loaded: 0.000043 seconds
#
#  (next mAP calculation at 200 iterations)
#  200: 3.251149, 3.796342 avg loss, 0.001000 rate, 5.539914 seconds, 12800 images, 2.410485 hours left
# Resizing to initial size: 416 x 416  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
#
#  calculation mAP (mean average precision)...
#
#  detections_count = 27498, unique_truth_count = 2147
# class_id = 0, name = Mask, ap = 16.64%   	 (TP = 7, FP = 1)
# class_id = 1, name = No_mask, ap = 0.88%   	 (TP = 0, FP = 1)
#
#  for conf_thresh = 0.25, precision = 0.78, recall = 0.00, F1-score = 0.01
#  for conf_thresh = 0.25, TP = 7, FP = 2, FN = 2140, average IoU = 51.86 %
#
#  IoU threshold = 50 %, used Area-Under-Curve for each unique Recall
#  mean average precision (mAP@0.50) = 0.087589, or 8.76 %
#
# Set -points flag:
#  `-points 101` for MS COCO
#  `-points 11` for PascalVOC 2007 (uncomment `difficult` in voc.data)
#  `-points 0` (AUC) for ImageNet, PascalVOC 2010-2012, your custom dataset
#
#  mean_average_precision (mAP@0.5) = 0.087589
# New best mAP!
# Resizing, random_coef = 1.40
#
#  416 x 416
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.179089 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  201: 4.309894, 3.847697 avg loss, 0.001000 rate, 6.589109 seconds, 12864 images, 2.424488 hours left
# Loaded: 0.000037 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  202: 7.601918, 4.223120 avg loss, 0.001000 rate, 7.058351 seconds, 12928 images, 2.415264 hours left
# Loaded: 0.000039 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  203: 4.959010, 4.296709 avg loss, 0.001000 rate, 6.936309 seconds, 12992 images, 2.406758 hours left
# Loaded: 0.000030 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  204: 3.580443, 4.225082 avg loss, 0.001000 rate, 6.621549 seconds, 13056 images, 2.398047 hours left
# Loaded: 0.000033 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  205: 2.928246, 4.095398 avg loss, 0.001000 rate, 6.533665 seconds, 13120 images, 2.388707 hours left
# Loaded: 0.000036 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  206: 3.885822, 4.074441 avg loss, 0.001000 rate, 6.505991 seconds, 13184 images, 2.379249 hours left
# Loaded: 0.000041 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  207: 2.817707, 3.948767 avg loss, 0.001000 rate, 6.436347 seconds, 13248 images, 2.369806 hours left
# Loaded: 0.000041 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  208: 3.866558, 3.940547 avg loss, 0.001000 rate, 6.679081 seconds, 13312 images, 2.360286 hours left
# Loaded: 0.000041 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  209: 5.089362, 4.055428 avg loss, 0.001000 rate, 6.620259 seconds, 13376 images, 2.351377 hours left
# Loaded: 0.000038 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  210: 3.809838, 4.030869 avg loss, 0.001000 rate, 6.741152 seconds, 13440 images, 2.342409 hours left
# Resizing, random_coef = 1.40
#
#  352 x 352
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.384014 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  211: 4.082937, 4.036076 avg loss, 0.001000 rate, 4.771084 seconds, 13504 images, 2.333779 hours left
# Loaded: 0.000031 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  212: 3.654853, 3.997953 avg loss, 0.001000 rate, 4.938183 seconds, 13568 images, 2.321739 hours left
# Loaded: 0.000042 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  213: 7.157823, 4.313941 avg loss, 0.001000 rate, 4.870680 seconds, 13632 images, 2.309331 hours left
# Loaded: 0.000044 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  214: 3.772378, 4.259784 avg loss, 0.001000 rate, 4.842664 seconds, 13696 images, 2.296886 hours left
# Loaded: 0.000040 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  215: 4.467148, 4.280520 avg loss, 0.001000 rate, 4.965055 seconds, 13760 images, 2.284490 hours left
# Loaded: 0.000038 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  216: 4.179401, 4.270409 avg loss, 0.001000 rate, 4.791432 seconds, 13824 images, 2.272472 hours left
# Loaded: 0.000055 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  217: 2.804961, 4.123864 avg loss, 0.001000 rate, 4.751854 seconds, 13888 images, 2.260182 hours left
# Loaded: 0.000056 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  218: 2.679247, 3.979402 avg loss, 0.001000 rate, 4.767909 seconds, 13952 images, 2.247915 hours left
# Loaded: 0.000082 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  219: 4.943629, 4.075825 avg loss, 0.001000 rate, 4.966795 seconds, 14016 images, 2.235793 hours left
# Loaded: 0.000040 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  220: 3.884589, 4.056701 avg loss, 0.001000 rate, 4.894017 seconds, 14080 images, 2.224211 hours left
# Resizing, random_coef = 1.40
#
#  512 x 512
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.000029 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  221: 4.585454, 4.109576 avg loss, 0.001000 rate, 8.940525 seconds, 14144 images, 2.212572 hours left
# Loaded: 0.000030 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  222: 3.935333, 4.092152 avg loss, 0.001000 rate, 8.919354 seconds, 14208 images, 2.209793 hours left
# Loaded: 0.000041 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  223: 3.783781, 4.061315 avg loss, 0.001000 rate, 8.893865 seconds, 14272 images, 2.206971 hours left
# Loaded: 0.000047 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  224: 2.940169, 3.949200 avg loss, 0.001000 rate, 8.828887 seconds, 14336 images, 2.204097 hours left
# Loaded: 0.000061 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  225: 2.704666, 3.824747 avg loss, 0.001000 rate, 8.745441 seconds, 14400 images, 2.201088 hours left
# Loaded: 0.000032 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  226: 2.969678, 3.739240 avg loss, 0.001000 rate, 8.796735 seconds, 14464 images, 2.197904 hours left
# Loaded: 0.000044 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  227: 4.673482, 3.832664 avg loss, 0.001000 rate, 9.207859 seconds, 14528 images, 2.194838 hours left
# Loaded: 0.000036 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  228: 3.036496, 3.753047 avg loss, 0.001000 rate, 8.863370 seconds, 14592 images, 2.192661 hours left
# Loaded: 0.000094 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  229: 3.585020, 3.736244 avg loss, 0.001000 rate, 9.078562 seconds, 14656 images, 2.189741 hours left
# Loaded: 0.000037 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  230: 3.828990, 3.745519 avg loss, 0.001000 rate, 8.987553 seconds, 14720 images, 2.187288 hours left
# Resizing, random_coef = 1.40
#
#  352 x 352
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.000039 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  231: 4.125988, 3.783566 avg loss, 0.001000 rate, 4.837300 seconds, 14784 images, 2.184638 hours left
# Loaded: 0.000062 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  232: 2.893802, 3.694590 avg loss, 0.001000 rate, 4.780269 seconds, 14848 images, 2.173125 hours left
# Loaded: 0.000033 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  233: 5.036883, 3.828819 avg loss, 0.001000 rate, 4.881845 seconds, 14912 images, 2.161592 hours left
# Loaded: 0.000066 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  234: 3.366798, 3.782617 avg loss, 0.001000 rate, 4.810110 seconds, 14976 images, 2.150377 hours left
# Loaded: 0.000040 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  235: 5.854435, 3.989799 avg loss, 0.001000 rate, 5.003113 seconds, 15040 images, 2.139108 hours left
# Loaded: 0.000039 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  236: 4.362538, 4.027073 avg loss, 0.001000 rate, 5.039866 seconds, 15104 images, 2.128349 hours left
# Loaded: 0.000060 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  237: 4.384258, 4.062791 avg loss, 0.001000 rate, 4.838880 seconds, 15168 images, 2.117761 hours left
# Loaded: 0.000051 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  238: 4.752732, 4.131785 avg loss, 0.001000 rate, 4.965923 seconds, 15232 images, 2.106839 hours left
# Loaded: 0.000036 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  239: 5.952242, 4.313831 avg loss, 0.001000 rate, 5.191684 seconds, 15296 images, 2.096282 hours left
# Loaded: 0.000029 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  240: 3.712015, 4.253650 avg loss, 0.001000 rate, 4.947694 seconds, 15360 images, 2.086294 hours left
# Resizing, random_coef = 1.40
#
#  576 x 576
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.000043 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  241: 4.537912, 4.282076 avg loss, 0.001000 rate, 11.993746 seconds, 15424 images, 2.075876 hours left
# Loaded: 0.000060 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  242: 3.281843, 4.182053 avg loss, 0.001000 rate, 12.105050 seconds, 15488 images, 2.080405 hours left
# Loaded: 0.000033 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  243: 4.287544, 4.192602 avg loss, 0.001000 rate, 12.189396 seconds, 15552 images, 2.085089 hours left
# Loaded: 0.000031 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  244: 4.989669, 4.272308 avg loss, 0.001000 rate, 12.617675 seconds, 15616 images, 2.089869 hours left
# Loaded: 0.000039 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  245: 2.983034, 4.143381 avg loss, 0.001000 rate, 12.072522 seconds, 15680 images, 2.095468 hours left
# Loaded: 0.000036 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  246: 4.285878, 4.157631 avg loss, 0.001000 rate, 12.471657 seconds, 15744 images, 2.099832 hours left
# Loaded: 0.000044 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  247: 4.412937, 4.183162 avg loss, 0.001000 rate, 12.185995 seconds, 15808 images, 2.104955 hours left
# Loaded: 0.000041 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  248: 5.840869, 4.348932 avg loss, 0.001000 rate, 12.542999 seconds, 15872 images, 2.109395 hours left
# Loaded: 0.000042 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  249: 3.520226, 4.266062 avg loss, 0.001000 rate, 12.040106 seconds, 15936 images, 2.114502 hours left
# Loaded: 0.000041 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  250: 4.209439, 4.260399 avg loss, 0.001000 rate, 12.137642 seconds, 16000 images, 2.118474 hours left
# Resizing, random_coef = 1.40
#
#  320 x 320
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.000039 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  251: 3.777838, 4.212143 avg loss, 0.001000 rate, 4.058798 seconds, 16064 images, 2.122576 hours left
# Loaded: 0.000066 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  252: 4.316487, 4.222578 avg loss, 0.001000 rate, 4.296313 seconds, 16128 images, 2.109795 hours left
# Loaded: 0.000038 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  253: 4.617077, 4.262028 avg loss, 0.001000 rate, 4.313811 seconds, 16192 images, 2.097624 hours left
# Loaded: 0.000031 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  254: 4.556008, 4.291426 avg loss, 0.001000 rate, 4.257202 seconds, 16256 images, 2.085599 hours left
# Loaded: 0.000039 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  255: 5.540060, 4.416289 avg loss, 0.001000 rate, 4.262082 seconds, 16320 images, 2.073565 hours left
# Loaded: 0.000040 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  256: 3.833507, 4.358011 avg loss, 0.001000 rate, 4.150755 seconds, 16384 images, 2.061649 hours left
# Loaded: 0.000037 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  257: 5.918640, 4.514074 avg loss, 0.001000 rate, 4.269249 seconds, 16448 images, 2.049611 hours left
# Loaded: 0.000035 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  258: 6.621081, 4.724775 avg loss, 0.001000 rate, 4.315999 seconds, 16512 images, 2.037926 hours left
# Loaded: 0.000040 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  259: 4.397020, 4.691999 avg loss, 0.001000 rate, 4.220776 seconds, 16576 images, 2.026443 hours left
# Loaded: 0.000033 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  260: 3.706016, 4.593401 avg loss, 0.001000 rate, 4.172901 seconds, 16640 images, 2.014867 hours left
# Resizing, random_coef = 1.40
#
#  480 x 480
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.000057 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  261: 3.558029, 4.489864 avg loss, 0.001000 rate, 7.898216 seconds, 16704 images, 2.003296 hours left
# Loaded: 0.000043 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  262: 4.639965, 4.504874 avg loss, 0.001000 rate, 8.339224 seconds, 16768 images, 1.999476 hours left
# Loaded: 0.000064 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  263: 3.520859, 4.406473 avg loss, 0.001000 rate, 8.307261 seconds, 16832 images, 1.996577 hours left
# Loaded: 0.000039 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  264: 3.034981, 4.269323 avg loss, 0.001000 rate, 8.252919 seconds, 16896 images, 1.993618 hours left
# Loaded: 0.000033 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  265: 4.667277, 4.309119 avg loss, 0.001000 rate, 8.407846 seconds, 16960 images, 1.990555 hours left
# Loaded: 0.000063 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  266: 3.725351, 4.250742 avg loss, 0.001000 rate, 8.133134 seconds, 17024 images, 1.987815 hours left
# Loaded: 0.000039 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  267: 3.496520, 4.175320 avg loss, 0.001000 rate, 8.319264 seconds, 17088 images, 1.984520 hours left
# Loaded: 0.000074 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  268: 4.575720, 4.215360 avg loss, 0.001000 rate, 8.374672 seconds, 17152 images, 1.981613 hours left
# Loaded: 0.000066 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  269: 2.929432, 4.086767 avg loss, 0.001000 rate, 8.090645 seconds, 17216 images, 1.978826 hours left
# Loaded: 0.000071 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  270: 3.658545, 4.043945 avg loss, 0.001000 rate, 8.347530 seconds, 17280 images, 1.975466 hours left
# Resizing, random_coef = 1.40
#
#  320 x 320
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.000040 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  271: 3.628994, 4.002450 avg loss, 0.001000 rate, 4.003601 seconds, 17344 images, 1.972639 hours left
# Loaded: 0.000039 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  272: 3.627197, 3.964924 avg loss, 0.001000 rate, 4.062679 seconds, 17408 images, 1.961020 hours left
# Loaded: 0.000062 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  273: 3.638465, 3.932278 avg loss, 0.001000 rate, 4.174236 seconds, 17472 images, 1.949625 hours left
# Loaded: 0.000068 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  274: 3.980598, 3.937110 avg loss, 0.001000 rate, 4.211878 seconds, 17536 images, 1.938559 hours left
# Loaded: 0.000031 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  275: 4.037346, 3.947134 avg loss, 0.001000 rate, 4.148137 seconds, 17600 images, 1.927667 hours left
# Loaded: 0.000050 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  276: 4.771737, 4.029594 avg loss, 0.001000 rate, 4.207236 seconds, 17664 images, 1.916745 hours left
# Loaded: 0.000038 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  277: 3.897143, 4.016349 avg loss, 0.001000 rate, 4.259665 seconds, 17728 images, 1.906039 hours left
# Loaded: 0.000053 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  278: 4.580794, 4.072794 avg loss, 0.001000 rate, 4.172008 seconds, 17792 images, 1.895533 hours left
# Loaded: 0.000055 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  279: 5.418680, 4.207383 avg loss, 0.001000 rate, 4.194318 seconds, 17856 images, 1.884945 hours left
# Loaded: 0.000041 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  280: 3.717220, 4.158366 avg loss, 0.001000 rate, 4.173191 seconds, 17920 images, 1.874496 hours left
# Resizing, random_coef = 1.40
#
#  416 x 416
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.000070 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  281: 4.055884, 4.148118 avg loss, 0.001000 rate, 6.691238 seconds, 17984 images, 1.864098 hours left
# Loaded: 0.000038 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  282: 4.230536, 4.156360 avg loss, 0.001000 rate, 6.573117 seconds, 18048 images, 1.858821 hours left
# Loaded: 0.000037 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  283: 3.033248, 4.044048 avg loss, 0.001000 rate, 6.585577 seconds, 18112 images, 1.853342 hours left
# Loaded: 0.000042 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  284: 4.887750, 4.128418 avg loss, 0.001000 rate, 6.588942 seconds, 18176 images, 1.847925 hours left
# Loaded: 0.000060 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  285: 4.914938, 4.207070 avg loss, 0.001000 rate, 6.755255 seconds, 18240 images, 1.842551 hours left
# Loaded: 0.000032 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  286: 4.558875, 4.242251 avg loss, 0.001000 rate, 6.724903 seconds, 18304 images, 1.837542 hours left
# Loaded: 0.000064 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  287: 3.193122, 4.137338 avg loss, 0.001000 rate, 6.653880 seconds, 18368 images, 1.832504 hours left
# Loaded: 0.000065 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  288: 5.746340, 4.298238 avg loss, 0.001000 rate, 6.764541 seconds, 18432 images, 1.827358 hours left
# Loaded: 0.000044 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  289: 5.048156, 4.373230 avg loss, 0.001000 rate, 6.745571 seconds, 18496 images, 1.822463 hours left
# Loaded: 0.000062 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  290: 3.921978, 4.328105 avg loss, 0.001000 rate, 6.597217 seconds, 18560 images, 1.817561 hours left
# Resizing, random_coef = 1.40
#
#  512 x 512
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.000039 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  291: 3.833544, 4.278649 avg loss, 0.001000 rate, 8.776916 seconds, 18624 images, 1.812397 hours left
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  292: 2.561066, 4.106891 avg loss, 0.001000 rate, 8.777216 seconds, 18688 images, 1.811559 hours left
# Loaded: 0.000050 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  293: 3.170231, 4.013225 avg loss, 0.001000 rate, 9.035653 seconds, 18752 images, 1.810705 hours left
# Loaded: 0.000040 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  294: 2.675990, 3.879501 avg loss, 0.001000 rate, 8.833615 seconds, 18816 images, 1.810343 hours left
# Loaded: 0.000062 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  295: 3.574402, 3.848991 avg loss, 0.001000 rate, 8.948217 seconds, 18880 images, 1.809564 hours left
# Loaded: 0.000038 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  296: 3.151358, 3.779228 avg loss, 0.001000 rate, 8.860066 seconds, 18944 images, 1.808992 hours left
# Loaded: 0.000044 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  297: 2.567957, 3.658101 avg loss, 0.001000 rate, 8.694600 seconds, 19008 images, 1.808228 hours left
# Loaded: 0.000042 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  298: 4.005757, 3.692866 avg loss, 0.001000 rate, 9.036046 seconds, 19072 images, 1.807125 hours left
# Loaded: 0.000042 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  299: 3.014886, 3.625068 avg loss, 0.001000 rate, 8.746841 seconds, 19136 images, 1.806674 hours left
# Loaded: 0.000062 seconds
#
#  (next mAP calculation at 300 iterations)
#  Last accuracy mAP@0.5 = 8.76 %, best = 8.76 %
#  300: 2.989415, 3.561503 avg loss, 0.001000 rate, 8.815786 seconds, 19200 images, 1.805639 hours left
# Resizing to initial size: 416 x 416  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
#
#  calculation mAP (mean average precision)...
#
#  detections_count = 22266, unique_truth_count = 2147
# class_id = 0, name = Mask, ap = 21.99%   	 (TP = 22, FP = 0)
# class_id = 1, name = No_mask, ap = 1.44%   	 (TP = 0, FP = 4)
#
#  for conf_thresh = 0.25, precision = 0.85, recall = 0.01, F1-score = 0.02
#  for conf_thresh = 0.25, TP = 22, FP = 4, FN = 2125, average IoU = 60.32 %
#
#  IoU threshold = 50 %, used Area-Under-Curve for each unique Recall
#  mean average precision (mAP@0.50) = 0.117135, or 11.71 %
#
# Set -points flag:
#  `-points 101` for MS COCO
#  `-points 11` for PascalVOC 2007 (uncomment `difficult` in voc.data)
#  `-points 0` (AUC) for ImageNet, PascalVOC 2010-2012, your custom dataset
#
#  mean_average_precision (mAP@0.5) = 0.117135
# New best mAP!
# Resizing, random_coef = 1.40
#
#  512 x 512
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.000041 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 11.71 %, best = 11.71 %
#  301: 4.317978, 3.637151 avg loss, 0.001000 rate, 8.996173 seconds, 19264 images, 1.825921 hours left
# Loaded: 0.000064 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 11.71 %, best = 11.71 %
#  302: 4.325116, 3.705947 avg loss, 0.001000 rate, 9.117232 seconds, 19328 images, 1.825130 hours left
# Loaded: 0.000067 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 11.71 %, best = 11.71 %
#  303: 4.450467, 3.780399 avg loss, 0.001000 rate, 9.203430 seconds, 19392 images, 1.824556 hours left
# Loaded: 0.000042 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 11.71 %, best = 11.71 %
#  304: 4.686920, 3.871051 avg loss, 0.001000 rate, 9.153901 seconds, 19456 images, 1.824129 hours left
# Loaded: 0.000041 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 11.71 %, best = 11.71 %
#  305: 4.221368, 3.906083 avg loss, 0.001000 rate, 8.934279 seconds, 19520 images, 1.823586 hours left
# Loaded: 0.000061 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 11.71 %, best = 11.71 %
#  306: 3.244593, 3.839934 avg loss, 0.001000 rate, 8.942147 seconds, 19584 images, 1.822598 hours left
# Loaded: 0.000035 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 11.71 %, best = 11.71 %
#  307: 3.089503, 3.764891 avg loss, 0.001000 rate, 9.091351 seconds, 19648 images, 1.821611 hours left
# Loaded: 0.000039 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 11.71 %, best = 11.71 %
#  308: 2.534082, 3.641810 avg loss, 0.001000 rate, 8.752240 seconds, 19712 images, 1.820896 hours left
# Loaded: 0.000065 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 11.71 %, best = 11.71 %
#  309: 3.490097, 3.626639 avg loss, 0.001000 rate, 9.170873 seconds, 19776 images, 1.819511 hours left
# Loaded: 0.000076 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 11.71 %, best = 11.71 %
#  310: 4.602934, 3.724268 avg loss, 0.001000 rate, 9.127569 seconds, 19840 images, 1.818919 hours left
# Resizing, random_coef = 1.40
#
#  352 x 352
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.000043 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 11.71 %, best = 11.71 %
#  311: 3.057271, 3.657568 avg loss, 0.001000 rate, 4.696442 seconds, 19904 images, 1.818224 hours left
# Loaded: 0.000032 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 11.71 %, best = 11.71 %
#  312: 3.300337, 3.621845 avg loss, 0.001000 rate, 4.804915 seconds, 19968 images, 1.809030 hours left
# Loaded: 0.000039 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 11.71 %, best = 11.71 %
#  313: 5.923702, 3.852031 avg loss, 0.001000 rate, 5.002067 seconds, 20032 images, 1.800123 hours left
# Loaded: 0.000065 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 11.71 %, best = 11.71 %
#  314: 4.539453, 3.920773 avg loss, 0.001000 rate, 4.991549 seconds, 20096 images, 1.791667 hours left
# Loaded: 0.000034 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 11.71 %, best = 11.71 %
#  315: 3.908153, 3.919511 avg loss, 0.001000 rate, 4.851557 seconds, 20160 images, 1.783262 hours left
# Loaded: 0.000048 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 11.71 %, best = 11.71 %
#  316: 3.657126, 3.893273 avg loss, 0.001000 rate, 4.815122 seconds, 20224 images, 1.774661 hours left
# Loaded: 0.000031 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 11.71 %, best = 11.71 %
#  317: 3.894261, 3.893372 avg loss, 0.001000 rate, 4.897452 seconds, 20288 images, 1.766064 hours left
# Loaded: 0.000064 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 11.71 %, best = 11.71 %
#  318: 4.329999, 3.937034 avg loss, 0.001000 rate, 4.965464 seconds, 20352 images, 1.757695 hours left
# Loaded: 0.000063 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 11.71 %, best = 11.71 %
#  319: 6.474605, 4.190792 avg loss, 0.001000 rate, 4.973665 seconds, 20416 images, 1.749525 hours left
# Loaded: 0.000068 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 11.71 %, best = 11.71 %
#  320: 4.201326, 4.191845 avg loss, 0.001000 rate, 5.128617 seconds, 20480 images, 1.741438 hours left
# Resizing, random_coef = 1.40
#
#  416 x 416
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.000060 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 11.71 %, best = 11.71 %
#  321: 4.813189, 4.253979 avg loss, 0.001000 rate, 6.594984 seconds, 20544 images, 1.733711 hours left
# Loaded: 0.000062 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 11.71 %, best = 11.71 %
#  322: 5.022575, 4.330839 avg loss, 0.001000 rate, 6.706804 seconds, 20608 images, 1.728813 hours left
# Loaded: 0.000041 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 11.71 %, best = 11.71 %
#  323: 3.263245, 4.224079 avg loss, 0.001000 rate, 6.527565 seconds, 20672 images, 1.724156 hours left
# Loaded: 0.000066 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 11.71 %, best = 11.71 %
#  324: 3.559993, 4.157670 avg loss, 0.001000 rate, 6.659873 seconds, 20736 images, 1.719190 hours left
# Loaded: 0.000049 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 11.71 %, best = 11.71 %
#  325: 4.935137, 4.235417 avg loss, 0.001000 rate, 6.608086 seconds, 20800 images, 1.714504 hours left
# Loaded: 0.000047 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 11.71 %, best = 11.71 %
#  326: 3.657372, 4.177613 avg loss, 0.001000 rate, 6.664289 seconds, 20864 images, 1.709749 hours left
# Loaded: 0.000040 seconds
#
#  (next mAP calculation at 400 iterations)
#  Last accuracy mAP@0.5 = 11.71 %, best = 11.71 %
#  327: 3.732100, 4.133061 avg loss, 0.001000 rate, 6.661228 seconds, 20928 images, 1.705129 hours left
# Loaded: 0.000053 seconds
#
#  (next mAP calculation at 400 iterations)
# ...
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  937: 2.924345, 2.731714 avg loss, 0.000100 rate, 13.571803 seconds, 59968 images, 0.434622 hours left
# Loaded: 0.000043 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  938: 2.870510, 2.745593 avg loss, 0.000100 rate, 13.829679 seconds, 60032 images, 0.432651 hours left
# Loaded: 0.000041 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  939: 2.353158, 2.706350 avg loss, 0.000100 rate, 13.557131 seconds, 60096 images, 0.430706 hours left
# Loaded: 0.000035 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  940: 3.085320, 2.744247 avg loss, 0.000100 rate, 13.451024 seconds, 60160 images, 0.428696 hours left
# Resizing, random_coef = 1.40
#
#  608 x 608
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.162277 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  941: 2.891900, 2.759012 avg loss, 0.000100 rate, 13.175414 seconds, 60224 images, 0.426651 hours left
# Loaded: 0.000062 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  942: 2.835418, 2.766653 avg loss, 0.000100 rate, 13.598548 seconds, 60288 images, 0.424570 hours left
# Loaded: 0.000035 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  943: 1.812501, 2.671238 avg loss, 0.000100 rate, 13.266275 seconds, 60352 images, 0.422516 hours left
# Loaded: 0.000040 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  944: 2.750981, 2.679212 avg loss, 0.000100 rate, 13.315746 seconds, 60416 images, 0.420391 hours left
# Loaded: 0.000038 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  945: 1.959201, 2.607211 avg loss, 0.000100 rate, 13.225076 seconds, 60480 images, 0.418258 hours left
# Loaded: 0.000037 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  946: 2.302502, 2.576740 avg loss, 0.000100 rate, 13.289486 seconds, 60544 images, 0.416096 hours left
# Loaded: 0.000038 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  947: 1.853194, 2.504386 avg loss, 0.000100 rate, 13.061419 seconds, 60608 images, 0.413929 hours left
# Loaded: 0.000043 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  948: 3.387636, 2.592711 avg loss, 0.000100 rate, 13.746056 seconds, 60672 images, 0.411712 hours left
# Loaded: 0.000041 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  949: 1.375308, 2.470970 avg loss, 0.000100 rate, 13.373575 seconds, 60736 images, 0.409581 hours left
# Loaded: 0.000051 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  950: 1.928021, 2.416676 avg loss, 0.000100 rate, 13.523603 seconds, 60800 images, 0.407380 hours left
# Resizing, random_coef = 1.40
#
#  608 x 608
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.000035 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  951: 2.001081, 2.375116 avg loss, 0.000100 rate, 13.182624 seconds, 60864 images, 0.405184 hours left
# Loaded: 0.000037 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  952: 3.381563, 2.475761 avg loss, 0.000100 rate, 13.595821 seconds, 60928 images, 0.402927 hours left
# Loaded: 0.000066 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  953: 2.444356, 2.472620 avg loss, 0.000100 rate, 13.545195 seconds, 60992 images, 0.400710 hours left
# Loaded: 0.000053 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  954: 1.956620, 2.421021 avg loss, 0.000100 rate, 13.502331 seconds, 61056 images, 0.398471 hours left
# Loaded: 0.000031 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  955: 3.335852, 2.512504 avg loss, 0.000100 rate, 13.702410 seconds, 61120 images, 0.396212 hours left
# Loaded: 0.000040 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  956: 2.546920, 2.515945 avg loss, 0.000100 rate, 13.601811 seconds, 61184 images, 0.393963 hours left
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  957: 3.123635, 2.576714 avg loss, 0.000100 rate, 13.600462 seconds, 61248 images, 0.391685 hours left
# Loaded: 0.000037 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  958: 2.738961, 2.592939 avg loss, 0.000100 rate, 13.500671 seconds, 61312 images, 0.389393 hours left
# Loaded: 0.000032 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  959: 2.559400, 2.589585 avg loss, 0.000100 rate, 13.429500 seconds, 61376 images, 0.387074 hours left
# Loaded: 0.000052 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  960: 2.044367, 2.535063 avg loss, 0.000100 rate, 13.695243 seconds, 61440 images, 0.384733 hours left
# Resizing, random_coef = 1.40
#
#  608 x 608
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.000038 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  961: 3.029931, 2.584550 avg loss, 0.000100 rate, 13.478102 seconds, 61504 images, 0.382407 hours left
# Loaded: 0.000062 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  962: 2.422367, 2.568332 avg loss, 0.000100 rate, 13.413874 seconds, 61568 images, 0.380043 hours left
# Loaded: 0.000040 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  963: 3.605245, 2.672023 avg loss, 0.000100 rate, 13.642139 seconds, 61632 images, 0.377659 hours left
# Loaded: 0.000036 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  964: 3.027494, 2.707570 avg loss, 0.000100 rate, 13.528262 seconds, 61696 images, 0.375284 hours left
# Loaded: 0.000051 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  965: 1.858440, 2.622657 avg loss, 0.000100 rate, 13.632119 seconds, 61760 images, 0.372884 hours left
# Loaded: 0.000042 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  966: 4.060593, 2.766451 avg loss, 0.000100 rate, 13.648071 seconds, 61824 images, 0.370481 hours left
# Loaded: 0.000039 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  967: 2.402150, 2.730021 avg loss, 0.000100 rate, 13.695970 seconds, 61888 images, 0.368065 hours left
# Loaded: 0.000037 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  968: 2.931955, 2.750214 avg loss, 0.000100 rate, 13.690752 seconds, 61952 images, 0.365640 hours left
# Loaded: 0.000040 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  969: 2.131509, 2.688344 avg loss, 0.000100 rate, 13.524943 seconds, 62016 images, 0.363200 hours left
# Loaded: 0.000078 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  970: 2.112009, 2.630710 avg loss, 0.000100 rate, 13.344339 seconds, 62080 images, 0.360733 hours left
# Resizing, random_coef = 1.40
#
#  608 x 608
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.141559 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  971: 2.444239, 2.612063 avg loss, 0.000100 rate, 13.673600 seconds, 62144 images, 0.358238 hours left
# Loaded: 0.000051 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  972: 3.289415, 2.679798 avg loss, 0.000100 rate, 13.877522 seconds, 62208 images, 0.355768 hours left
# Loaded: 0.000033 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  973: 2.779868, 2.689805 avg loss, 0.000100 rate, 13.439691 seconds, 62272 images, 0.353290 hours left
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  974: 2.266460, 2.647471 avg loss, 0.000100 rate, 13.708396 seconds, 62336 images, 0.350765 hours left
# Loaded: 0.000043 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  975: 2.244275, 2.607151 avg loss, 0.000100 rate, 13.698934 seconds, 62400 images, 0.348248 hours left
# Loaded: 0.000042 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  976: 1.905655, 2.537002 avg loss, 0.000100 rate, 13.055792 seconds, 62464 images, 0.345716 hours left
# Loaded: 0.000042 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  977: 1.805235, 2.463825 avg loss, 0.000100 rate, 13.438112 seconds, 62528 images, 0.343130 hours left
# Loaded: 0.000061 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  978: 2.352204, 2.452663 avg loss, 0.000100 rate, 13.274088 seconds, 62592 images, 0.340557 hours left
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  979: 1.961070, 2.403504 avg loss, 0.000100 rate, 13.417400 seconds, 62656 images, 0.337962 hours left
# Loaded: 0.000043 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  980: 2.414209, 2.404574 avg loss, 0.000100 rate, 13.521250 seconds, 62720 images, 0.335366 hours left
# Resizing, random_coef = 1.40
#
#  608 x 608
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.004071 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  981: 2.597615, 2.423878 avg loss, 0.000100 rate, 13.352992 seconds, 62784 images, 0.332763 hours left
# Loaded: 0.000041 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  982: 2.913590, 2.472849 avg loss, 0.000100 rate, 13.763250 seconds, 62848 images, 0.330140 hours left
# Loaded: 0.000040 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  983: 2.161124, 2.441677 avg loss, 0.000100 rate, 13.787112 seconds, 62912 images, 0.327527 hours left
# Loaded: 0.000059 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  984: 3.922202, 2.589729 avg loss, 0.000100 rate, 13.773201 seconds, 62976 images, 0.324903 hours left
# Loaded: 0.000056 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  985: 3.425578, 2.673314 avg loss, 0.000100 rate, 13.643309 seconds, 63040 images, 0.322266 hours left
# Loaded: 0.000074 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  986: 2.355773, 2.641560 avg loss, 0.000100 rate, 13.619406 seconds, 63104 images, 0.319612 hours left
# Loaded: 0.000070 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  987: 2.503969, 2.627801 avg loss, 0.000100 rate, 13.416694 seconds, 63168 images, 0.316945 hours left
# Loaded: 0.000033 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  988: 3.275724, 2.692593 avg loss, 0.000100 rate, 13.556204 seconds, 63232 images, 0.314260 hours left
# Loaded: 0.000039 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  989: 1.895529, 2.612887 avg loss, 0.000100 rate, 13.797636 seconds, 63296 images, 0.311570 hours left
# Loaded: 0.000033 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  990: 2.414015, 2.592999 avg loss, 0.000100 rate, 13.260733 seconds, 63360 images, 0.308876 hours left
# Resizing, random_coef = 1.40
#
#  608 x 608
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.167637 seconds - performance bottleneck on CPU or Disk HDD/SSD
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  991: 2.265725, 2.560272 avg loss, 0.000100 rate, 13.526597 seconds, 63424 images, 0.306155 hours left
# Loaded: 0.000047 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  992: 1.832686, 2.487513 avg loss, 0.000100 rate, 13.608277 seconds, 63488 images, 0.303436 hours left
# Loaded: 0.000038 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  993: 2.599200, 2.498682 avg loss, 0.000100 rate, 13.564544 seconds, 63552 images, 0.300704 hours left
# Loaded: 0.000037 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  994: 2.142649, 2.463079 avg loss, 0.000100 rate, 13.535841 seconds, 63616 images, 0.297961 hours left
# Loaded: 0.000042 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  995: 3.310933, 2.547864 avg loss, 0.000100 rate, 13.448213 seconds, 63680 images, 0.295207 hours left
# Loaded: 0.000040 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  996: 2.853463, 2.578424 avg loss, 0.000100 rate, 13.681530 seconds, 63744 images, 0.292441 hours left
# Loaded: 0.000043 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  997: 2.088485, 2.529430 avg loss, 0.000100 rate, 13.381875 seconds, 63808 images, 0.289669 hours left
# Loaded: 0.000041 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  998: 1.712002, 2.447687 avg loss, 0.000100 rate, 13.416604 seconds, 63872 images, 0.286884 hours left
# Loaded: 0.000041 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  999: 2.712962, 2.474215 avg loss, 0.000100 rate, 13.704655 seconds, 63936 images, 0.284090 hours left
# Loaded: 0.000038 seconds
#
#  (next mAP calculation at 1000 iterations)
#  Last accuracy mAP@0.5 = 49.75 %, best = 49.75 %
#  1000: 2.297211, 2.456514 avg loss, 0.000100 rate, 13.307852 seconds, 64000 images, 0.281287 hours left
# Resizing to initial size: 416 x 416  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
#
#  calculation mAP (mean average precision)...
#
#  detections_count = 13988, unique_truth_count = 2147
# class_id = 0, name = Mask, ap = 77.01%   	 (TP = 346, FP = 106)
# class_id = 1, name = No_mask, ap = 23.04%   	 (TP = 292, FP = 275)
#
#  for conf_thresh = 0.25, precision = 0.63, recall = 0.30, F1-score = 0.40
#  for conf_thresh = 0.25, TP = 638, FP = 381, FN = 1509, average IoU = 45.89 %
#
#  IoU threshold = 50 %, used Area-Under-Curve for each unique Recall
#  mean average precision (mAP@0.50) = 0.500203, or 50.02 %
#
# Set -points flag:
#  `-points 101` for MS COCO
#  `-points 11` for PascalVOC 2007 (uncomment `difficult` in voc.data)
#  `-points 0` (AUC) for ImageNet, PascalVOC 2010-2012, your custom dataset
#
#  mean_average_precision (mAP@0.5) = 0.500203
# New best mAP!

# %% [markdown]
# # <font style="color:blue">Notes on Training</font>
# From the above training process we can make the following observations:
# 1. The images are resized after every 10 iterations
# It takes around 11 seconds per iteration which consists of 64 images for an image size of 576.
# 1. We can see that the training started very slowly in the first few iterations and then very gradually, the loss started reducing.
# 1. As we can see the learning rate increases gradually from 0 to 0.001 by the 100th batch ( burn_in was set to 100 ). It would stay there till the 1500th batch when it would again change to 0.0001.
# 1. mAP is calculated for every 100 iterations. It reaches >80% after 200 iterations.
# 1. You can check out the training graph for mAP v/s iterations which is saved in the file **chart.png**

# %% [markdown]
# ## <font style="color:blue">Download our trained weights</font>
# You can download our weights which we trained using the link below.

# %%
# !wget "https://www.dropbox.com/s/qeno1qc1habd03d/yolov3-ambulance_last.weights?dl=1" -O yolov3-ambulance.weights
# Out:
# --2020-07-07 03:51:54--  https://www.dropbox.com/s/qeno1qc1habd03d/yolov3-ambulance_last.weights?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.1.1, 2620:100:6016:1::a27d:101
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.1.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/qeno1qc1habd03d/yolov3-ambulance_last.weights [following]
# --2020-07-07 03:51:55--  https://www.dropbox.com/s/dl/qeno1qc1habd03d/yolov3-ambulance_last.weights
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc349c71947a6fe37d2224bb75f2.dl.dropboxusercontent.com/cd/0/get/A7Dq_STtBh_YX3PEC4Yd5dRXfOF9UsocDiY3uWdtCQ58rO8hY0hAfSL-mwPKKfe-s_ap3saixkKembzc7hfSF6ONPvYy0DMnQA5rsTc_8-FFQtSpV0cScT3DUzz2DUho19E/file?dl=1# [following]
# --2020-07-07 03:51:55--  https://uc349c71947a6fe37d2224bb75f2.dl.dropboxusercontent.com/cd/0/get/A7Dq_STtBh_YX3PEC4Yd5dRXfOF9UsocDiY3uWdtCQ58rO8hY0hAfSL-mwPKKfe-s_ap3saixkKembzc7hfSF6ONPvYy0DMnQA5rsTc_8-FFQtSpV0cScT3DUzz2DUho19E/file?dl=1
# Resolving uc349c71947a6fe37d2224bb75f2.dl.dropboxusercontent.com (uc349c71947a6fe37d2224bb75f2.dl.dropboxusercontent.com)... 162.125.1.15, 2620:100:6016:15::a27d:10f
# Connecting to uc349c71947a6fe37d2224bb75f2.dl.dropboxusercontent.com (uc349c71947a6fe37d2224bb75f2.dl.dropboxusercontent.com)|162.125.1.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 246239852 (235M) [application/binary]
# Saving to: ‘yolov3-ambulance.weights’
#
# yolov3-ambulance.we 100%[===================>] 234.83M  36.4MB/s    in 6.3s
#
# 2020-07-07 03:52:02 (37.1 MB/s) - ‘yolov3-ambulance.weights’ saved [246239852/246239852]

# %% [markdown]
# # <font style="color:blue">9. Perform Inference</font>
# Finally, let us use the trained model to perform inference on some unseen images from the internet.

# %% [markdown]
# We have written a simple utility function which can be used to display the input and output similar to what we did in the previous section
#
# We are already familiar with the inference code which we saw in the previous section.

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

def display_output(imagePath):
    src = cv2.imread(imagePath,1)
    output = cv2.imread("predictions.jpg")

    plt.figure(figsize=[20,8])
    plt.subplot(121)
    plt.imshow(src[:,:,::-1])
    plt.title("Original Image")
    plt.subplot(122)
    plt.imshow(output[:,:,::-1])
    plt.title("Predictions")
    plt.show()

# %% [markdown]
# ### <font style="color:green">9.1. Test Image 1</font>

# %%
# !wget "https://www.dropbox.com/s/aad0pw7pf4ygs4b/traffic_1.jpg?dl=1" -O test1.jpg
# Out:
# --2020-07-07 03:32:13--  https://www.dropbox.com/s/aad0pw7pf4ygs4b/traffic_1.jpg?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.1.1, 2620:100:6016:1::a27d:101
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.1.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/aad0pw7pf4ygs4b/traffic_1.jpg [following]
# --2020-07-07 03:32:13--  https://www.dropbox.com/s/dl/aad0pw7pf4ygs4b/traffic_1.jpg
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc8252dd6bba9737a290f4ab3c1a.dl.dropboxusercontent.com/cd/0/get/A7DN7aRI-ssAX9kYrgS8BEss0lrTNK6fDqVEeX3L-98m7Dxu6BZUvrjNKUwSQ6BSHvsx9BYgsev2CUWCsmB4qSuHKD0TV0PJeod9aCp2C9kE4NHWDYKClVYCAL1_FQYVGAw/file?dl=1# [following]
# --2020-07-07 03:32:13--  https://uc8252dd6bba9737a290f4ab3c1a.dl.dropboxusercontent.com/cd/0/get/A7DN7aRI-ssAX9kYrgS8BEss0lrTNK6fDqVEeX3L-98m7Dxu6BZUvrjNKUwSQ6BSHvsx9BYgsev2CUWCsmB4qSuHKD0TV0PJeod9aCp2C9kE4NHWDYKClVYCAL1_FQYVGAw/file?dl=1
# Resolving uc8252dd6bba9737a290f4ab3c1a.dl.dropboxusercontent.com (uc8252dd6bba9737a290f4ab3c1a.dl.dropboxusercontent.com)... 162.125.1.15, 2620:100:6016:15::a27d:10f
# Connecting to uc8252dd6bba9737a290f4ab3c1a.dl.dropboxusercontent.com (uc8252dd6bba9737a290f4ab3c1a.dl.dropboxusercontent.com)|162.125.1.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 179153 (175K) [application/binary]
# Saving to: ‘test1.jpg’
#
# test1.jpg           100%[===================>] 174.95K  --.-KB/s    in 0.03s
#
# 2020-07-07 03:32:13 (6.59 MB/s) - ‘test1.jpg’ saved [179153/179153]

# %%
# !pwd
#Testing Ambulance
#!./darknet detector test yolov3-ambulance-setup.data yolov3-ambulance-test.cfg backup/yolov3-ambulance-train_best.weights test1.jpg -thresh .6 2> /dev/null
#!./darknet detector test yolov3-ambulance-setup.data yolov3-ambulance-test.cfg backup/yolov3-ambulance-train_last.weights test1.jpg -thresh .6 2> /dev/null
#!./darknet detector test yolov3-ambulance-setup.data yolov3-ambulance-test.cfg yolov3-ambulance.weights test1.jpg -thresh 0.5
#!./darknet detect cfg/yolov3.cfg yolov3.weights traffic.jpg -thresh 0.5

#Testing MASK
# !./darknet detector test yolov3-mask-setup.data yolov3-mask-test.cfg backup/yolov3-mask-train_final.weights test-image1.jpg -thresh .4 2> /dev/null

display_output("test-image1.jpg")
# Out:
# /content/drive/My Drive/darknet
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#
#  seen 64, trained: 64 K-images (1 Kilo-batches_64)
# test-image1.jpg: Predicted in 102.881000 milli-seconds.
# Mask: 98%

# %% [markdown]
# We can see that the Ambulance from our previous example is now getting detected.
#
# Let us see some more examples!

# %% [markdown]
# ### <font style="color:green">9.2. Test Image 2</font>

# %%
# !wget https://d1muy2ct2wkbaz.cloudfront.net/video/259000/258637/580x325/0.jpg -O test2.jpg
# Out:
# --2020-07-07 04:25:11--  https://d1muy2ct2wkbaz.cloudfront.net/video/259000/258637/580x325/0.jpg
# Resolving d1muy2ct2wkbaz.cloudfront.net (d1muy2ct2wkbaz.cloudfront.net)... 13.224.2.70, 13.224.2.6, 13.224.2.136, ...
# Connecting to d1muy2ct2wkbaz.cloudfront.net (d1muy2ct2wkbaz.cloudfront.net)|13.224.2.70|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 31241 (31K) [image/jpeg]
# Saving to: ‘test2.jpg’
#
# test2.jpg           100%[===================>]  30.51K  --.-KB/s    in 0.1s
#
# 2020-07-07 04:25:11 (268 KB/s) - ‘test2.jpg’ saved [31241/31241]

# %%
# Testing Ambulance
#!./darknet detector test yolov3-ambulance-setup.data yolov3-ambulance-test.cfg backup/yolov3-ambulance-train_best.weights test2.jpg -thresh .6  2> /dev/null
#!./darknet detector test yolov3-ambulance-setup.data yolov3-ambulance-test.cfg backup/yolov3-ambulance-train_last.weights test2.jpg -thresh .6  2> /dev/null
#!./darknet detector test yolov3-ambulance-setup.data yolov3-ambulance-test.cfg yolov3-ambulance.weights test2.jpg -thresh .6  2> /dev/null

#display_output("test2.jpg")

#Testing MASK
# !./darknet detector test yolov3-mask-setup.data yolov3-mask-test.cfg backup/yolov3-mask-train_final.weights test-image2.jpg -thresh .4 2> /dev/null

display_output("test-image2.jpg")
# Out:
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#
#  seen 64, trained: 64 K-images (1 Kilo-batches_64)
# test-image2.jpg: Predicted in 103.064000 milli-seconds.
# Mask: 48%
# Mask: 52%
# No_mask: 53%
# Mask: 43%
# Mask: 73%

# %% [markdown]
# ### <font style="color:green">9.3. Test Image 3</font>

# %%
# !wget https://www.straitstimes.com/sites/default/files/styles/article_pictrure_780x520_/public/articles/2020/01/18/ST_20200118_AMBULANCE_5390028.jpg -O test3.jpg
# Out:
# --2020-07-07 04:30:52--  https://www.straitstimes.com/sites/default/files/styles/article_pictrure_780x520_/public/articles/2020/01/18/ST_20200118_AMBULANCE_5390028.jpg
# Resolving www.straitstimes.com (www.straitstimes.com)... 152.195.55.6
# Connecting to www.straitstimes.com (www.straitstimes.com)|152.195.55.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 102238 (100K) [image/jpeg]
# Saving to: ‘test3.jpg’
#
# test3.jpg           100%[===================>]  99.84K  --.-KB/s    in 0.009s
#
# 2020-07-07 04:30:52 (10.3 MB/s) - ‘test3.jpg’ saved [102238/102238]

# %%
# Testing Ambulance
#!./darknet detector test yolov3-ambulance-setup.data yolov3-ambulance-test.cfg backup/yolov3-ambulance-train_best.weights test3.jpg -thresh .6  2> /dev/null
#display_output("test3.jpg")

#Testing MASK
# !./darknet detector test yolov3-mask-setup.data yolov3-mask-test.cfg backup/yolov3-mask-train_final.weights test-image3.jpg -thresh .4 2> /dev/null

display_output("test-image3.jpg")
# Out:
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#
#  seen 64, trained: 64 K-images (1 Kilo-batches_64)
# test-image3.jpg: Predicted in 102.877000 milli-seconds.
# Mask: 100%
# Mask: 97%
# Mask: 100%
# Mask: 70%
# Mask: 99%
# Mask: 90%
# Mask: 68%
# Mask: 99%
# Mask: 74%
# Mask: 88%
# Mask: 100%
# Mask: 87%
# Mask: 100%
# Mask: 100%
# Mask: 58%
# Mask: 98%

# %% [markdown]
# ### <font style="color:green">9.4. Test Image 4</font>

# %%
# !wget https://www.zhl.org.in/blog/wp-content/uploads/2019/09/Ambulance-Service.jpg -O test4.jpg
# Out:
# --2020-07-07 04:32:03--  https://www.zhl.org.in/blog/wp-content/uploads/2019/09/Ambulance-Service.jpg
# Resolving www.zhl.org.in (www.zhl.org.in)... 13.232.106.231
# Connecting to www.zhl.org.in (www.zhl.org.in)|13.232.106.231|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 294313 (287K) [image/jpeg]
# Saving to: ‘test4.jpg’
#
# test4.jpg           100%[===================>] 287.42K   307KB/s    in 0.9s
#
# 2020-07-07 04:32:05 (307 KB/s) - ‘test4.jpg’ saved [294313/294313]

# %%
# Testing Ambulance
#!./darknet detector test yolov3-ambulance-setup.data yolov3-ambulance-test.cfg backup/yolov3-ambulance-train_best.weights test4.jpg -thresh .6 2> /dev/null
#!./darknet detector test yolov3-ambulance-setup.data yolov3-ambulance-test.cfg backup/yolov3-ambulance-train_last.weights test4.jpg -thresh .6 2> /dev/null
#!./darknet detector test yolov3-ambulance-setup.data yolov3-ambulance-test.cfg yolov3-ambulance.weights test4.jpg -thresh .6 2> /dev/null

#display_output("test4.jpg")

#Testing MASK
# !./darknet detector test yolov3-mask-setup.data yolov3-mask-test.cfg backup/yolov3-mask-train_final.weights test-image4.jpg -thresh .4 2> /dev/null

display_output("test-image4.jpg")
# Out:
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#
#  seen 64, trained: 64 K-images (1 Kilo-batches_64)
# test-image4.jpg: Predicted in 103.281000 milli-seconds.
# No_mask: 46%
# Mask: 56%
# Mask: 100%
# Mask: 59%
# Mask: 100%

# %% [markdown]
# In the last example, we can see that there is a false positive - It classifies a Car as Ambulance. This is bound to happen since many ambulances are of the shape of a car.

# %%
#Testing MASK
# !./darknet detector demo yolov3-mask-setup.data yolov3-mask-test.cfg backup/yolov3-mask-train_final.weights test-video1.mp4 -thresh .4 -out_filename out-vid1.avi -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 94%
#
# FPS:11.8 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 94%
#
# FPS:11.8 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 92%
#
# FPS:11.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 89%
#
# FPS:11.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 81%
#
# FPS:11.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 67%
#
# FPS:11.7 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 69%
#
# FPS:11.7 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 70%
#
# FPS:11.7 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 81%
#
# FPS:11.7 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 79%
#
# FPS:11.7 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 78%
#
# FPS:11.7 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 85%
#
# FPS:11.7 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 89%
#
# FPS:11.7 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 89%
#
# FPS:11.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 88%
#
# FPS:11.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 91%
#
# FPS:11.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 89%
#
# FPS:11.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 90%
#
# FPS:11.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 85%
#
# FPS:11.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 85%
#
# FPS:11.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 80%
#
# FPS:11.7 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 98%
# Mask: 81%
#
# FPS:11.7 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 97%
# Mask: 88%
#
# FPS:11.7 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 97%
# Mask: 92%
#
# FPS:11.7 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 98%
# Mask: 92%
#
# FPS:11.6 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 98%
# Mask: 92%
#
# FPS:11.6 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 53%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 91%
#
# FPS:11.5 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 53%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 91%
#
# FPS:11.5 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 53%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 88%
#
# FPS:11.5 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 53%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 94%
#
# FPS:11.5 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 94%
#
# FPS:11.4 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 94%
#
# FPS:11.5 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 95%
#
# FPS:11.5 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 95%
#
# FPS:11.5 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 96%
#
# FPS:11.5 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 98%
#
# FPS:11.6 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.6 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.6 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.6 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:11.6 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:11.6 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:11.6 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:11.6 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:11.6 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:11.6 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:11.7 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:11.7 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:11.8 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.0 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.0 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.0 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 99%
#
# FPS:12.0 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.0 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.9 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.0 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.7 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 51%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 51%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 51%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.9 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 51%
# Mask: 50%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.0 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 51%
# Mask: 50%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.1 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.0 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.0 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.9 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.0 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.0 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.0 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.0 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.0 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.0 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.0 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.1 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.1 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.1 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.1 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.1 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.2 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.2 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.2 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.2 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.2 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.1 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.1 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.2 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 99%
#
# FPS:12.1 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 68%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 93%
#
# FPS:12.1 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 79%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 84%
#
# FPS:12.2 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 80%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 84%
#
# FPS:12.2 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 93%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 58%
#
# FPS:12.2 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 94%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.2 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 97%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.3 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 99%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.3 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 99%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.3 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 99%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.3 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 100%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.2 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 100%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.2 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 100%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.2 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 99%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.3 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 99%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.3 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 99%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.3 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 98%
# No_mask: 51%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.3 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 98%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.3 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 98%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.3 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 98%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.2 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 98%
# No_mask: 51%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.3 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 98%
# No_mask: 51%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.1 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 97%
# No_mask: 51%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.2 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 96%
# No_mask: 51%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.2 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 95%
# No_mask: 51%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.3 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 94%
# No_mask: 51%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.2 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 90%
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.2 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 90%
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.2 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 86%
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.2 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 84%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.2 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 84%
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.2 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 84%
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.3 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 87%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.3 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 87%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.3 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 85%
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.4 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 86%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.4 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 86%
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.2 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 90%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.2 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 93%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.2 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 93%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.3 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 93%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.3 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 93%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.3 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 91%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.3 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 90%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.3 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 89%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.3 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 89%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.3 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 91%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.3 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 91%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.4 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 90%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.4 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 91%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.4 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 93%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.4 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 93%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.4 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 94%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.4 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 89%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.4 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 83%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.4 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 78%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.4 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 67%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.4 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 67%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.2 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 64%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.1 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 66%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.1 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 69%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.2 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 70%
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.2 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 73%
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.3 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 73%
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.3 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 70%
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.3 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 66%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.3 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 75%
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.3 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 79%
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.3 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 83%
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.3 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 82%
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:12.3 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 83%
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.3 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 82%
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.3 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 87%
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.4 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 87%
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.4 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 88%
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.4 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 88%
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.4 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 90%
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.4 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 91%
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.5 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 92%
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.5 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 92%
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.5 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 92%
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.6 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 92%
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.6 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 91%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.6 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 91%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 98%
#
# FPS:12.6 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 90%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 98%
#
# FPS:12.6 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 89%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.5 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 87%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.5 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 87%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.4 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 88%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.3 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 87%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.2 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 86%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.2 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 87%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.1 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 85%
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.1 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 85%
# No_mask: 51%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.1 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 88%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.0 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 88%
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.0 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 91%
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.9 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 91%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.0 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 91%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.0 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 91%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.0 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 93%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.0 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 94%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 92%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 86%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 93%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 93%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 98%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 98%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 98%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 98%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.9 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 99%
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.9 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 99%
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.7 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 99%
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 99%
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 99%
# No_mask: 51%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 99%
# No_mask: 51%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 99%
# No_mask: 51%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.9 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 99%
# No_mask: 51%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 99%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.9 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 99%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.9 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 98%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.9 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 98%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.0 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 97%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.0 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 97%
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.9 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 98%
# No_mask: 51%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.9 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 98%
# No_mask: 51%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.9 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 98%
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.9 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 96%
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.9 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 72%
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 85%
#
# FPS:11.9 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 72%
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 85%
#
# FPS:11.9 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 98%
#
# FPS:11.9 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:12.3
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.0 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.1 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 99%
#
# FPS:12.2 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 99%
#
# FPS:12.1 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 98%
#
# FPS:12.0 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 97%
#
# FPS:12.0 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 97%
#
# FPS:11.9 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 97%
#
# FPS:11.9 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 51%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 97%
#
# FPS:11.9 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 51%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 97%
#
# FPS:12.0 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 47%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 98%
#
# FPS:11.9 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 47%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 97%
#
# FPS:11.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 97%
#
# FPS:11.9 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 94%
#
# FPS:11.6 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 91%
#
# FPS:11.6 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 91%
#
# FPS:11.5 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 91%
#
# FPS:11.6 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 47%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 97%
#
# FPS:11.7 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 51%
# Mask: 47%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 97%
#
# FPS:11.7 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 51%
# Mask: 47%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 97%
#
# FPS:11.7 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 51%
# Mask: 47%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 98%
#
# FPS:11.7 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 51%
# Mask: 47%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 98%
#
# FPS:11.6 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 47%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 98%
#
# FPS:11.6 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 99%
#
# FPS:11.6 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 99%
#
# FPS:11.7 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.7 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.7 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.7 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.7 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.7 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 51%
# Mask: 46%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 51%
# Mask: 47%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 51%
# Mask: 47%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 50%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 50%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.0 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 51%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.0 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 51%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.0 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.0 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.0 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:12.0 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 98%
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 98%
#
# FPS:12.0 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 47%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 51%
# Mask: 47%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 51%
# Mask: 47%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 51%
# Mask: 47%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 51%
# Mask: 46%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 50%
# Mask: 46%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 50%
# Mask: 46%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 50%
# Mask: 47%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 50%
# Mask: 47%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 50%
# Mask: 46%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 49%
# Mask: 47%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.7 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 49%
# Mask: 47%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 49%
# Mask: 47%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 50%
# Mask: 47%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 51%
# Mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 51%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 51%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 51%
# Mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 50%
# Mask: 46%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 99%
#
# FPS:11.7 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 49%
# Mask: 45%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 49%
# Mask: 45%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 50%
# Mask: 45%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 43%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 43%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 50%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 42%
#
# FPS:11.7 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 42% , No_mask: 50%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 42% , No_mask: 50%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 41% , No_mask: 50%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 50%
# Mask: 45%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.7 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 50%
# Mask: 45%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 50%
# Mask: 47%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.7 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 50%
# Mask: 47%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 50%
# Mask: 47%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.7 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 49%
# Mask: 46%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 48%
# Mask: 45%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 48%
# Mask: 45%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 48%
# Mask: 45%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.7 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 48%
# Mask: 44%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 49%
# Mask: 45%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 44%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 44%
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 44%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 49%
# Mask: 45%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.7 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 44%
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 43%
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 42%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 47%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 42%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 47%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 42%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 47%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 41%
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
# Mask: 42%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 40% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 40% , No_mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 41% , No_mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 41% , No_mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 41% , No_mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 41% , No_mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 41% , No_mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 41% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 41% , No_mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 41% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 42% , No_mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 42% , No_mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 43% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 43% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 43% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.6 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 43% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 43% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.6 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 43% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 43% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 43% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 42% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.6 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 42% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 40% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 47%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.6 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 47%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 47%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 47%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 40% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 42% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 43% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 43% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 44% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.6 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 44% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.6 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 44% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.6 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 44% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.6 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 44% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.6 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 44% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.6 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 44% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.6 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 44% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.6 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 45% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.5 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 45% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.5 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 45% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.5 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 46% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.6 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 45% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 45% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 44% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.6 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 44% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.6 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 43% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.5 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 44% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.5 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 44% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:11.5 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 44% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:11.6 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 45% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:11.6 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 44% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:11.6 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 44% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:11.6 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 44% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.6 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 43% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 43% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 43% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 43% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 43% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 43% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 44% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 44% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 43% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 43% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:11.7 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 43% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:11.8 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 42% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:11.8 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 43% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:11.8 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 42% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:11.7 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 42% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:11.8 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 42% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:11.7 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 41% , No_mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:11.8 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 42% , No_mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:11.7 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 42% , No_mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:11.8 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 42% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:11.8 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 42% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:11.8 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 43% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:11.8 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 43% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:11.9 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 42% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:11.8 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 42% , No_mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:11.9 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 42% , No_mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:11.9 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 42% , No_mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:11.9 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 41% , No_mask: 49%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:11.9 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 40% , No_mask: 48%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:11.9 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 46%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 42%
#
# FPS:11.8 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 48%
# Mask: 45%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:11.9 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 48%
# Mask: 45%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:11.8 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 48%
# Mask: 46%
# Mask: 100%
# Mask: 100%
# Mask: 100%
# Mask: 100%
#
# FPS:11.8 	 AVG_FPS:11.6
# Stream closed.
#
#  cvWriteFrame
# input video stream closed.
#  closing... closed!output_video_writer closed.

# %%
#Testing MASK
# !./darknet detector demo yolov3-mask-setup.data yolov3-mask-test.cfg backup/yolov3-mask-train_best.weights test-video2.mp4 -thresh .4 -out_filename out-vid2.avi -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# Mask: 49%
#
# FPS:11.5 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# Mask: 67%
#
# FPS:11.6 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No_mask: 55%
#
# FPS:11.8 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No_mask: 67%
#
# FPS:11.8 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No_mask: 90%
#
# FPS:11.7 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No_mask: 90%
#
# FPS:11.7 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No_mask: 87%
#
# FPS:11.6 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No_mask: 81%
#
# FPS:11.7 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# No_mask: 54%
#
# FPS:11.7 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 72%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 71%
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 40%
#
# FPS:11.6 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 78%
#
# FPS:11.5 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 49%
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 41%
#
# FPS:11.4 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 42%
#
# FPS:11.5 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 46%
#
# FPS:11.5 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 45%
#
# FPS:11.5 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 79%
#
# FPS:11.5 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 58%
#
# FPS:11.4 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 47%
#
# FPS:11.3 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.4 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
# No_mask: 56%
#
# FPS:11.5 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
# Mask: 41%
#
# FPS:11.5 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
# Mask: 44%
#
# FPS:11.5 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
# No_mask: 46%
#
# FPS:11.7 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
# No_mask: 74%
#
# FPS:11.7 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
# No_mask: 44%
#
# FPS:11.7 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
# No_mask: 96%
#
# FPS:11.8 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
# No_mask: 97%
#
# FPS:11.7 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
# No_mask: 97%
#
# FPS:11.8 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
# No_mask: 81%
# No_mask: 44%
#
# FPS:11.8 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
# No_mask: 67%
#
# FPS:11.8 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
# Mask: 43% , No_mask: 46%
#
# FPS:11.8 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
# No_mask: 60%
# Mask: 52% , No_mask: 41%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 40%
# Mask: 49%
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 46%
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 52% , No_mask: 42%
#
# FPS:12.0 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 55%
#
# FPS:12.0 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 52%
#
# FPS:12.0 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 53%
#
# FPS:12.1 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 54%
#
# FPS:12.1 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 55%
#
# FPS:12.1 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 54%
#
# FPS:12.2 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 42%
#
# FPS:12.1 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 53%
# Mask: 82%
#
# FPS:12.1 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 53%
# Mask: 83%
#
# FPS:12.0 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 91%
#
# FPS:12.0 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 92%
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 67%
# Mask: 79%
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 95%
#
# FPS:12.0 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 93%
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 93%
#
# FPS:12.0 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 58%
# Mask: 96%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 78%
# Mask: 97%
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 78%
# Mask: 96%
#
# FPS:12.0 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
#
# FPS:12.0 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 98%
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 98%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 97%
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
#
# FPS:12.0 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 96%
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# Mask: 98%
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.0 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.0 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.0 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.0 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.0 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.0 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.0 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.1 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 58%
#
# FPS:12.1 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.1 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.0 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 46%
# No_mask: 40%
#
# FPS:12.0 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 45%
#
# FPS:11.9 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 45%
#
# FPS:11.9 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
#
# FPS:11.9 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 77%
#
# FPS:12.0 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 78%
#
# FPS:12.0 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 71%
#
# FPS:12.0 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 43%
#
# FPS:12.1 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 44%
#
# FPS:12.1 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.1 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.1 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.1 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.1 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.1 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.2 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.2 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.2 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.2 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 45%
#
# FPS:12.3 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.3 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.4 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 55%
#
# FPS:12.3 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 49%
#
# FPS:12.3 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 49%
#
# FPS:12.2 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 54%
#
# FPS:12.2 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 49%
#
# FPS:12.1 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 49%
#
# FPS:12.1 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.1 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 44%
#
# FPS:12.0 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.0 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
#
# FPS:12.0 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
# No_mask: 40%
#
# FPS:11.7 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
# No_mask: 66%
#
# FPS:11.6 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 47%
# Mask: 46%
#
# FPS:11.6 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
# No_mask: 70%
#
# FPS:11.8 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
# No_mask: 65%
#
# FPS:11.7 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
# No_mask: 74%
#
# FPS:11.8 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
# No_mask: 68%
#
# FPS:11.8 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 65%
#
# FPS:11.7 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 90%
#
# FPS:11.8 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 90%
#
# FPS:11.7 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
# Mask: 76%
#
# FPS:11.8 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
# No_mask: 50%
#
# FPS:11.8 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
# No_mask: 55%
#
# FPS:11.7 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
# No_mask: 45%
#
# FPS:11.7 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 76%
#
# FPS:11.7 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 77%
#
# FPS:11.6 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 44%
#
# FPS:11.7 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 94%
#
# FPS:11.7 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 94%
#
# FPS:11.8 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 74%
#
# FPS:11.7 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 46%
#
# FPS:11.8 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 48%
#
# FPS:11.7 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# No_mask: 43%
#
# FPS:11.8 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 46%
#
# FPS:11.7 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 43%
#
# FPS:11.8 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 50%
#
# FPS:11.8 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 46%
#
# FPS:11.8 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 46%
#
# FPS:11.7 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 46%
#
# FPS:11.6 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 72%
#
# FPS:11.5 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 56%
#
# FPS:11.7 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 89%
#
# FPS:11.7 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 96%
#
# FPS:11.8 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 96%
#
# FPS:11.7 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
#
# FPS:11.7 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
#
# FPS:11.7 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
#
# FPS:11.5 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 97%
#
# FPS:11.6 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 84%
#
# FPS:11.8 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 83%
#
# FPS:11.9 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.0 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 48%
#
# FPS:12.0 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.0 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.1 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.1 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.2 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.1 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 40%
#
# FPS:12.1 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
# Mask: 49%
#
# FPS:12.2 	 AVG_FPS:11.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.2 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.3 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.3 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.2 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 75%
#
# FPS:12.2 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 58%
#
# FPS:12.3 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 43%
# Mask: 41%
#
# FPS:12.3 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.3 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.2 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.3 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.4 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.4 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.4 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.4 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.3 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.3 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.2 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 45%
#
# FPS:12.2 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.1 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.1 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.1 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.1 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 60%
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.1 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 51%
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 90%
#
# FPS:12.1 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 90%
#
# FPS:12.1 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 91%
#
# FPS:12.1 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 86%
#
# FPS:12.1 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 65%
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 68%
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 74%
# No_mask: 55%
#
# FPS:12.1 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 74%
# No_mask: 56%
#
# FPS:12.1 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 73%
#
# FPS:12.1 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# No_mask: 41%
#
# FPS:12.1 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 99%
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 59%
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 82%
#
# FPS:12.0 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
# No_mask: 84%
#
# FPS:12.0 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
# No_mask: 83%
#
# FPS:12.0 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.0 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.1 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.1 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.1 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.1 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.1 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.1 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.1 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.1 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.2 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.2 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.1 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.1 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.1 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.1 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.1 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.1 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.0 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.1 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.1 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.0 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.1 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.0 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.0 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.1 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.1 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
# No_mask: 40%
#
# FPS:12.1 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.1 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
# No_mask: 45%
#
# FPS:12.2 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
# No_mask: 50%
#
# FPS:12.1 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.1 	 AVG_FPS:12.1
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 47%
# No_mask: 44%
#
# FPS:11.7 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 65%
# No_mask: 54%
#
# FPS:11.8 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 79%
#
# FPS:11.8 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 53%
#
# FPS:11.9 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 53%
#
# FPS:11.8 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 51%
#
# FPS:11.9 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
#
# FPS:11.8 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
#
# FPS:11.8 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 55%
#
# FPS:11.9 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 42%
#
# FPS:12.0 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 56%
#
# FPS:12.0 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 48%
#
# FPS:12.1 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 63%
# No_mask: 41%
# No_mask: 40%
#
# FPS:12.1 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 62%
# No_mask: 42%
#
# FPS:12.1 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 64%
# No_mask: 45%
#
# FPS:12.2 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 55%
#
# FPS:12.2 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.1 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 44%
# No_mask: 40%
# Mask: 48%
#
# FPS:12.2 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 43%
# Mask: 43%
#
# FPS:12.2 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 44%
# Mask: 43%
#
# FPS:12.3 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 52%
#
# FPS:12.3 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 46%
# No_mask: 41%
# Mask: 56%
#
# FPS:12.3 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 78%
# Mask: 51%
#
# FPS:12.4 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 51%
#
# FPS:12.4 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 64%
# Mask: 70%
#
# FPS:12.4 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 65%
# Mask: 70%
#
# FPS:12.3 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 83%
#
# FPS:12.2 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 81%
# Mask: 52%
#
# FPS:12.1 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 77%
#
# FPS:11.9 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 53%
# Mask: 81%
#
# FPS:12.0 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 97%
#
# FPS:12.0 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 97%
#
# FPS:11.9 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 90%
#
# FPS:11.9 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 81%
#
# FPS:11.9 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 43%
# Mask: 98%
#
# FPS:11.8 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
#
# FPS:11.8 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
#
# FPS:11.8 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
#
# FPS:11.9 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
#
# FPS:11.9 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 41%
# Mask: 100%
#
# FPS:11.8 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 47%
# Mask: 95%
#
# FPS:11.7 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 47%
# Mask: 59%
#
# FPS:11.8 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 43%
#
# FPS:11.8 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 43%
#
# FPS:11.9 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 42% , No_mask: 43%
#
# FPS:11.7 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 45% , No_mask: 45%
#
# FPS:11.8 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 44%
# Mask: 48%
#
# FPS:11.8 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 47% , No_mask: 45%
#
# FPS:11.8 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 65%
# Mask: 41%
#
# FPS:11.7 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 69%
# Mask: 41%
#
# FPS:11.8 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 77%
#
# FPS:11.8 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 79%
# Mask: 45% , No_mask: 40%
#
# FPS:11.7 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 46%
# Mask: 48% , No_mask: 42%
#
# FPS:11.8 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 44% , No_mask: 41%
#
# FPS:11.7 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 49%
# Mask: 52%
#
# FPS:11.7 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 49%
# Mask: 52%
#
# FPS:11.8 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 54%
# Mask: 50%
#
# FPS:11.9 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 58%
# Mask: 50%
#
# FPS:11.9 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 51%
# Mask: 43%
#
# FPS:11.8 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 46%
# Mask: 83%
#
# FPS:11.9 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 72%
#
# FPS:11.9 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# Mask: 70%
#
# FPS:11.9 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
# No_mask: 42%
#
# FPS:11.6 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:12.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 63%
# No_mask: 43%
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 62%
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 66%
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 76%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 50%
# No_mask: 47%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 90%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 90%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 95%
# No_mask: 41%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 86%
# No_mask: 44%
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 42%
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 41%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 40%
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 45%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 51%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 51%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 67%
# No_mask: 48%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 58%
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 51%
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 83%
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 93%
# No_mask: 43%
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 93%
# No_mask: 43%
#
# FPS:11.9 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 96%
# No_mask: 70%
# No_mask: 40%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 99%
# No_mask: 75%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 97%
# No_mask: 42%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 85%
# No_mask: 42%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 98%
# No_mask: 62%
#
# FPS:11.8 	 AVG_FPS:11.7
#
#  cvWriteFrame
# Objects:
#
# No_mask: 98%
# No_mask: 61%
#
# FPS:11.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 45%
# No_mask: 44%
#
# FPS:11.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 87%
#
# FPS:11.9 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.0 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.0 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
#
# FPS:11.9 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
#
# FPS:12.0 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 53%
#
# FPS:12.1 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 43%
#
# FPS:11.7 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 44%
#
# FPS:11.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 45%
#
# FPS:11.7 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 49%
# No_mask: 44%
# No_mask: 42%
#
# FPS:11.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 51%
#
# FPS:11.9 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 44%
#
# FPS:11.9 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 49%
# No_mask: 45%
#
# FPS:11.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 50%
# No_mask: 44%
#
# FPS:11.9 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 49%
# Mask: 40% , No_mask: 48%
#
# FPS:11.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 43%
#
# FPS:11.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# Mask: 42% , No_mask: 49%
#
# FPS:11.7 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 47%
# Mask: 43%
#
# FPS:11.7 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 47%
# Mask: 42%
#
# FPS:11.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 63%
# Mask: 46%
#
# FPS:11.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 62%
# No_mask: 42%
# Mask: 52% , No_mask: 42%
#
# FPS:11.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 82%
# Mask: 54%
#
# FPS:11.7 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 77%
# Mask: 50% , No_mask: 40%
#
# FPS:11.7 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# Mask: 45%
#
# FPS:11.7 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# Mask: 45%
#
# FPS:11.7 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# Mask: 52%
#
# FPS:11.7 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# Mask: 56%
#
# FPS:11.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# Mask: 50%
#
# FPS:11.9 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# Mask: 54%
#
# FPS:12.0 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# Mask: 50%
#
# FPS:12.0 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# Mask: 51%
#
# FPS:12.0 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.0 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 42%
#
# FPS:11.9 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 43%
#
# FPS:11.9 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# Mask: 53%
#
# FPS:11.9 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# Mask: 94%
#
# FPS:11.9 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 40%
# Mask: 94%
#
# FPS:12.0 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# Mask: 96%
#
# FPS:12.0 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# Mask: 91%
#
# FPS:11.9 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 51%
# Mask: 96%
#
# FPS:12.0 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 57%
# No_mask: 48%
# Mask: 86%
#
# FPS:11.9 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 59%
# No_mask: 58%
# No_mask: 40%
#
# FPS:12.0 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 60%
# No_mask: 56%
#
# FPS:12.1 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 54%
# No_mask: 41%
# No_mask: 40%
#
# FPS:12.2 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 41%
#
# FPS:12.2 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.2 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 43%
# No_mask: 42%
#
# FPS:12.1 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 51%
#
# FPS:12.1 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 51%
#
# FPS:12.0 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 49%
# No_mask: 48%
#
# FPS:12.0 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 53%
#
# FPS:12.0 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 55%
# No_mask: 44%
#
# FPS:11.9 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# Mask: 40% , No_mask: 48%
#
# FPS:11.9 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 50%
# No_mask: 45%
# Mask: 40%
#
# FPS:12.0 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 50%
# No_mask: 49%
#
# FPS:11.9 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# Mask: 42% , No_mask: 45%
#
# FPS:12.0 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 46%
# Mask: 50% , No_mask: 45%
# No_mask: 43%
#
# FPS:11.9 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 48%
# Mask: 49% , No_mask: 44%
# No_mask: 41%
#
# FPS:12.0 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 45%
# No_mask: 43%
# Mask: 54% , No_mask: 43%
#
# FPS:11.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 48%
# Mask: 54%
#
# FPS:11.9 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 46%
# Mask: 54%
#
# FPS:11.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 55%
# Mask: 50% , No_mask: 40%
#
# FPS:11.9 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 54%
# No_mask: 52%
# Mask: 47%
#
# FPS:11.9 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 54%
# No_mask: 42%
#
# FPS:11.9 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 48%
# No_mask: 42%
#
# FPS:11.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 51%
#
# FPS:11.8 	 AVG_FPS:11.8
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 48%
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 57%
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 49%
# No_mask: 44%
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.6 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 62%
# No_mask: 51%
# No_mask: 46%
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 57%
# No_mask: 43%
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 41%
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 44%
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 50%
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 50%
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 40%
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 59%
# No_mask: 47%
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 66%
# No_mask: 47%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 66%
# No_mask: 50%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 64%
# No_mask: 50%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 44%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 53%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 50%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 45%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 45%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 50%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 43%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 58%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 70%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 68%
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 80%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 89%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 42%
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 48%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 46%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 42%
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 44%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 47%
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 47%
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 49%
# Mask: 77%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 44%
# Mask: 92%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 42% , No_mask: 41%
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 41%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 46%
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 41%
# Mask: 47%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 45%
# No_mask: 40%
# Mask: 50%
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 45%
# Mask: 53% , No_mask: 41%
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 47%
# Mask: 52%
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 57%
# Mask: 48%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 47%
# Mask: 75%
# Mask: 48%
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 47%
# Mask: 75%
# Mask: 48%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 90%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 51%
# Mask: 93%
# Mask: 84%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 56%
# Mask: 87%
# Mask: 73%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 49%
# Mask: 98%
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 98%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 98%
#
# FPS:11.7 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 98%
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 94%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 81%
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 59%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 58%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 47%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 44%
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.1 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 40%
#
# FPS:12.1 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 40%
#
# FPS:12.2 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.2 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.2 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.3 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.3 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.3 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.3 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.4 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.4 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.4 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.5 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.4 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.4 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.4 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.5 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.5 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 63%
#
# FPS:12.5 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.5 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.5 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.5 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.5 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.5 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 43%
#
# FPS:12.5 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.5 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.5 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 41%
#
# FPS:12.4 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 42%
#
# FPS:12.3 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 42%
#
# FPS:12.3 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 44%
#
# FPS:12.3 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 46%
#
# FPS:12.2 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 43%
#
# FPS:12.1 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.1 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.1 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.0 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 41%
#
# FPS:12.0 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 44%
#
# FPS:11.8 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 43%
#
# FPS:11.8 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 42%
#
# FPS:11.7 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# Mask: 44%
#
# FPS:11.7 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 48%
#
# FPS:11.7 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 48%
# No_mask: 41%
#
# FPS:11.7 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 48%
# No_mask: 41%
#
# FPS:11.8 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 61%
# No_mask: 43%
#
# FPS:11.7 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
#
# FPS:11.5 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.5 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:12.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.1 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.1 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 40%
#
# FPS:12.1 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 40%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 44%
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 54%
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 49%
# Mask: 42%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 43%
# Mask: 41%
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 46%
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 49%
# Mask: 51%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 49%
# Mask: 51%
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 46%
# Mask: 50%
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# No_mask: 52%
# Mask: 47%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 46%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 44%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 67%
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 74%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 97%
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 88%
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 98%
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 100%
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 99%
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 88%
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
# Mask: 87%
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.0 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.8 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.9 	 AVG_FPS:11.9
# Stream closed.
#
#  cvWriteFrame
# input video stream closed.
#  closing... closed!output_video_writer closed.
